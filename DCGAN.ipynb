# %% [markdown]
# This first cell makes sure that torchgan is installed. It's primarily here for use with colab, since colab doesn't have torchgan installed by default.

# %%
# from torchGAN tutorial

try:
    import torchgan

    print(f"Existing TorchGAN {torchgan.__version__} installation found")
except ImportError:
    import subprocess
    import sys

    subprocess.check_call([sys.executable, "-m", "pip", "install", "torchgan"])
    import torchgan

    print(f"Installed TorchGAN {torchgan.__version__}")
# Out:
# Existing TorchGAN v0.1.0 installation found

# %%
import torch
import torch.nn as nn
import torch.backends.cudnn
import torch.utils.data as tdata
from torch.optim import Adam
import torchvision
import torchvision.datasets as dsets
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import torchgan
from torchgan.models import *
from torchgan.losses import *
from torchgan.trainer import Trainer

# %% [markdown]
# This cell takes care of creating the dataset. Any PNG or JPEG image files are acceptable, as long as their width and height are the same. The models also require that the dimensions of the image are a perfect power of 2, but that can be overcome by scaling the images.
#
# Another thing to note is that the file path provided as root cannot be the exact folder that holds the images. In order for the path to be recognized properly, you must specify the folder that contains the folder with the images.
#
# For copyright reasons, the images that I am training from are not included with the GitHub repo. If you are interested in learning more, the citations for all of the images are included in the bibliography of the accompanying report.

# %%
size = 256

data = ImageFolder(
    root="./data/pictures/preprocessed/complete/",
    transform=transforms.Compose([
        transforms.Resize((size, size)),
        transforms.ToTensor(),
        transforms.Normalize(mean=.5, std=.5)
    ])
)
print(len(data))
# Out:
# 211

# %%
dataloader = tdata.DataLoader(data, batch_size=64, shuffle=True)

# %%
# adapted from torchgan tutorial

dcgan_network = {
    "generator": {
        "name": DCGANGenerator,
        "args": {
            "encoding_dims": 100,
            "out_size": size,           # this is how many pixels wide and tall the generated images will be
            "out_channels": 3,          # change this to 1 if the images are in black and white
            "step_channels": 32,
            "nonlinearity": nn.LeakyReLU(0.2),
            "last_nonlinearity": nn.Tanh(),
        },
        "optimizer": {"name": Adam, "args": {"lr": 0.0001, "betas": (0.5, 0.999)}},
    },
    "discriminator": {
        "name": DCGANDiscriminator,
        "args": {
            "in_size": size,            # this is how many pixels wide and tall we resized the images to be.
            "in_channels": 3,           # change this to 1 if the images are in black and white
            "step_channels": 32,
            "nonlinearity": nn.LeakyReLU(0.2),
            "last_nonlinearity": nn.LeakyReLU(0.2),
        },
        "optimizer": {"name": Adam, "args": {"lr": 0.0003, "betas": (0.5, 0.999)}},
    },
}

# %%
# from torchgan tutorial

minimax_losses = [MinimaxGeneratorLoss(), MinimaxDiscriminatorLoss()]
wgangp_losses = [
    WassersteinGeneratorLoss(),
    WassersteinDiscriminatorLoss(),
    WassersteinGradientPenalty(),
]
lsgan_losses = [LeastSquaresGeneratorLoss(), LeastSquaresDiscriminatorLoss()]

# %% [markdown]
# If you're running this on colab, be sure to select a GPU runtime for the best performance.

# %%
# more from torchgan tutorial

if torch.cuda.is_available():
    device = torch.device("cuda:0")
    # Use deterministic cudnn algorithms
    torch.backends.cudnn.deterministic = True
    epochs = 10
else:
    device = torch.device("cpu")
    epochs = 5

print("Device: {}".format(device))
print("Epochs: {}".format(epochs))
# Out:
# Device: cpu
# Epochs: 5

# %%
# from torchgan tutorial

trainer = Trainer(
    dcgan_network,
    lsgan_losses,
    sample_size=64,
    epochs=1000,             # you can override the number of epochs here if you want to try to get better results
    device=device
)

# %% [markdown]
# This is the cell that actually does the training. After it finishes, you can run it again to keep training the same model.

# %%
trainer(dataloader)
# Out:
# Saving Model at './model/gan0.model'
# Epoch 1 Summary
# Epoch time duration : 35.821415185928345
# generator Mean Gradients : 7.647486985263731
# discriminator Mean Gradients : 341.87434565231916
# Mean Running Discriminator Loss : 0.13479580695551427
# Mean Running Generator Loss : 0.6077807422124453
# Generating and Saving Images to ./images/epoch1001_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 2 Summary
# Epoch time duration : 35.77073907852173
# generator Mean Gradients : 7.639974272064119
# discriminator Mean Gradients : 341.78451712187723
# Mean Running Discriminator Loss : 0.13473731691819757
# Mean Running Generator Loss : 0.6077075987150837
# Generating and Saving Images to ./images/epoch1002_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 3 Summary
# Epoch time duration : 35.505197286605835
# generator Mean Gradients : 7.632463430596368
# discriminator Mean Gradients : 341.4944557798314
# Mean Running Discriminator Loss : 0.134631456859573
# Mean Running Generator Loss : 0.6076270775109945
# Generating and Saving Images to ./images/epoch1003_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 4 Summary
# Epoch time duration : 36.525869607925415
# generator Mean Gradients : 7.6249050405039265
# discriminator Mean Gradients : 341.1771258856588
# Mean Running Discriminator Loss : 0.13451292785600572
# Mean Running Generator Loss : 0.6075323575391505
# Generating and Saving Images to ./images/epoch1004_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 5 Summary
# Epoch time duration : 35.75388312339783
# generator Mean Gradients : 7.617435330734465
# discriminator Mean Gradients : 340.88910304669196
# Mean Running Discriminator Loss : 0.13439359582461932
# Mean Running Generator Loss : 0.6074255997361384
# Generating and Saving Images to ./images/epoch1005_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 6 Summary
# Epoch time duration : 35.49365472793579
# generator Mean Gradients : 7.610153057836141
# discriminator Mean Gradients : 340.58359091222064
# Mean Running Discriminator Loss : 0.13427955462274102
# Mean Running Generator Loss : 0.6073309371329355
# Generating and Saving Images to ./images/epoch1006_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 7 Summary
# Epoch time duration : 35.791470766067505
# generator Mean Gradients : 7.602725287130998
# discriminator Mean Gradients : 340.2577859226321
# Mean Running Discriminator Loss : 0.13416804046951702
# Mean Running Generator Loss : 0.6072359142590096
# Generating and Saving Images to ./images/epoch1007_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 8 Summary
# Epoch time duration : 35.66484975814819
# generator Mean Gradients : 7.601332318397362
# discriminator Mean Gradients : 340.0447352101484
# Mean Running Discriminator Loss : 0.13408662854725129
# Mean Running Generator Loss : 0.6071324972084738
# Generating and Saving Images to ./images/epoch1008_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 9 Summary
# Epoch time duration : 36.041287422180176
# generator Mean Gradients : 7.593980824308738
# discriminator Mean Gradients : 339.8069046767265
# Mean Running Discriminator Loss : 0.13398513430172815
# Mean Running Generator Loss : 0.6070819974658186
# Generating and Saving Images to ./images/epoch1009_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 10 Summary
# Epoch time duration : 36.446876525878906
# generator Mean Gradients : 7.587012098418909
# discriminator Mean Gradients : 339.52614374444914
# Mean Running Discriminator Loss : 0.13389369152428116
# Mean Running Generator Loss : 0.6070409682514791
# Generating and Saving Images to ./images/epoch1010_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 11 Summary
# Epoch time duration : 36.63819599151611
# generator Mean Gradients : 7.579629337194911
# discriminator Mean Gradients : 339.9249816983422
# Mean Running Discriminator Loss : 0.13397437992616157
# Mean Running Generator Loss : 0.6070568745883972
# Generating and Saving Images to ./images/epoch1011_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 12 Summary
# Epoch time duration : 35.8503634929657
# generator Mean Gradients : 7.572526211389379
# discriminator Mean Gradients : 339.6359763641653
# Mean Running Discriminator Loss : 0.13389035054017664
# Mean Running Generator Loss : 0.6069771538510653
# Generating and Saving Images to ./images/epoch1012_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 13 Summary
# Epoch time duration : 35.48079538345337
# generator Mean Gradients : 7.565094290046191
# discriminator Mean Gradients : 339.3242892943093
# Mean Running Discriminator Loss : 0.1337881432542509
# Mean Running Generator Loss : 0.6068816964274598
# Generating and Saving Images to ./images/epoch1013_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 14 Summary
# Epoch time duration : 35.391812324523926
# generator Mean Gradients : 7.557713561486887
# discriminator Mean Gradients : 339.22503608712015
# Mean Running Discriminator Loss : 0.13374596212195997
# Mean Running Generator Loss : 0.606795994945135
# Generating and Saving Images to ./images/epoch1014_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 15 Summary
# Epoch time duration : 35.62341499328613
# generator Mean Gradients : 7.550440282786666
# discriminator Mean Gradients : 338.9137531433819
# Mean Running Discriminator Loss : 0.1336481844710147
# Mean Running Generator Loss : 0.6067063399301521
# Generating and Saving Images to ./images/epoch1015_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 16 Summary
# Epoch time duration : 35.476848125457764
# generator Mean Gradients : 7.543524389378487
# discriminator Mean Gradients : 338.7514860381613
# Mean Running Discriminator Loss : 0.13355401017646168
# Mean Running Generator Loss : 0.6065527470287405
# Generating and Saving Images to ./images/epoch1016_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 17 Summary
# Epoch time duration : 35.607436656951904
# generator Mean Gradients : 7.540428381627769
# discriminator Mean Gradients : 338.51097929978124
# Mean Running Discriminator Loss : 0.1336458897340991
# Mean Running Generator Loss : 0.6066275715348086
# Generating and Saving Images to ./images/epoch1017_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 18 Summary
# Epoch time duration : 35.26872515678406
# generator Mean Gradients : 7.533061512524535
# discriminator Mean Gradients : 338.2886891256184
# Mean Running Discriminator Loss : 0.13355900129242843
# Mean Running Generator Loss : 0.6065903783360522
# Generating and Saving Images to ./images/epoch1018_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 19 Summary
# Epoch time duration : 35.44359636306763
# generator Mean Gradients : 7.525699693353685
# discriminator Mean Gradients : 337.97532585805334
# Mean Running Discriminator Loss : 0.13345111824475092
# Mean Running Generator Loss : 0.6065333389985111
# Generating and Saving Images to ./images/epoch1019_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 20 Summary
# Epoch time duration : 36.73420548439026
# generator Mean Gradients : 7.518354607831798
# discriminator Mean Gradients : 337.7222950153001
# Mean Running Discriminator Loss : 0.13334678580214648
# Mean Running Generator Loss : 0.6064701503854902
# Generating and Saving Images to ./images/epoch1020_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 21 Summary
# Epoch time duration : 35.78351902961731
# generator Mean Gradients : 7.511117204484141
# discriminator Mean Gradients : 337.81828311717527
# Mean Running Discriminator Loss : 0.13331680449341418
# Mean Running Generator Loss : 0.6063633811670145
# Generating and Saving Images to ./images/epoch1021_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 22 Summary
# Epoch time duration : 35.557626247406006
# generator Mean Gradients : 7.5038798994153275
# discriminator Mean Gradients : 337.5546293829369
# Mean Running Discriminator Loss : 0.13334826439426672
# Mean Running Generator Loss : 0.6063691869527539
# Generating and Saving Images to ./images/epoch1022_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 23 Summary
# Epoch time duration : 35.54995536804199
# generator Mean Gradients : 7.496647894735484
# discriminator Mean Gradients : 337.29974553616665
# Mean Running Discriminator Loss : 0.13324907022950655
# Mean Running Generator Loss : 0.6062921388557259
# Generating and Saving Images to ./images/epoch1023_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 24 Summary
# Epoch time duration : 35.810954093933105
# generator Mean Gradients : 7.489386476920126
# discriminator Mean Gradients : 337.123027770488
# Mean Running Discriminator Loss : 0.13316650259363882
# Mean Running Generator Loss : 0.6062129844885931
# Generating and Saving Images to ./images/epoch1024_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 25 Summary
# Epoch time duration : 35.238866567611694
# generator Mean Gradients : 7.482220550732146
# discriminator Mean Gradients : 336.83664915421565
# Mean Running Discriminator Loss : 0.13308726848259272
# Mean Running Generator Loss : 0.6061441865581565
# Generating and Saving Images to ./images/epoch1025_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 26 Summary
# Epoch time duration : 35.202887535095215
# generator Mean Gradients : 7.476106887155196
# discriminator Mean Gradients : 336.9748232428619
# Mean Running Discriminator Loss : 0.1330891189874968
# Mean Running Generator Loss : 0.60609704606983
# Generating and Saving Images to ./images/epoch1026_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 27 Summary
# Epoch time duration : 36.30272817611694
# generator Mean Gradients : 7.469021166469112
# discriminator Mean Gradients : 336.6688145991123
# Mean Running Discriminator Loss : 0.13300033066756256
# Mean Running Generator Loss : 0.6060401402584331
# Generating and Saving Images to ./images/epoch1027_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 28 Summary
# Epoch time duration : 36.059630393981934
# generator Mean Gradients : 7.461940302844742
# discriminator Mean Gradients : 336.40931858130415
# Mean Running Discriminator Loss : 0.13290471527206232
# Mean Running Generator Loss : 0.6059566963743056
# Generating and Saving Images to ./images/epoch1028_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 29 Summary
# Epoch time duration : 35.513009786605835
# generator Mean Gradients : 7.4554770165767765
# discriminator Mean Gradients : 336.1767234313024
# Mean Running Discriminator Loss : 0.13280648702211506
# Mean Running Generator Loss : 0.6058499923299915
# Generating and Saving Images to ./images/epoch1029_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 30 Summary
# Epoch time duration : 35.06764531135559
# generator Mean Gradients : 7.448730023141022
# discriminator Mean Gradients : 335.89174531272903
# Mean Running Discriminator Loss : 0.13269888591809645
# Mean Running Generator Loss : 0.605771836640259
# Generating and Saving Images to ./images/epoch1030_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 31 Summary
# Epoch time duration : 35.61808156967163
# generator Mean Gradients : 7.441554392657678
# discriminator Mean Gradients : 335.5926326474889
# Mean Running Discriminator Loss : 0.13258014042315477
# Mean Running Generator Loss : 0.6056825165970162
# Generating and Saving Images to ./images/epoch1031_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 32 Summary
# Epoch time duration : 35.41454267501831
# generator Mean Gradients : 7.434709761717029
# discriminator Mean Gradients : 335.31134513818483
# Mean Running Discriminator Loss : 0.13246456262626904
# Mean Running Generator Loss : 0.605604341370956
# Generating and Saving Images to ./images/epoch1032_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 33 Summary
# Epoch time duration : 35.496488094329834
# generator Mean Gradients : 7.427664316091223
# discriminator Mean Gradients : 335.01833069632374
# Mean Running Discriminator Loss : 0.1323507371799667
# Mean Running Generator Loss : 0.6055090105592021
# Generating and Saving Images to ./images/epoch1033_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 34 Summary
# Epoch time duration : 37.39056849479675
# generator Mean Gradients : 7.420879363307794
# discriminator Mean Gradients : 334.7626327252712
# Mean Running Discriminator Loss : 0.13224731202426906
# Mean Running Generator Loss : 0.6054273051960931
# Generating and Saving Images to ./images/epoch1034_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 35 Summary
# Epoch time duration : 35.07881760597229
# generator Mean Gradients : 7.413975018110607
# discriminator Mean Gradients : 334.5182586995009
# Mean Running Discriminator Loss : 0.1321392557192886
# Mean Running Generator Loss : 0.6053309916244181
# Generating and Saving Images to ./images/epoch1035_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 36 Summary
# Epoch time duration : 37.43901491165161
# generator Mean Gradients : 7.407304554330921
# discriminator Mean Gradients : 334.372195468429
# Mean Running Discriminator Loss : 0.13208101949440793
# Mean Running Generator Loss : 0.6052582839874255
# Generating and Saving Images to ./images/epoch1036_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 37 Summary
# Epoch time duration : 35.31265568733215
# generator Mean Gradients : 7.400459565867512
# discriminator Mean Gradients : 334.12287396281454
# Mean Running Discriminator Loss : 0.13198043388951516
# Mean Running Generator Loss : 0.605203496644286
# Generating and Saving Images to ./images/epoch1037_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 38 Summary
# Epoch time duration : 36.741438150405884
# generator Mean Gradients : 7.393407473944019
# discriminator Mean Gradients : 333.82203498326226
# Mean Running Discriminator Loss : 0.1318786519823299
# Mean Running Generator Loss : 0.6051541724922369
# Generating and Saving Images to ./images/epoch1038_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 39 Summary
# Epoch time duration : 35.40638041496277
# generator Mean Gradients : 7.387060929199634
# discriminator Mean Gradients : 333.5332398241601
# Mean Running Discriminator Loss : 0.1317744818113272
# Mean Running Generator Loss : 0.6050757012411565
# Generating and Saving Images to ./images/epoch1039_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 40 Summary
# Epoch time duration : 35.33442974090576
# generator Mean Gradients : 7.380151124847406
# discriminator Mean Gradients : 333.2480978151471
# Mean Running Discriminator Loss : 0.13166556909390448
# Mean Running Generator Loss : 0.6050138742179395
# Generating and Saving Images to ./images/epoch1040_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 41 Summary
# Epoch time duration : 35.2263503074646
# generator Mean Gradients : 7.373102887645036
# discriminator Mean Gradients : 332.99793298380837
# Mean Running Discriminator Loss : 0.13156279837888218
# Mean Running Generator Loss : 0.6049343409691289
# Generating and Saving Images to ./images/epoch1041_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 42 Summary
# Epoch time duration : 35.22485566139221
# generator Mean Gradients : 7.366142240711077
# discriminator Mean Gradients : 333.0408488291157
# Mean Running Discriminator Loss : 0.13149161538116558
# Mean Running Generator Loss : 0.6048532398203084
# Generating and Saving Images to ./images/epoch1042_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 43 Summary
# Epoch time duration : 35.066816568374634
# generator Mean Gradients : 7.359600950137142
# discriminator Mean Gradients : 332.7727227153097
# Mean Running Discriminator Loss : 0.13147493389825546
# Mean Running Generator Loss : 0.6048067049109953
# Generating and Saving Images to ./images/epoch1043_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 44 Summary
# Epoch time duration : 35.29804539680481
# generator Mean Gradients : 7.352756241189988
# discriminator Mean Gradients : 332.5936982642681
# Mean Running Discriminator Loss : 0.13139099291026443
# Mean Running Generator Loss : 0.6047211022944086
# Generating and Saving Images to ./images/epoch1044_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 45 Summary
# Epoch time duration : 35.232664346694946
# generator Mean Gradients : 7.345938942735398
# discriminator Mean Gradients : 332.3900368396775
# Mean Running Discriminator Loss : 0.13129853608658199
# Mean Running Generator Loss : 0.604644338496065
# Generating and Saving Images to ./images/epoch1045_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 46 Summary
# Epoch time duration : 35.00346565246582
# generator Mean Gradients : 7.33913408644685
# discriminator Mean Gradients : 332.2951302800463
# Mean Running Discriminator Loss : 0.1312720171493869
# Mean Running Generator Loss : 0.6045205955256496
# Generating and Saving Images to ./images/epoch1046_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 47 Summary
# Epoch time duration : 35.592238903045654
# generator Mean Gradients : 7.33226087302291
# discriminator Mean Gradients : 332.03649477641346
# Mean Running Discriminator Loss : 0.131283676945869
# Mean Running Generator Loss : 0.6044660954262061
# Generating and Saving Images to ./images/epoch1047_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 48 Summary
# Epoch time duration : 36.02408766746521
# generator Mean Gradients : 7.333128224551318
# discriminator Mean Gradients : 331.7432040597035
# Mean Running Discriminator Loss : 0.13120118658555333
# Mean Running Generator Loss : 0.6043195343871409
# Generating and Saving Images to ./images/epoch1048_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 49 Summary
# Epoch time duration : 35.128445625305176
# generator Mean Gradients : 7.340224853018326
# discriminator Mean Gradients : 331.6125922623007
# Mean Running Discriminator Loss : 0.1311234794098203
# Mean Running Generator Loss : 0.6041573976478171
# Generating and Saving Images to ./images/epoch1049_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 50 Summary
# Epoch time duration : 35.32914733886719
# generator Mean Gradients : 7.354375808797131
# discriminator Mean Gradients : 333.29754558053554
# Mean Running Discriminator Loss : 0.13215181683883115
# Mean Running Generator Loss : 0.6064438424161858
# Generating and Saving Images to ./images/epoch1050_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 51 Summary
# Epoch time duration : 35.096399784088135
# generator Mean Gradients : 7.4188598013608145
# discriminator Mean Gradients : 333.5723018211296
# Mean Running Discriminator Loss : 0.13251864651226253
# Mean Running Generator Loss : 0.6074141147355953
# Generating and Saving Images to ./images/epoch1051_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 52 Summary
# Epoch time duration : 36.007686614990234
# generator Mean Gradients : 7.415345692952146
# discriminator Mean Gradients : 333.52511388512573
# Mean Running Discriminator Loss : 0.13275697806296993
# Mean Running Generator Loss : 0.6079719887396583
# Generating and Saving Images to ./images/epoch1052_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 53 Summary
# Epoch time duration : 35.35809564590454
# generator Mean Gradients : 7.4097369226915255
# discriminator Mean Gradients : 333.3989427804682
# Mean Running Discriminator Loss : 0.13282824046795935
# Mean Running Generator Loss : 0.607971008482291
# Generating and Saving Images to ./images/epoch1053_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 54 Summary
# Epoch time duration : 35.13619136810303
# generator Mean Gradients : 7.405592422611818
# discriminator Mean Gradients : 333.1363159389805
# Mean Running Discriminator Loss : 0.13285181732907708
# Mean Running Generator Loss : 0.6082036219744023
# Generating and Saving Images to ./images/epoch1054_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 55 Summary
# Epoch time duration : 35.21588945388794
# generator Mean Gradients : 7.400557508043913
# discriminator Mean Gradients : 332.87462904567667
# Mean Running Discriminator Loss : 0.1328191211343946
# Mean Running Generator Loss : 0.6081810307808185
# Generating and Saving Images to ./images/epoch1055_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 56 Summary
# Epoch time duration : 35.036153078079224
# generator Mean Gradients : 7.398063480537024
# discriminator Mean Gradients : 332.60554709936855
# Mean Running Discriminator Loss : 0.13274795779365045
# Mean Running Generator Loss : 0.6084628724854679
# Generating and Saving Images to ./images/epoch1056_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 57 Summary
# Epoch time duration : 35.642502307891846
# generator Mean Gradients : 7.391373912469117
# discriminator Mean Gradients : 332.3728426897286
# Mean Running Discriminator Loss : 0.1326654824151705
# Mean Running Generator Loss : 0.6084911783455802
# Generating and Saving Images to ./images/epoch1057_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 58 Summary
# Epoch time duration : 35.24297618865967
# generator Mean Gradients : 7.385016845425661
# discriminator Mean Gradients : 332.1172818207291
# Mean Running Discriminator Loss : 0.1325766630834413
# Mean Running Generator Loss : 0.6084730262984301
# Generating and Saving Images to ./images/epoch1058_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 59 Summary
# Epoch time duration : 35.15590214729309
# generator Mean Gradients : 7.378201796536314
# discriminator Mean Gradients : 331.8870857073089
# Mean Running Discriminator Loss : 0.13248707335364254
# Mean Running Generator Loss : 0.6084278297880568
# Generating and Saving Images to ./images/epoch1059_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 60 Summary
# Epoch time duration : 35.413267850875854
# generator Mean Gradients : 7.371430815108905
# discriminator Mean Gradients : 331.61110150030925
# Mean Running Discriminator Loss : 0.13238456889504857
# Mean Running Generator Loss : 0.6083472229478846
# Generating and Saving Images to ./images/epoch1060_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 61 Summary
# Epoch time duration : 35.03988599777222
# generator Mean Gradients : 7.364993848347031
# discriminator Mean Gradients : 331.3265278362598
# Mean Running Discriminator Loss : 0.1322865646851379
# Mean Running Generator Loss : 0.6082638440544837
# Generating and Saving Images to ./images/epoch1061_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 62 Summary
# Epoch time duration : 35.38220024108887
# generator Mean Gradients : 7.35869349827617
# discriminator Mean Gradients : 331.04973147040175
# Mean Running Discriminator Loss : 0.1321966799396233
# Mean Running Generator Loss : 0.6081840267620644
# Generating and Saving Images to ./images/epoch1062_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 63 Summary
# Epoch time duration : 35.72246742248535
# generator Mean Gradients : 7.353362707255183
# discriminator Mean Gradients : 330.7820521919152
# Mean Running Discriminator Loss : 0.1320894792063669
# Mean Running Generator Loss : 0.6080960630888674
# Generating and Saving Images to ./images/epoch1063_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 64 Summary
# Epoch time duration : 34.958261013031006
# generator Mean Gradients : 7.351929717752052
# discriminator Mean Gradients : 330.4808860870492
# Mean Running Discriminator Loss : 0.13199802049523424
# Mean Running Generator Loss : 0.6082489026327008
# Generating and Saving Images to ./images/epoch1064_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 65 Summary
# Epoch time duration : 35.74749231338501
# generator Mean Gradients : 7.345210227627979
# discriminator Mean Gradients : 330.2105713836503
# Mean Running Discriminator Loss : 0.13189593806667166
# Mean Running Generator Loss : 0.6082219441950392
# Generating and Saving Images to ./images/epoch1065_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 66 Summary
# Epoch time duration : 35.93588829040527
# generator Mean Gradients : 7.338439421526845
# discriminator Mean Gradients : 330.09060963265216
# Mean Running Discriminator Loss : 0.13181885522900552
# Mean Running Generator Loss : 0.6081656642742176
# Generating and Saving Images to ./images/epoch1066_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 67 Summary
# Epoch time duration : 45.194191217422485
# generator Mean Gradients : 7.33176954882198
# discriminator Mean Gradients : 329.8183278850343
# Mean Running Discriminator Loss : 0.13173650297138365
# Mean Running Generator Loss : 0.608129331348909
# Generating and Saving Images to ./images/epoch1067_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 68 Summary
# Epoch time duration : 36.39913630485535
# generator Mean Gradients : 7.325143102199746
# discriminator Mean Gradients : 329.60775254413625
# Mean Running Discriminator Loss : 0.13164394847489064
# Mean Running Generator Loss : 0.6080733997623474
# Generating and Saving Images to ./images/epoch1068_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 69 Summary
# Epoch time duration : 46.088444232940674
# generator Mean Gradients : 7.318443914016067
# discriminator Mean Gradients : 329.4680701990629
# Mean Running Discriminator Loss : 0.13159545196593375
# Mean Running Generator Loss : 0.6080284865879714
# Generating and Saving Images to ./images/epoch1069_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 70 Summary
# Epoch time duration : 45.8767728805542
# generator Mean Gradients : 7.31339137026704
# discriminator Mean Gradients : 329.3171692337868
# Mean Running Discriminator Loss : 0.13152227568854666
# Mean Running Generator Loss : 0.607898477827869
# Generating and Saving Images to ./images/epoch1070_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 71 Summary
# Epoch time duration : 45.01090693473816
# generator Mean Gradients : 7.308289998322549
# discriminator Mean Gradients : 329.0484406183672
# Mean Running Discriminator Loss : 0.1314658784611567
# Mean Running Generator Loss : 0.607823680047151
# Generating and Saving Images to ./images/epoch1071_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 72 Summary
# Epoch time duration : 36.6474506855011
# generator Mean Gradients : 7.301715250946371
# discriminator Mean Gradients : 328.75248776019185
# Mean Running Discriminator Loss : 0.13136337612817062
# Mean Running Generator Loss : 0.6077424604245879
# Generating and Saving Images to ./images/epoch1072_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 73 Summary
# Epoch time duration : 36.53251004219055
# generator Mean Gradients : 7.295456764795361
# discriminator Mean Gradients : 328.4530478698573
# Mean Running Discriminator Loss : 0.13125672329577182
# Mean Running Generator Loss : 0.6076495590848017
# Generating and Saving Images to ./images/epoch1073_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 74 Summary
# Epoch time duration : 36.27841091156006
# generator Mean Gradients : 7.290740022369354
# discriminator Mean Gradients : 328.1938365498498
# Mean Running Discriminator Loss : 0.13115320074625852
# Mean Running Generator Loss : 0.6075519280693732
# Generating and Saving Images to ./images/epoch1074_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 75 Summary
# Epoch time duration : 37.18172359466553
# generator Mean Gradients : 7.307836153602468
# discriminator Mean Gradients : 327.928762619976
# Mean Running Discriminator Loss : 0.1310426334116803
# Mean Running Generator Loss : 0.6074828360532952
# Generating and Saving Images to ./images/epoch1075_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 76 Summary
# Epoch time duration : 37.27351713180542
# generator Mean Gradients : 7.301177363872448
# discriminator Mean Gradients : 327.6305710994298
# Mean Running Discriminator Loss : 0.13093693722862806
# Mean Running Generator Loss : 0.607421327203159
# Generating and Saving Images to ./images/epoch1076_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 77 Summary
# Epoch time duration : 37.02768158912659
# generator Mean Gradients : 7.2945391110632745
# discriminator Mean Gradients : 327.3802164570356
# Mean Running Discriminator Loss : 0.1308294920851334
# Mean Running Generator Loss : 0.607347867353028
# Generating and Saving Images to ./images/epoch1077_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 78 Summary
# Epoch time duration : 37.17499113082886
# generator Mean Gradients : 7.287882032984267
# discriminator Mean Gradients : 327.24151744784024
# Mean Running Discriminator Loss : 0.13074949018053317
# Mean Running Generator Loss : 0.6072780845318757
# Generating and Saving Images to ./images/epoch1078_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 79 Summary
# Epoch time duration : 37.05726456642151
# generator Mean Gradients : 7.2815326004669005
# discriminator Mean Gradients : 327.1895525075271
# Mean Running Discriminator Loss : 0.13075527028513828
# Mean Running Generator Loss : 0.6071669158428231
# Generating and Saving Images to ./images/epoch1079_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 80 Summary
# Epoch time duration : 36.95950174331665
# generator Mean Gradients : 7.275032908574269
# discriminator Mean Gradients : 327.03186710931965
# Mean Running Discriminator Loss : 0.13072731963389
# Mean Running Generator Loss : 0.607089556506145
# Generating and Saving Images to ./images/epoch1080_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 81 Summary
# Epoch time duration : 36.891947984695435
# generator Mean Gradients : 7.269121102407398
# discriminator Mean Gradients : 326.84840174610935
# Mean Running Discriminator Loss : 0.1306505594465013
# Mean Running Generator Loss : 0.6070022754152335
# Generating and Saving Images to ./images/epoch1081_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 82 Summary
# Epoch time duration : 38.50369381904602
# generator Mean Gradients : 7.262663121632287
# discriminator Mean Gradients : 326.5852759579256
# Mean Running Discriminator Loss : 0.13057169270363436
# Mean Running Generator Loss : 0.6069515656736678
# Generating and Saving Images to ./images/epoch1082_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 83 Summary
# Epoch time duration : 43.844053745269775
# generator Mean Gradients : 7.256040511667602
# discriminator Mean Gradients : 326.3634373794227
# Mean Running Discriminator Loss : 0.130485238443109
# Mean Running Generator Loss : 0.6068813754245639
# Generating and Saving Images to ./images/epoch1083_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 84 Summary
# Epoch time duration : 43.23387789726257
# generator Mean Gradients : 7.249583910961686
# discriminator Mean Gradients : 326.21249910228624
# Mean Running Discriminator Loss : 0.1304301737871698
# Mean Running Generator Loss : 0.606807960596836
# Generating and Saving Images to ./images/epoch1084_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 85 Summary
# Epoch time duration : 43.765735149383545
# generator Mean Gradients : 7.243830560177274
# discriminator Mean Gradients : 325.9261101558644
# Mean Running Discriminator Loss : 0.1303240494538648
# Mean Running Generator Loss : 0.6066992086894845
# Generating and Saving Images to ./images/epoch1085_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 86 Summary
# Epoch time duration : 43.831156730651855
# generator Mean Gradients : 7.239760238221856
# discriminator Mean Gradients : 326.00208174644405
# Mean Running Discriminator Loss : 0.13034077091691382
# Mean Running Generator Loss : 0.606621549961296
# Generating and Saving Images to ./images/epoch1086_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 87 Summary
# Epoch time duration : 43.240474462509155
# generator Mean Gradients : 7.70841825184195
# discriminator Mean Gradients : 325.9531001764094
# Mean Running Discriminator Loss : 0.1305529248824458
# Mean Running Generator Loss : 0.607213158480028
# Generating and Saving Images to ./images/epoch1087_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 88 Summary
# Epoch time duration : 42.71619272232056
# generator Mean Gradients : 7.7014461093263655
# discriminator Mean Gradients : 325.74158173977884
# Mean Running Discriminator Loss : 0.13061906836040127
# Mean Running Generator Loss : 0.607176703210023
# Generating and Saving Images to ./images/epoch1088_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 89 Summary
# Epoch time duration : 39.65354633331299
# generator Mean Gradients : 7.694455019600797
# discriminator Mean Gradients : 325.51103132858873
# Mean Running Discriminator Loss : 0.1305793551514327
# Mean Running Generator Loss : 0.6070943186812178
# Generating and Saving Images to ./images/epoch1089_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 90 Summary
# Epoch time duration : 37.59808611869812
# generator Mean Gradients : 7.68743211513939
# discriminator Mean Gradients : 325.4209265417457
# Mean Running Discriminator Loss : 0.13050331112014454
# Mean Running Generator Loss : 0.6070354685059176
# Generating and Saving Images to ./images/epoch1090_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 91 Summary
# Epoch time duration : 37.44964385032654
# generator Mean Gradients : 7.680429614259942
# discriminator Mean Gradients : 325.1617612660383
# Mean Running Discriminator Loss : 0.1304737901345824
# Mean Running Generator Loss : 0.607023787215236
# Generating and Saving Images to ./images/epoch1091_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 92 Summary
# Epoch time duration : 37.344810962677
# generator Mean Gradients : 7.673454539811691
# discriminator Mean Gradients : 325.03037305948203
# Mean Running Discriminator Loss : 0.1304124525774632
# Mean Running Generator Loss : 0.6069767055325141
# Generating and Saving Images to ./images/epoch1092_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 93 Summary
# Epoch time duration : 38.420530796051025
# generator Mean Gradients : 7.666489069567116
# discriminator Mean Gradients : 324.7418578704609
# Mean Running Discriminator Loss : 0.13031727036892385
# Mean Running Generator Loss : 0.6069699398438767
# Generating and Saving Images to ./images/epoch1093_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 94 Summary
# Epoch time duration : 37.205323696136475
# generator Mean Gradients : 7.659527548490441
# discriminator Mean Gradients : 324.47742601800286
# Mean Running Discriminator Loss : 0.1302201707144668
# Mean Running Generator Loss : 0.6069224163748569
# Generating and Saving Images to ./images/epoch1094_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 95 Summary
# Epoch time duration : 37.33339858055115
# generator Mean Gradients : 7.652570103280532
# discriminator Mean Gradients : 324.19013319297034
# Mean Running Discriminator Loss : 0.13010813273568148
# Mean Running Generator Loss : 0.6068458438540498
# Generating and Saving Images to ./images/epoch1095_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 96 Summary
# Epoch time duration : 37.474724531173706
# generator Mean Gradients : 7.645752615316234
# discriminator Mean Gradients : 323.967076487648
# Mean Running Discriminator Loss : 0.13001842173311373
# Mean Running Generator Loss : 0.6067758207387856
# Generating and Saving Images to ./images/epoch1096_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 97 Summary
# Epoch time duration : 36.97013187408447
# generator Mean Gradients : 7.638847989374211
# discriminator Mean Gradients : 324.03976929903604
# Mean Running Discriminator Loss : 0.1300133024598111
# Mean Running Generator Loss : 0.6067849109560564
# Generating and Saving Images to ./images/epoch1097_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 98 Summary
# Epoch time duration : 36.25511884689331
# generator Mean Gradients : 7.631936933708747
# discriminator Mean Gradients : 323.8095583738711
# Mean Running Discriminator Loss : 0.1299361045386868
# Mean Running Generator Loss : 0.6067514794264566
# Generating and Saving Images to ./images/epoch1098_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 99 Summary
# Epoch time duration : 35.25841689109802
# generator Mean Gradients : 7.625054062889942
# discriminator Mean Gradients : 323.53209280840724
# Mean Running Discriminator Loss : 0.129862229087351
# Mean Running Generator Loss : 0.6067123640340509
# Generating and Saving Images to ./images/epoch1099_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 100 Summary
# Epoch time duration : 35.086631536483765
# generator Mean Gradients : 7.618217191244943
# discriminator Mean Gradients : 323.28989190274484
# Mean Running Discriminator Loss : 0.129777242830129
# Mean Running Generator Loss : 0.6066564740113576
# Generating and Saving Images to ./images/epoch1100_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 101 Summary
# Epoch time duration : 35.008872509002686
# generator Mean Gradients : 7.611373434576029
# discriminator Mean Gradients : 323.0176622071844
# Mean Running Discriminator Loss : 0.12967010313005514
# Mean Running Generator Loss : 0.6065821173007885
# Generating and Saving Images to ./images/epoch1101_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 102 Summary
# Epoch time duration : 34.970181465148926
# generator Mean Gradients : 7.605212813941666
# discriminator Mean Gradients : 322.7434983560645
# Mean Running Discriminator Loss : 0.12958262020947256
# Mean Running Generator Loss : 0.606495956875918
# Generating and Saving Images to ./images/epoch1102_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 103 Summary
# Epoch time duration : 34.81994891166687
# generator Mean Gradients : 7.598602860287336
# discriminator Mean Gradients : 322.57254148487795
# Mean Running Discriminator Loss : 0.12950982676208075
# Mean Running Generator Loss : 0.6064369395343167
# Generating and Saving Images to ./images/epoch1103_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 104 Summary
# Epoch time duration : 35.00273060798645
# generator Mean Gradients : 7.5917894728618505
# discriminator Mean Gradients : 322.2944915690657
# Mean Running Discriminator Loss : 0.12940783022255029
# Mean Running Generator Loss : 0.6063843803974611
# Generating and Saving Images to ./images/epoch1104_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 105 Summary
# Epoch time duration : 35.28574085235596
# generator Mean Gradients : 7.584994873823909
# discriminator Mean Gradients : 322.01413094702826
# Mean Running Discriminator Loss : 0.1292986734021177
# Mean Running Generator Loss : 0.6063032682133813
# Generating and Saving Images to ./images/epoch1105_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 106 Summary
# Epoch time duration : 34.9008412361145
# generator Mean Gradients : 7.578284018393925
# discriminator Mean Gradients : 321.8034636295375
# Mean Running Discriminator Loss : 0.1291947652164562
# Mean Running Generator Loss : 0.6062149258295098
# Generating and Saving Images to ./images/epoch1106_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 107 Summary
# Epoch time duration : 35.16225481033325
# generator Mean Gradients : 7.57153732279313
# discriminator Mean Gradients : 321.53934119042447
# Mean Running Discriminator Loss : 0.12909698133990372
# Mean Running Generator Loss : 0.6061594582691977
# Generating and Saving Images to ./images/epoch1107_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 108 Summary
# Epoch time duration : 35.06643486022949
# generator Mean Gradients : 7.565414904937414
# discriminator Mean Gradients : 321.335437859849
# Mean Running Discriminator Loss : 0.12903238289118726
# Mean Running Generator Loss : 0.6060573231934869
# Generating and Saving Images to ./images/epoch1108_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 109 Summary
# Epoch time duration : 35.13427996635437
# generator Mean Gradients : 7.559403205504998
# discriminator Mean Gradients : 321.05571840738463
# Mean Running Discriminator Loss : 0.12892310571933638
# Mean Running Generator Loss : 0.6059267877452444
# Generating and Saving Images to ./images/epoch1109_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 110 Summary
# Epoch time duration : 35.37604522705078
# generator Mean Gradients : 7.553042814126151
# discriminator Mean Gradients : 320.842318358027
# Mean Running Discriminator Loss : 0.1288378967837481
# Mean Running Generator Loss : 0.6058379061058633
# Generating and Saving Images to ./images/epoch1110_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 111 Summary
# Epoch time duration : 35.04931902885437
# generator Mean Gradients : 7.546595077521753
# discriminator Mean Gradients : 320.60379174341125
# Mean Running Discriminator Loss : 0.12873621367982277
# Mean Running Generator Loss : 0.6057524964101042
# Generating and Saving Images to ./images/epoch1111_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 112 Summary
# Epoch time duration : 34.857994079589844
# generator Mean Gradients : 7.540070546058049
# discriminator Mean Gradients : 320.3877161208412
# Mean Running Discriminator Loss : 0.1286402222755484
# Mean Running Generator Loss : 0.6056708027382562
# Generating and Saving Images to ./images/epoch1112_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 113 Summary
# Epoch time duration : 34.90208554267883
# generator Mean Gradients : 7.5335396401358095
# discriminator Mean Gradients : 320.26523057033467
# Mean Running Discriminator Loss : 0.12856787641297168
# Mean Running Generator Loss : 0.6055787867755167
# Generating and Saving Images to ./images/epoch1113_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 114 Summary
# Epoch time duration : 34.71602201461792
# generator Mean Gradients : 7.52685821509729
# discriminator Mean Gradients : 320.00538090196756
# Mean Running Discriminator Loss : 0.12850153357109484
# Mean Running Generator Loss : 0.6055351417098709
# Generating and Saving Images to ./images/epoch1114_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 115 Summary
# Epoch time duration : 34.75045156478882
# generator Mean Gradients : 7.520219185520164
# discriminator Mean Gradients : 319.764492103819
# Mean Running Discriminator Loss : 0.12840262072405156
# Mean Running Generator Loss : 0.6054609338005361
# Generating and Saving Images to ./images/epoch1115_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 116 Summary
# Epoch time duration : 35.2642080783844
# generator Mean Gradients : 7.513669878750637
# discriminator Mean Gradients : 319.4899606108261
# Mean Running Discriminator Loss : 0.12829563429082183
# Mean Running Generator Loss : 0.6053744905693357
# Generating and Saving Images to ./images/epoch1116_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 117 Summary
# Epoch time duration : 35.271517276763916
# generator Mean Gradients : 7.5070092601069724
# discriminator Mean Gradients : 319.3352534960624
# Mean Running Discriminator Loss : 0.12820189145813474
# Mean Running Generator Loss : 0.6052966656683608
# Generating and Saving Images to ./images/epoch1117_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 118 Summary
# Epoch time duration : 35.149577140808105
# generator Mean Gradients : 7.500605673579881
# discriminator Mean Gradients : 319.06718218891757
# Mean Running Discriminator Loss : 0.1281074472051822
# Mean Running Generator Loss : 0.6052390709527716
# Generating and Saving Images to ./images/epoch1118_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 119 Summary
# Epoch time duration : 34.995662689208984
# generator Mean Gradients : 7.494657374542741
# discriminator Mean Gradients : 318.8053949579429
# Mean Running Discriminator Loss : 0.12800605280956934
# Mean Running Generator Loss : 0.6051516490493226
# Generating and Saving Images to ./images/epoch1119_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 120 Summary
# Epoch time duration : 34.919352293014526
# generator Mean Gradients : 7.488239156434885
# discriminator Mean Gradients : 318.58415966659453
# Mean Running Discriminator Loss : 0.1279329095583567
# Mean Running Generator Loss : 0.6050519290321972
# Generating and Saving Images to ./images/epoch1120_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 121 Summary
# Epoch time duration : 35.8094744682312
# generator Mean Gradients : 7.482211841777156
# discriminator Mean Gradients : 318.5842371136313
# Mean Running Discriminator Loss : 0.12788817772164485
# Mean Running Generator Loss : 0.604922432057812
# Generating and Saving Images to ./images/epoch1121_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 122 Summary
# Epoch time duration : 34.76150465011597
# generator Mean Gradients : 7.475867646864395
# discriminator Mean Gradients : 318.33751729834944
# Mean Running Discriminator Loss : 0.12785331714961018
# Mean Running Generator Loss : 0.6049379915365893
# Generating and Saving Images to ./images/epoch1122_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 123 Summary
# Epoch time duration : 35.01541304588318
# generator Mean Gradients : 7.469290444062195
# discriminator Mean Gradients : 318.08271199231046
# Mean Running Discriminator Loss : 0.12776758453573614
# Mean Running Generator Loss : 0.6048952953919822
# Generating and Saving Images to ./images/epoch1123_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 124 Summary
# Epoch time duration : 34.94839262962341
# generator Mean Gradients : 7.462777730611844
# discriminator Mean Gradients : 317.94775700861095
# Mean Running Discriminator Loss : 0.12770258375056986
# Mean Running Generator Loss : 0.6048263477839304
# Generating and Saving Images to ./images/epoch1124_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 125 Summary
# Epoch time duration : 35.02415156364441
# generator Mean Gradients : 7.4563015009545826
# discriminator Mean Gradients : 317.78612745152805
# Mean Running Discriminator Loss : 0.1276358693058913
# Mean Running Generator Loss : 0.6047605680566694
# Generating and Saving Images to ./images/epoch1125_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 126 Summary
# Epoch time duration : 35.03084921836853
# generator Mean Gradients : 7.44976248235004
# discriminator Mean Gradients : 317.52557054693085
# Mean Running Discriminator Loss : 0.12753710582561636
# Mean Running Generator Loss : 0.604710763337696
# Generating and Saving Images to ./images/epoch1126_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 127 Summary
# Epoch time duration : 34.97684597969055
# generator Mean Gradients : 7.44327207760128
# discriminator Mean Gradients : 317.3090149819742
# Mean Running Discriminator Loss : 0.12744083230872494
# Mean Running Generator Loss : 0.6046425991938734
# Generating and Saving Images to ./images/epoch1127_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 128 Summary
# Epoch time duration : 35.06716871261597
# generator Mean Gradients : 7.436764529889699
# discriminator Mean Gradients : 317.1794528481208
# Mean Running Discriminator Loss : 0.12738301303513852
# Mean Running Generator Loss : 0.6045858043300464
# Generating and Saving Images to ./images/epoch1128_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 129 Summary
# Epoch time duration : 35.259329319000244
# generator Mean Gradients : 7.430213266805691
# discriminator Mean Gradients : 316.9156444049046
# Mean Running Discriminator Loss : 0.12727762875023427
# Mean Running Generator Loss : 0.6045081954724935
# Generating and Saving Images to ./images/epoch1129_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 130 Summary
# Epoch time duration : 34.91789245605469
# generator Mean Gradients : 7.423824964178002
# discriminator Mean Gradients : 316.6445911741254
# Mean Running Discriminator Loss : 0.1271711507374297
# Mean Running Generator Loss : 0.6044274485950251
# Generating and Saving Images to ./images/epoch1130_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 131 Summary
# Epoch time duration : 34.948588848114014
# generator Mean Gradients : 7.417442616995893
# discriminator Mean Gradients : 316.3748808139995
# Mean Running Discriminator Loss : 0.1270635214119686
# Mean Running Generator Loss : 0.6043445571448414
# Generating and Saving Images to ./images/epoch1131_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 132 Summary
# Epoch time duration : 36.4169647693634
# generator Mean Gradients : 7.41102455827824
# discriminator Mean Gradients : 316.11132590994015
# Mean Running Discriminator Loss : 0.12695751710450967
# Mean Running Generator Loss : 0.6042703280411331
# Generating and Saving Images to ./images/epoch1132_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 133 Summary
# Epoch time duration : 36.01889085769653
# generator Mean Gradients : 7.4046915234199
# discriminator Mean Gradients : 315.95166756783686
# Mean Running Discriminator Loss : 0.1268667778208201
# Mean Running Generator Loss : 0.6041899311700664
# Generating and Saving Images to ./images/epoch1133_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 134 Summary
# Epoch time duration : 34.893269777297974
# generator Mean Gradients : 7.398273907874769
# discriminator Mean Gradients : 315.7058828940727
# Mean Running Discriminator Loss : 0.1267985169664091
# Mean Running Generator Loss : 0.6041457010030654
# Generating and Saving Images to ./images/epoch1134_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 135 Summary
# Epoch time duration : 34.83954620361328
# ...
# Mean Running Discriminator Loss : 0.11674293122220507
# Mean Running Generator Loss : 0.5536461653624012
# Generating and Saving Images to ./images/epoch1956_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 957 Summary
# Epoch time duration : 37.847005128860474
# generator Mean Gradients : 4.987632830831509
# discriminator Mean Gradients : 213.30621758034985
# Mean Running Discriminator Loss : 0.11669590557648434
# Mean Running Generator Loss : 0.5536231255157831
# Generating and Saving Images to ./images/epoch1957_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 958 Summary
# Epoch time duration : 37.980114459991455
# generator Mean Gradients : 4.985511486700455
# discriminator Mean Gradients : 213.2114239604766
# Mean Running Discriminator Loss : 0.11665652788363576
# Mean Running Generator Loss : 0.5535985724810241
# Generating and Saving Images to ./images/epoch1958_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 959 Summary
# Epoch time duration : 37.33460998535156
# generator Mean Gradients : 4.983465530772411
# discriminator Mean Gradients : 213.10763738080922
# Mean Running Discriminator Loss : 0.1166214557972391
# Mean Running Generator Loss : 0.5535596180212793
# Generating and Saving Images to ./images/epoch1959_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 960 Summary
# Epoch time duration : 36.06624889373779
# generator Mean Gradients : 4.981658149342914
# discriminator Mean Gradients : 213.01199156973902
# Mean Running Discriminator Loss : 0.11657949552921179
# Mean Running Generator Loss : 0.5535195187408933
# Generating and Saving Images to ./images/epoch1960_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 961 Summary
# Epoch time duration : 37.64166808128357
# generator Mean Gradients : 4.979709142074684
# discriminator Mean Gradients : 212.91513659450058
# Mean Running Discriminator Loss : 0.11655448747346199
# Mean Running Generator Loss : 0.5534790537554214
# Generating and Saving Images to ./images/epoch1961_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 962 Summary
# Epoch time duration : 37.30908226966858
# generator Mean Gradients : 4.97780165617623
# discriminator Mean Gradients : 212.85439986453832
# Mean Running Discriminator Loss : 0.11653733378379234
# Mean Running Generator Loss : 0.5534505333920426
# Generating and Saving Images to ./images/epoch1962_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 963 Summary
# Epoch time duration : 36.063902378082275
# generator Mean Gradients : 4.975821304472873
# discriminator Mean Gradients : 212.7640320564336
# Mean Running Discriminator Loss : 0.11650768630892148
# Mean Running Generator Loss : 0.5534147174788855
# Generating and Saving Images to ./images/epoch1963_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 964 Summary
# Epoch time duration : 35.9841787815094
# generator Mean Gradients : 4.974098993786305
# discriminator Mean Gradients : 212.66124238802476
# Mean Running Discriminator Loss : 0.11647025836229062
# Mean Running Generator Loss : 0.5533798505445893
# Generating and Saving Images to ./images/epoch1964_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 965 Summary
# Epoch time duration : 35.911524295806885
# generator Mean Gradients : 4.972397465518992
# discriminator Mean Gradients : 212.57094213868038
# Mean Running Discriminator Loss : 0.11644194290011116
# Mean Running Generator Loss : 0.5533388452097281
# Generating and Saving Images to ./images/epoch1965_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 966 Summary
# Epoch time duration : 36.623393297195435
# generator Mean Gradients : 4.970438551467162
# discriminator Mean Gradients : 212.47291846833502
# Mean Running Discriminator Loss : 0.11640876604304275
# Mean Running Generator Loss : 0.55331215266108
# Generating and Saving Images to ./images/epoch1966_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 967 Summary
# Epoch time duration : 36.365729331970215
# generator Mean Gradients : 4.968428764221164
# discriminator Mean Gradients : 212.37044589359962
# Mean Running Discriminator Loss : 0.11638182046776803
# Mean Running Generator Loss : 0.5532853783425048
# Generating and Saving Images to ./images/epoch1967_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 968 Summary
# Epoch time duration : 36.25347304344177
# generator Mean Gradients : 4.966538994066684
# discriminator Mean Gradients : 212.27115607230698
# Mean Running Discriminator Loss : 0.11636392257355695
# Mean Running Generator Loss : 0.5532407441575883
# Generating and Saving Images to ./images/epoch1968_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 969 Summary
# Epoch time duration : 36.53627896308899
# generator Mean Gradients : 4.965247469229201
# discriminator Mean Gradients : 212.1736085850134
# Mean Running Discriminator Loss : 0.11632583392564058
# Mean Running Generator Loss : 0.5531987763398293
# Generating and Saving Images to ./images/epoch1969_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 970 Summary
# Epoch time duration : 36.26207900047302
# generator Mean Gradients : 4.963526384788482
# discriminator Mean Gradients : 212.08444631810104
# Mean Running Discriminator Loss : 0.1163215846869253
# Mean Running Generator Loss : 0.5531661582051725
# Generating and Saving Images to ./images/epoch1970_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 971 Summary
# Epoch time duration : 36.297035455703735
# generator Mean Gradients : 4.961895142199489
# discriminator Mean Gradients : 212.0018218382205
# Mean Running Discriminator Loss : 0.11631850775896857
# Mean Running Generator Loss : 0.5531450784677769
# Generating and Saving Images to ./images/epoch1971_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 972 Summary
# Epoch time duration : 37.452150106430054
# generator Mean Gradients : 4.960087993504278
# discriminator Mean Gradients : 211.90661769321395
# Mean Running Discriminator Loss : 0.11629227216841471
# Mean Running Generator Loss : 0.5531319943200004
# Generating and Saving Images to ./images/epoch1972_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 973 Summary
# Epoch time duration : 36.26461744308472
# generator Mean Gradients : 4.958218361744577
# discriminator Mean Gradients : 211.9764879820991
# Mean Running Discriminator Loss : 0.11635007375359886
# Mean Running Generator Loss : 0.5531365929612323
# Generating and Saving Images to ./images/epoch1973_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 974 Summary
# Epoch time duration : 37.17900800704956
# generator Mean Gradients : 4.9561477131647615
# discriminator Mean Gradients : 211.87642237898413
# Mean Running Discriminator Loss : 0.11634271396165988
# Mean Running Generator Loss : 0.5531262931080861
# Generating and Saving Images to ./images/epoch1974_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 975 Summary
# Epoch time duration : 36.073970794677734
# generator Mean Gradients : 4.954065847640589
# discriminator Mean Gradients : 211.77402650800573
# Mean Running Discriminator Loss : 0.11630485592162401
# Mean Running Generator Loss : 0.553106866293127
# Generating and Saving Images to ./images/epoch1975_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 976 Summary
# Epoch time duration : 37.42756104469299
# generator Mean Gradients : 4.952527870046682
# discriminator Mean Gradients : 211.67319699624315
# Mean Running Discriminator Loss : 0.1162673853864933
# Mean Running Generator Loss : 0.5530643688377204
# Generating and Saving Images to ./images/epoch1976_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 977 Summary
# Epoch time duration : 38.82959842681885
# generator Mean Gradients : 4.9504595969243805
# discriminator Mean Gradients : 211.57830540567005
# Mean Running Discriminator Loss : 0.11623622784468773
# Mean Running Generator Loss : 0.5530521676206248
# Generating and Saving Images to ./images/epoch1977_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 978 Summary
# Epoch time duration : 36.06153130531311
# generator Mean Gradients : 4.948379032387343
# discriminator Mean Gradients : 211.47771502561898
# Mean Running Discriminator Loss : 0.11620532466003086
# Mean Running Generator Loss : 0.5530375240039159
# Generating and Saving Images to ./images/epoch1978_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 979 Summary
# Epoch time duration : 36.46950364112854
# generator Mean Gradients : 4.946442052194726
# discriminator Mean Gradients : 211.37833651911527
# Mean Running Discriminator Loss : 0.11616836795679841
# Mean Running Generator Loss : 0.5529959710280046
# Generating and Saving Images to ./images/epoch1979_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 980 Summary
# Epoch time duration : 35.799285650253296
# generator Mean Gradients : 4.944630494918015
# discriminator Mean Gradients : 211.3028631226888
# Mean Running Discriminator Loss : 0.11615639429932197
# Mean Running Generator Loss : 0.5529605099677363
# Generating and Saving Images to ./images/epoch1980_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 981 Summary
# Epoch time duration : 35.69981360435486
# generator Mean Gradients : 4.942614062221548
# discriminator Mean Gradients : 211.2063038288496
# Mean Running Discriminator Loss : 0.11612585960541359
# Mean Running Generator Loss : 0.5529476013598735
# Generating and Saving Images to ./images/epoch1981_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 982 Summary
# Epoch time duration : 35.91460871696472
# generator Mean Gradients : 4.940652276622153
# discriminator Mean Gradients : 211.11232494224333
# Mean Running Discriminator Loss : 0.11609387776908849
# Mean Running Generator Loss : 0.5529236182651278
# Generating and Saving Images to ./images/epoch1982_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 983 Summary
# Epoch time duration : 35.42588520050049
# generator Mean Gradients : 4.9387237729535
# discriminator Mean Gradients : 211.03131021179
# Mean Running Discriminator Loss : 0.11607007460823199
# Mean Running Generator Loss : 0.5528912339021371
# Generating and Saving Images to ./images/epoch1983_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 984 Summary
# Epoch time duration : 36.0285804271698
# generator Mean Gradients : 4.936939697136221
# discriminator Mean Gradients : 210.94198584386038
# Mean Running Discriminator Loss : 0.1160427250554588
# Mean Running Generator Loss : 0.5528591749053674
# Generating and Saving Images to ./images/epoch1984_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 985 Summary
# Epoch time duration : 35.79460167884827
# generator Mean Gradients : 4.935225915880608
# discriminator Mean Gradients : 210.8555347679117
# Mean Running Discriminator Loss : 0.11601531725477718
# Mean Running Generator Loss : 0.5528326507920507
# Generating and Saving Images to ./images/epoch1985_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 986 Summary
# Epoch time duration : 35.88486194610596
# generator Mean Gradients : 4.933454918700484
# discriminator Mean Gradients : 210.76967566861288
# Mean Running Discriminator Loss : 0.11599762223847117
# Mean Running Generator Loss : 0.5528577185730185
# Generating and Saving Images to ./images/epoch1986_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 987 Summary
# Epoch time duration : 35.81469917297363
# generator Mean Gradients : 4.931321262727544
# discriminator Mean Gradients : 210.67201831914363
# Mean Running Discriminator Loss : 0.11595878490105282
# Mean Running Generator Loss : 0.5528432053973628
# Generating and Saving Images to ./images/epoch1987_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 988 Summary
# Epoch time duration : 36.55014109611511
# generator Mean Gradients : 4.929356322890389
# discriminator Mean Gradients : 210.5708074747963
# Mean Running Discriminator Loss : 0.11591173618714751
# Mean Running Generator Loss : 0.5528256603407953
# Generating and Saving Images to ./images/epoch1988_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 989 Summary
# Epoch time duration : 35.672974824905396
# generator Mean Gradients : 4.927351138030638
# discriminator Mean Gradients : 210.46708653584042
# Mean Running Discriminator Loss : 0.1158652901578069
# Mean Running Generator Loss : 0.5527975065928644
# Generating and Saving Images to ./images/epoch1989_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 990 Summary
# Epoch time duration : 36.80795192718506
# generator Mean Gradients : 4.925544824602635
# discriminator Mean Gradients : 210.36850650025573
# Mean Running Discriminator Loss : 0.11582149600284876
# Mean Running Generator Loss : 0.5527645454250613
# Generating and Saving Images to ./images/epoch1990_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 991 Summary
# Epoch time duration : 36.114245653152466
# generator Mean Gradients : 4.923686704649117
# discriminator Mean Gradients : 210.2736459821321
# Mean Running Discriminator Loss : 0.11579844607159566
# Mean Running Generator Loss : 0.5527520546580172
# Generating and Saving Images to ./images/epoch1991_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 992 Summary
# Epoch time duration : 43.84683632850647
# generator Mean Gradients : 4.921943757567706
# discriminator Mean Gradients : 210.17773187745564
# Mean Running Discriminator Loss : 0.11576849931288122
# Mean Running Generator Loss : 0.55272435795527
# Generating and Saving Images to ./images/epoch1992_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 993 Summary
# Epoch time duration : 36.3392276763916
# generator Mean Gradients : 4.919801819910213
# discriminator Mean Gradients : 210.08144961694921
# Mean Running Discriminator Loss : 0.11573767181807391
# Mean Running Generator Loss : 0.5526932618055984
# Generating and Saving Images to ./images/epoch1993_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 994 Summary
# Epoch time duration : 43.04384422302246
# generator Mean Gradients : 4.917761796544867
# discriminator Mean Gradients : 209.98771758763698
# Mean Running Discriminator Loss : 0.1157048818953765
# Mean Running Generator Loss : 0.5526835762082021
# Generating and Saving Images to ./images/epoch1994_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 995 Summary
# Epoch time duration : 46.00666904449463
# generator Mean Gradients : 4.9158296367572225
# discriminator Mean Gradients : 209.91409559949128
# Mean Running Discriminator Loss : 0.11567979116053473
# Mean Running Generator Loss : 0.5526611174659846
# Generating and Saving Images to ./images/epoch1995_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 996 Summary
# Epoch time duration : 45.83837580680847
# generator Mean Gradients : 4.913769213536515
# discriminator Mean Gradients : 209.8143931853652
# Mean Running Discriminator Loss : 0.11564521499343015
# Mean Running Generator Loss : 0.5526423803101367
# Generating and Saving Images to ./images/epoch1996_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 997 Summary
# Epoch time duration : 38.144567012786865
# generator Mean Gradients : 4.911842381220049
# discriminator Mean Gradients : 209.7237625961975
# Mean Running Discriminator Loss : 0.11560665775565211
# Mean Running Generator Loss : 0.5526197123880842
# Generating and Saving Images to ./images/epoch1997_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 998 Summary
# Epoch time duration : 37.9670135974884
# generator Mean Gradients : 4.9096662262786905
# discriminator Mean Gradients : 209.62239692167168
# Mean Running Discriminator Loss : 0.11556448844807769
# Mean Running Generator Loss : 0.552606991046594
# Generating and Saving Images to ./images/epoch1998_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 999 Summary
# Epoch time duration : 36.827967405319214
# generator Mean Gradients : 4.907724387945513
# discriminator Mean Gradients : 209.54760520760817
# Mean Running Discriminator Loss : 0.1155551922802961
# Mean Running Generator Loss : 0.5525958962382571
# Generating and Saving Images to ./images/epoch1999_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 1000 Summary
# Epoch time duration : 35.74944806098938
# generator Mean Gradients : 4.905900084821179
# discriminator Mean Gradients : 209.48597372763012
# Mean Running Discriminator Loss : 0.11552405930589885
# Mean Running Generator Loss : 0.552571054409258
# Generating and Saving Images to ./images/epoch2000_generator.png
#
# Training of the Model is Complete

# %% [markdown]
# Use this cell instead of the previous one if you want to resume training a model that you saved from a previous session. Be sure to use the correct file path and file name when you call the function.

# %%
trainer.load_model("")
trainer(dataloader)
