# %% [markdown]
# This first cell makes sure that torchgan is installed. It's primarily here for use with colab, since colab doesn't have torchgan installed by default.

# %%
# from torchGAN tutorial

try:
    import torchgan

    print(f"Existing TorchGAN {torchgan.__version__} installation found")
except ImportError:
    import subprocess
    import sys

    subprocess.check_call([sys.executable, "-m", "pip", "install", "torchgan"])
    import torchgan

    print(f"Installed TorchGAN {torchgan.__version__}")
# Out:
# Existing TorchGAN v0.1.0 installation found

# %%
import torch
import torch.nn as nn
import torch.backends.cudnn
import torch.utils.data as tdata
from torch.optim import Adam
import torchvision
import torchvision.datasets as dsets
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import torchgan
from torchgan.models import *
from torchgan.losses import *
from torchgan.trainer import Trainer

# %% [markdown]
# This cell takes care of creating the dataset. Any PNG or JPEG image files are acceptable. The models require that the width and height of the images are equal, and that the dimensions of the image are a perfect power of 2, but those can both be overcome by scaling the images.
#
# The size variable is how big the generated images will be. Larger images can be more detailed, but dramatically slow down the training process. Additionally, as mentioned above, this value must be a perfect power of 2.
#
# If your images are in black and white, or if you wish to convert them to black and white, set grayscale to True in line 2.
#
# Due to the way that torchvision works, the file path provided in line 3 cannot be the exact folder that holds the images. In order for the path to be recognized properly, you must specify the folder that contains the folder with the images.
#
# For copyright reasons, the images that I am training from are not included with the GitHub repo. If you are interested in learning more, the citations for all of the images are included in the bibliography of the accompanying report.

# %%
size = 128
grayscale = False   # change this to True if your images are in black and white
folder = "./data/otherGANGogh/images/landscape/"

if grayscale:
    channels = 1
    data = ImageFolder(
        root=folder,
        transform=transforms.Compose([
            transforms.Resize((size, size)),
            transforms.ToTensor(),
            transforms.Grayscale(),
            transforms.Normalize(mean=.5, std=.5)
        ])
    )
else:
    channels = 3
    data = ImageFolder(
        root=folder,
        transform=transforms.Compose([
            transforms.Resize((size, size)),
            transforms.ToTensor(),
            transforms.Normalize(mean=.5, std=.5)
        ])
    )
print(len(data))
# Out:
# 15000

# %%
dataloader = tdata.DataLoader(data, batch_size=64, shuffle=True)

# %%
# adapted from torchgan tutorial

dcgan_network = {
    "generator": {
        "name": DCGANGenerator,
        "args": {
            "encoding_dims": 100,
            "out_size": size,           # this is how many pixels wide and tall the generated images will be
            "out_channels": channels,
            "step_channels": 32,
            "nonlinearity": nn.LeakyReLU(0.2),
            "last_nonlinearity": nn.Tanh(),
        },
        "optimizer": {"name": Adam, "args": {"lr": 0.0001, "betas": (0.5, 0.999)}},
    },
    "discriminator": {
        "name": DCGANDiscriminator,
        "args": {
            "in_size": size,            # this is how many pixels wide and tall we resized the images to be.
            "in_channels": channels,
            "step_channels": 32,
            "nonlinearity": nn.LeakyReLU(0.2),
            "last_nonlinearity": nn.LeakyReLU(0.2),
        },
        "optimizer": {"name": Adam, "args": {"lr": 0.0003, "betas": (0.5, 0.999)}},
    },
}

# %%
# from torchgan tutorial

minimax_losses = [MinimaxGeneratorLoss(), MinimaxDiscriminatorLoss()]
wgangp_losses = [
    WassersteinGeneratorLoss(),
    WassersteinDiscriminatorLoss(),
    WassersteinGradientPenalty(),
]
lsgan_losses = [LeastSquaresGeneratorLoss(), LeastSquaresDiscriminatorLoss()]

# %% [markdown]
# If you're running this on colab, be sure to select a GPU runtime for the best performance.

# %%
# more from torchgan tutorial

if torch.cuda.is_available():
    device = torch.device("cuda:0")
    # Use deterministic cudnn algorithms
    torch.backends.cudnn.deterministic = True
    epochs = 10
else:
    device = torch.device("cpu")
    epochs = 5

print("Device: {}".format(device))
print("Epochs: {}".format(epochs))
# Out:
# Device: cpu
# Epochs: 5

# %%
# from torchgan tutorial
epochs = 700    # you can override the number of epochs here if you want to try to get better results

trainer = Trainer(
    dcgan_network,
    lsgan_losses,
    sample_size=64,
    epochs=epochs,
    device=device
)

# %% [markdown]
# This is the cell that actually does the training. After it finishes, use the next cell if you want to keep training the same model.

# %%
trainer(dataloader)
# Out:
# c:\users\leafy\pycharmprojects\gangogh\venv\lib\site-packages\PIL\TiffImagePlugin.py:845: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# Saving Model at './model/gan0.model'
# Epoch 1 Summary
# Epoch time duration : 1003.3898904323578
# generator Mean Gradients : 36.18075446934572
# discriminator Mean Gradients : 367.2088514130637
# Mean Running Discriminator Loss : 0.36510538287619326
# Mean Running Generator Loss : 0.8458863792901343
# c:\users\leafy\pycharmprojects\gangogh\venv\lib\site-packages\torchvision\utils.py:68: UserWarning: The parameter 'range' is deprecated since 0.12 and will be removed in 0.14. Please use 'value_range' instead.
#   warnings.warn(
# Generating and Saving Images to ./images/epoch1_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 2 Summary
# Epoch time duration : 856.2223539352417
# generator Mean Gradients : 19.761261659166436
# discriminator Mean Gradients : 256.79356252814733
# Mean Running Discriminator Loss : 0.2177339577472749
# Mean Running Generator Loss : 0.7154120697937113
# Generating and Saving Images to ./images/epoch2_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 3 Summary
# Epoch time duration : 669.5286500453949
# generator Mean Gradients : 13.850664039708674
# discriminator Mean Gradients : 220.01047040482334
# Mean Running Discriminator Loss : 0.1688748215080787
# Mean Running Generator Loss : 0.6690223753663666
# Generating and Saving Images to ./images/epoch3_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 4 Summary
# Epoch time duration : 720.5223140716553
# generator Mean Gradients : 10.758290492662736
# discriminator Mean Gradients : 191.93496075266353
# Mean Running Discriminator Loss : 0.1394829614855785
# Mean Running Generator Loss : 0.6447378350540679
# Generating and Saving Images to ./images/epoch4_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 5 Summary
# Epoch time duration : 709.4125661849976
# generator Mean Gradients : 8.886492547201936
# discriminator Mean Gradients : 171.54267443770553
# Mean Running Discriminator Loss : 0.11929052387007531
# Mean Running Generator Loss : 0.6316478937103394
# Generating and Saving Images to ./images/epoch5_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 6 Summary
# Epoch time duration : 638.6733846664429
# generator Mean Gradients : 7.578489533742412
# discriminator Mean Gradients : 158.52084717295375
# Mean Running Discriminator Loss : 0.10537700273165915
# Mean Running Generator Loss : 0.620856658543678
# Generating and Saving Images to ./images/epoch6_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 7 Summary
# Epoch time duration : 638.7959151268005
# generator Mean Gradients : 6.622244679571095
# discriminator Mean Gradients : 147.2284286660172
# Mean Running Discriminator Loss : 0.09527790586203676
# Mean Running Generator Loss : 0.6126432205315419
# Generating and Saving Images to ./images/epoch7_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 8 Summary
# Epoch time duration : 641.0729598999023
# generator Mean Gradients : 5.885809913857862
# discriminator Mean Gradients : 136.60091991479382
# Mean Running Discriminator Loss : 0.0868942148810094
# Mean Running Generator Loss : 0.6052941916708616
# Generating and Saving Images to ./images/epoch8_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 9 Summary
# Epoch time duration : 640.4323379993439
# generator Mean Gradients : 5.2938261693440625
# discriminator Mean Gradients : 128.87989400914495
# Mean Running Discriminator Loss : 0.08042447085549558
# Mean Running Generator Loss : 0.5995297863057882
# Generating and Saving Images to ./images/epoch9_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 10 Summary
# Epoch time duration : 755.0260453224182
# generator Mean Gradients : 4.840512738693249
# discriminator Mean Gradients : 130.0406417869379
# Mean Running Discriminator Loss : 0.08051809779834002
# Mean Running Generator Loss : 0.5958385660990756
# Generating and Saving Images to ./images/epoch10_generator.png
#
# Training of the Model is Complete

# %% [markdown]
# Use this cell instead of the previous one if you want to resume training a model that you saved from a previous session. Be sure to use the correct file path and file name when you call the function.

# %%
model = "./model/gan4.model"

trainer.load_model(model)
trainer(dataloader)
# Out:
# Loading Model From './model/gan4.model' to cpu
# Saving Model at './model/gan0.model'
# Epoch 601 Summary
# Epoch time duration : 896.8301000595093
# generator Mean Gradients : 358.1461636051608
# discriminator Mean Gradients : 0.577842693512792
# Mean Running Discriminator Loss : 0.017121337555572182
# Mean Running Generator Loss : 0.5313584453214201
# Generating and Saving Images to ./images/epoch1_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 602 Summary
# Epoch time duration : 796.395012140274
# generator Mean Gradients : 336.4234823853853
# discriminator Mean Gradients : 0.5655728990364813
# Mean Running Discriminator Loss : 0.01710568771397569
# Mean Running Generator Loss : 0.5313479043554399
# Generating and Saving Images to ./images/epoch2_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 603 Summary
# Epoch time duration : 639.3975124359131
# generator Mean Gradients : 354.99015876436545
# discriminator Mean Gradients : 0.60791500271883
# Mean Running Discriminator Loss : 0.017091601979218503
# Mean Running Generator Loss : 0.5313550442056554
# Generating and Saving Images to ./images/epoch3_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 604 Summary
# Epoch time duration : 641.3607943058014
# generator Mean Gradients : 370.7022347370324
# discriminator Mean Gradients : 0.5960787955634109
# Mean Running Discriminator Loss : 0.01707681541813325
# Mean Running Generator Loss : 0.5313415072829989
# Generating and Saving Images to ./images/epoch4_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 605 Summary
# Epoch time duration : 696.9639866352081
# generator Mean Gradients : 361.4067070887463
# discriminator Mean Gradients : 0.6082970915960688
# Mean Running Discriminator Loss : 0.017062620844320905
# Mean Running Generator Loss : 0.5313381107637034
# Generating and Saving Images to ./images/epoch5_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 606 Summary
# Epoch time duration : 744.4385333061218
# generator Mean Gradients : 356.0625400284361
# discriminator Mean Gradients : 0.7089724982596388
# Mean Running Discriminator Loss : 0.01705355561275028
# Mean Running Generator Loss : 0.5313380651096976
# Generating and Saving Images to ./images/epoch6_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 607 Summary
# Epoch time duration : 735.739182472229
# generator Mean Gradients : 328.8242644262906
# discriminator Mean Gradients : 0.7134585947972266
# Mean Running Discriminator Loss : 0.017039238639526694
# Mean Running Generator Loss : 0.5313297618546526
# Generating and Saving Images to ./images/epoch7_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 608 Summary
# Epoch time duration : 716.6213438510895
# generator Mean Gradients : 321.3921242719696
# discriminator Mean Gradients : 0.6941548336211874
# Mean Running Discriminator Loss : 0.01702404795951907
# Mean Running Generator Loss : 0.5313179943501982
# Generating and Saving Images to ./images/epoch8_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 609 Summary
# Epoch time duration : 720.0142302513123
# generator Mean Gradients : 317.47354919338414
# discriminator Mean Gradients : 0.7109897751072743
# Mean Running Discriminator Loss : 0.017012063174577197
# Mean Running Generator Loss : 0.5313186580026624
# Generating and Saving Images to ./images/epoch9_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 610 Summary
# Epoch time duration : 735.7218973636627
# generator Mean Gradients : 315.88349420627503
# discriminator Mean Gradients : 0.6845994112384641
# Mean Running Discriminator Loss : 0.016996360708896707
# Mean Running Generator Loss : 0.5313175976954149
# Generating and Saving Images to ./images/epoch10_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 611 Summary
# Epoch time duration : 853.065411567688
# generator Mean Gradients : 303.69471773431025
# discriminator Mean Gradients : 0.6681111504201273
# Mean Running Discriminator Loss : 0.016980073465923205
# Mean Running Generator Loss : 0.5313040135588973
# Generating and Saving Images to ./images/epoch11_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 612 Summary
# Epoch time duration : 873.2887561321259
# generator Mean Gradients : 296.66314419535934
# discriminator Mean Gradients : 0.7035895985117638
# Mean Running Discriminator Loss : 0.016970658945752306
# Mean Running Generator Loss : 0.5313043355237226
# Generating and Saving Images to ./images/epoch12_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 613 Summary
# Epoch time duration : 679.199923992157
# generator Mean Gradients : 296.7171255720258
# discriminator Mean Gradients : 0.6896376066260297
# Mean Running Discriminator Loss : 0.01695521328309063
# Mean Running Generator Loss : 0.5312976525515967
# Generating and Saving Images to ./images/epoch13_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 614 Summary
# Epoch time duration : 689.0082890987396
# generator Mean Gradients : 293.2489506395124
# discriminator Mean Gradients : 0.6855669248155679
# Mean Running Discriminator Loss : 0.0169408286445401
# Mean Running Generator Loss : 0.5312909040028707
# Generating and Saving Images to ./images/epoch14_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 615 Summary
# Epoch time duration : 658.3298375606537
# generator Mean Gradients : 286.4864302879792
# discriminator Mean Gradients : 0.6874687650885424
# Mean Running Discriminator Loss : 0.016927433669007445
# Mean Running Generator Loss : 0.5312841653677445
# Generating and Saving Images to ./images/epoch15_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 616 Summary
# Epoch time duration : 793.5271353721619
# generator Mean Gradients : 282.14772016987774
# discriminator Mean Gradients : 0.7112517224933272
# Mean Running Discriminator Loss : 0.01691703752646854
# Mean Running Generator Loss : 0.531285613541998
# Generating and Saving Images to ./images/epoch16_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 617 Summary
# Epoch time duration : 688.1621911525726
# generator Mean Gradients : 274.68463260977563
# discriminator Mean Gradients : 0.7159305407392331
# Mean Running Discriminator Loss : 0.016905175599501863
# Mean Running Generator Loss : 0.5312823238220785
# Generating and Saving Images to ./images/epoch17_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 618 Summary
# Epoch time duration : 662.2759082317352
# generator Mean Gradients : 269.94141266257407
# discriminator Mean Gradients : 0.7084695966703239
# Mean Running Discriminator Loss : 0.0168908415152943
# Mean Running Generator Loss : 0.5312767742812564
# Generating and Saving Images to ./images/epoch18_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 619 Summary
# Epoch time duration : 671.7520291805267
# generator Mean Gradients : 268.43030100313325
# discriminator Mean Gradients : 0.7063906908354521
# Mean Running Discriminator Loss : 0.016878117870426618
# Mean Running Generator Loss : 0.5312695641059209
# Generating and Saving Images to ./images/epoch19_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 620 Summary
# Epoch time duration : 658.076798915863
# generator Mean Gradients : 265.7051059254437
# discriminator Mean Gradients : 0.7107790048926586
# Mean Running Discriminator Loss : 0.016866394078233402
# Mean Running Generator Loss : 0.5312669526978396
# Generating and Saving Images to ./images/epoch20_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 621 Summary
# Epoch time duration : 818.9376556873322
# generator Mean Gradients : 266.60414883512465
# discriminator Mean Gradients : 0.7127185557140876
# Mean Running Discriminator Loss : 0.01685394886188532
# Mean Running Generator Loss : 0.5312674419464619
# Generating and Saving Images to ./images/epoch21_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 622 Summary
# Epoch time duration : 904.2798421382904
# generator Mean Gradients : 265.16040670084334
# discriminator Mean Gradients : 0.7140042129862268
# Mean Running Discriminator Loss : 0.016841760799125003
# Mean Running Generator Loss : 0.5312665272084847
# Generating and Saving Images to ./images/epoch22_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 623 Summary
# Epoch time duration : 681.7909941673279
# generator Mean Gradients : 264.4255716699891
# discriminator Mean Gradients : 0.7159217763869078
# Mean Running Discriminator Loss : 0.01682950352886774
# Mean Running Generator Loss : 0.5312605623145527
# Generating and Saving Images to ./images/epoch23_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 624 Summary
# Epoch time duration : 682.8912882804871
# generator Mean Gradients : 262.9439785565167
# discriminator Mean Gradients : 0.7298522169343691
# Mean Running Discriminator Loss : 0.016819608597926652
# Mean Running Generator Loss : 0.5312595600102745
# Generating and Saving Images to ./images/epoch24_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 625 Summary
# Epoch time duration : 684.7438459396362
# generator Mean Gradients : 264.08166168148534
# discriminator Mean Gradients : 0.7219838342076271
# Mean Running Discriminator Loss : 0.016805112686420376
# Mean Running Generator Loss : 0.5312507937831067
# Generating and Saving Images to ./images/epoch25_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 626 Summary
# Epoch time duration : 785.7776782512665
# generator Mean Gradients : 263.123076818473
# discriminator Mean Gradients : 0.7192423750608608
# Mean Running Discriminator Loss : 0.016791787293579004
# Mean Running Generator Loss : 0.5312349821709491
# Generating and Saving Images to ./images/epoch26_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 627 Summary
# Epoch time duration : 695.5766105651855
# generator Mean Gradients : 259.6890126442233
# discriminator Mean Gradients : 0.7208376648213354
# Mean Running Discriminator Loss : 0.016778550698924737
# Mean Running Generator Loss : 0.5312316986467506
# Generating and Saving Images to ./images/epoch27_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 628 Summary
# Epoch time duration : 683.211786031723
# generator Mean Gradients : 257.2146889514575
# discriminator Mean Gradients : 0.7178387609103698
# Mean Running Discriminator Loss : 0.016765525089499852
# Mean Running Generator Loss : 0.5312219257852074
# Generating and Saving Images to ./images/epoch28_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 629 Summary
# Epoch time duration : 695.5548877716064
# generator Mean Gradients : 256.5554861649818
# discriminator Mean Gradients : 0.7130189141139035
# Mean Running Discriminator Loss : 0.016752528012237002
# Mean Running Generator Loss : 0.5312144245047477
# Generating and Saving Images to ./images/epoch29_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 630 Summary
# Epoch time duration : 702.1112344264984
# generator Mean Gradients : 256.3444607524584
# discriminator Mean Gradients : 0.7195736046785751
# Mean Running Discriminator Loss : 0.016741906849268608
# Mean Running Generator Loss : 0.5312114636316689
# Generating and Saving Images to ./images/epoch30_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 631 Summary
# Epoch time duration : 784.5788600444794
# generator Mean Gradients : 255.1007470113303
# discriminator Mean Gradients : 0.7136263375022395
# Mean Running Discriminator Loss : 0.01672773894326914
# Mean Running Generator Loss : 0.5312054615985938
# Generating and Saving Images to ./images/epoch31_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 632 Summary
# Epoch time duration : 857.7819745540619
# generator Mean Gradients : 255.16309672712362
# discriminator Mean Gradients : 0.7122205052211904
# Mean Running Discriminator Loss : 0.016715478060174222
# Mean Running Generator Loss : 0.5312006296400846
# Generating and Saving Images to ./images/epoch32_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 633 Summary
# Epoch time duration : 697.1688387393951
# generator Mean Gradients : 254.82307336960656
# discriminator Mean Gradients : 0.7137232139547385
# Mean Running Discriminator Loss : 0.016702681449638088
# Mean Running Generator Loss : 0.5311935686567467
# Generating and Saving Images to ./images/epoch33_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 634 Summary
# Epoch time duration : 695.6397242546082
# generator Mean Gradients : 256.213809612071
# discriminator Mean Gradients : 0.7171577655741188
# Mean Running Discriminator Loss : 0.01669108681947706
# Mean Running Generator Loss : 0.5311874061236806
# Generating and Saving Images to ./images/epoch34_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 635 Summary
# Epoch time duration : 702.326758146286
# generator Mean Gradients : 256.9880286109792
# discriminator Mean Gradients : 0.714652446708936
# Mean Running Discriminator Loss : 0.01667804464921268
# Mean Running Generator Loss : 0.5311819627177558
# Generating and Saving Images to ./images/epoch35_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 636 Summary
# Epoch time duration : 836.6082575321198
# generator Mean Gradients : 256.7562399862698
# discriminator Mean Gradients : 0.715982200551502
# Mean Running Discriminator Loss : 0.01666566394519729
# Mean Running Generator Loss : 0.5311784515600758
# Generating and Saving Images to ./images/epoch36_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 637 Summary
# Epoch time duration : 760.5658903121948
# generator Mean Gradients : 254.2328309598726
# discriminator Mean Gradients : 0.7171415639331863
# Mean Running Discriminator Loss : 0.016653785892997913
# Mean Running Generator Loss : 0.5311845041148755
# Generating and Saving Images to ./images/epoch37_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 638 Summary
# Epoch time duration : 646.7210505008698
# generator Mean Gradients : 254.26952561865534
# discriminator Mean Gradients : 0.7150496325514042
# Mean Running Discriminator Loss : 0.016640749544860372
# Mean Running Generator Loss : 0.5311758057828472
# Generating and Saving Images to ./images/epoch38_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 639 Summary
# Epoch time duration : 645.1383891105652
# generator Mean Gradients : 255.27454218054152
# discriminator Mean Gradients : 0.716603938834294
# Mean Running Discriminator Loss : 0.016628663070176526
# Mean Running Generator Loss : 0.531165783315122
# Generating and Saving Images to ./images/epoch39_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 640 Summary
# Epoch time duration : 644.3285138607025
# generator Mean Gradients : 256.33802206999474
# discriminator Mean Gradients : 0.7171161637350761
# Mean Running Discriminator Loss : 0.016616202950108537
# Mean Running Generator Loss : 0.5311589310583757
# Generating and Saving Images to ./images/epoch40_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 641 Summary
# Epoch time duration : 848.0612540245056
# generator Mean Gradients : 257.6630292360269
# discriminator Mean Gradients : 0.7178849938260504
# Mean Running Discriminator Loss : 0.016604278643256982
# Mean Running Generator Loss : 0.5311587850645179
# Generating and Saving Images to ./images/epoch41_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 642 Summary
# Epoch time duration : 848.4283974170685
# generator Mean Gradients : 260.12857172818025
# discriminator Mean Gradients : 0.7178742544399852
# Mean Running Discriminator Loss : 0.016591781770692333
# Mean Running Generator Loss : 0.5311526114764678
# Generating and Saving Images to ./images/epoch42_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 643 Summary
# Epoch time duration : 645.6811661720276
# generator Mean Gradients : 260.06708167081456
# discriminator Mean Gradients : 0.7165617393934365
# Mean Running Discriminator Loss : 0.016579543345699558
# Mean Running Generator Loss : 0.5311469628357176
# Generating and Saving Images to ./images/epoch43_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 644 Summary
# Epoch time duration : 642.963606595993
# generator Mean Gradients : 262.4371818577709
# discriminator Mean Gradients : 0.7136296711297023
# Mean Running Discriminator Loss : 0.01656649153649086
# Mean Running Generator Loss : 0.5311441099397948
# Generating and Saving Images to ./images/epoch44_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 645 Summary
# Epoch time duration : 645.2199647426605
# generator Mean Gradients : 263.07859450683424
# discriminator Mean Gradients : 0.7121811783348073
# Mean Running Discriminator Loss : 0.016553938537292305
# Mean Running Generator Loss : 0.5311427146940563
# Generating and Saving Images to ./images/epoch45_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 646 Summary
# Epoch time duration : 766.8678605556488
# generator Mean Gradients : 265.2028797003468
# discriminator Mean Gradients : 0.7079801505231789
# Mean Running Discriminator Loss : 0.016540681247954138
# Mean Running Generator Loss : 0.5311383048064482
# Generating and Saving Images to ./images/epoch46_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 647 Summary
# Epoch time duration : 700.3739228248596
# generator Mean Gradients : 265.27282216550515
# discriminator Mean Gradients : 0.7031823278097198
# Mean Running Discriminator Loss : 0.016525129793426848
# Mean Running Generator Loss : 0.5311271781648385
# Generating and Saving Images to ./images/epoch47_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 648 Summary
# Epoch time duration : 645.335813999176
# generator Mean Gradients : 267.101756450469
# discriminator Mean Gradients : 0.6995426845701427
# Mean Running Discriminator Loss : 0.016511427351130606
# Mean Running Generator Loss : 0.531121637389193
# Generating and Saving Images to ./images/epoch48_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 649 Summary
# Epoch time duration : 641.1164257526398
# generator Mean Gradients : 269.0967971712353
# discriminator Mean Gradients : 0.697138397547916
# Mean Running Discriminator Loss : 0.016497927702853375
# Mean Running Generator Loss : 0.5311206088667404
# Generating and Saving Images to ./images/epoch49_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 650 Summary
# Epoch time duration : 688.1097903251648
# generator Mean Gradients : 269.27429630841766
# discriminator Mean Gradients : 0.6957302936682191
# Mean Running Discriminator Loss : 0.016485033143918394
# Mean Running Generator Loss : 0.5311162290171203
# Generating and Saving Images to ./images/epoch50_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 651 Summary
# Epoch time duration : 728.8253645896912
# generator Mean Gradients : 269.2038733899744
# discriminator Mean Gradients : 0.6939457116235055
# Mean Running Discriminator Loss : 0.016471632676142524
# Mean Running Generator Loss : 0.5311092913554035
# Generating and Saving Images to ./images/epoch51_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 652 Summary
# Epoch time duration : 813.7605271339417
# generator Mean Gradients : 268.37924915109096
# discriminator Mean Gradients : 0.7020675308146179
# Mean Running Discriminator Loss : 0.01646223819997641
# Mean Running Generator Loss : 0.5311057952896778
# Generating and Saving Images to ./images/epoch52_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 653 Summary
# Epoch time duration : 643.311217546463
# generator Mean Gradients : 265.7138757370647
# discriminator Mean Gradients : 0.7038180554886322
# Mean Running Discriminator Loss : 0.016451829509860714
# Mean Running Generator Loss : 0.5310978191764134
# Generating and Saving Images to ./images/epoch53_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 654 Summary
# Epoch time duration : 642.5108261108398
# generator Mean Gradients : 265.4613113623567
# discriminator Mean Gradients : 0.7028959024632926
# Mean Running Discriminator Loss : 0.016440093444940993
# Mean Running Generator Loss : 0.5310961455527524
# Generating and Saving Images to ./images/epoch54_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 655 Summary
# Epoch time duration : 640.6562173366547
# generator Mean Gradients : 265.2673587157987
# discriminator Mean Gradients : 0.700896915579361
# Mean Running Discriminator Loss : 0.01642766930485398
# Mean Running Generator Loss : 0.5310900526200096
# Generating and Saving Images to ./images/epoch55_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 656 Summary
# Epoch time duration : 692.7704346179962
# generator Mean Gradients : 264.75489353383495
# discriminator Mean Gradients : 0.6984134170823708
# Mean Running Discriminator Loss : 0.016414421060287537
# Mean Running Generator Loss : 0.5310803206406484
# Generating and Saving Images to ./images/epoch56_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 657 Summary
# Epoch time duration : 887.391312122345
# generator Mean Gradients : 264.8628573725178
# discriminator Mean Gradients : 0.6960132934125154
# Mean Running Discriminator Loss : 0.016401722598111856
# Mean Running Generator Loss : 0.5310802914558589
# Generating and Saving Images to ./images/epoch57_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 658 Summary
# Epoch time duration : 670.8766903877258
# generator Mean Gradients : 265.823533900401
# discriminator Mean Gradients : 0.6958585646195595
# Mean Running Discriminator Loss : 0.01638981967744858
# Mean Running Generator Loss : 0.5310873254339569
# Generating and Saving Images to ./images/epoch58_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 659 Summary
# Epoch time duration : 644.2534656524658
# generator Mean Gradients : 265.8088219033804
# discriminator Mean Gradients : 0.6918659451089242
# Mean Running Discriminator Loss : 0.01637560634254795
# Mean Running Generator Loss : 0.5310925707348523
# Generating and Saving Images to ./images/epoch59_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 660 Summary
# Epoch time duration : 638.2599053382874
# generator Mean Gradients : 268.06333504995104
# discriminator Mean Gradients : 0.6912425020514211
# Mean Running Discriminator Loss : 0.016362735833619167
# Mean Running Generator Loss : 0.5310909955385114
# Generating and Saving Images to ./images/epoch60_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 661 Summary
# Epoch time duration : 643.6457939147949
# generator Mean Gradients : 265.21957040446154
# discriminator Mean Gradients : 0.6910152457927873
# Mean Running Discriminator Loss : 0.016348692291542826
# Mean Running Generator Loss : 0.5310837636180598
# Generating and Saving Images to ./images/epoch61_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 662 Summary
# Epoch time duration : 1105.7420072555542
# generator Mean Gradients : 264.8714200008529
# discriminator Mean Gradients : 0.6930884044656431
# Mean Running Discriminator Loss : 0.016337905358304622
# Mean Running Generator Loss : 0.5310825367597471
# Generating and Saving Images to ./images/epoch62_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 663 Summary
# Epoch time duration : 700.5693609714508
# generator Mean Gradients : 265.76688454953097
# discriminator Mean Gradients : 0.6921203638128705
# Mean Running Discriminator Loss : 0.016325810690240406
# Mean Running Generator Loss : 0.5310839057412458
# Generating and Saving Images to ./images/epoch63_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 664 Summary
# Epoch time duration : 644.3422386646271
# generator Mean Gradients : 265.8473151145809
# discriminator Mean Gradients : 0.6941895765726525
# Mean Running Discriminator Loss : 0.016314715233245153
# Mean Running Generator Loss : 0.5310808179026741
# Generating and Saving Images to ./images/epoch64_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 665 Summary
# Epoch time duration : 643.7471055984497
# generator Mean Gradients : 265.9934585009168
# discriminator Mean Gradients : 0.6932104362007433
# Mean Running Discriminator Loss : 0.01630199535443087
# Mean Running Generator Loss : 0.5310804572618975
# Generating and Saving Images to ./images/epoch65_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 666 Summary
# Epoch time duration : 704.9999270439148
# generator Mean Gradients : 265.60041310870713
# discriminator Mean Gradients : 0.6963592406723651
# Mean Running Discriminator Loss : 0.016291778613018226
# Mean Running Generator Loss : 0.5310771619858098
# Generating and Saving Images to ./images/epoch66_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 667 Summary
# Epoch time duration : 760.8139441013336
# generator Mean Gradients : 265.77648166785133
# discriminator Mean Gradients : 0.6943629977388246
# Mean Running Discriminator Loss : 0.016279025588538956
# Mean Running Generator Loss : 0.531077151192391
# Generating and Saving Images to ./images/epoch67_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 668 Summary
# Epoch time duration : 677.3841474056244
# generator Mean Gradients : 265.1229442998095
# discriminator Mean Gradients : 0.6931687807530428
# Mean Running Discriminator Loss : 0.016267145122680255
# Mean Running Generator Loss : 0.5310768806939292
# Generating and Saving Images to ./images/epoch68_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 669 Summary
# Epoch time duration : 650.0423526763916
# generator Mean Gradients : 264.5791491672094
# discriminator Mean Gradients : 0.6919201896281928
# Mean Running Discriminator Loss : 0.01625503998505414
# Mean Running Generator Loss : 0.5310801215311788
# Generating and Saving Images to ./images/epoch69_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 670 Summary
# Epoch time duration : 654.2116105556488
# generator Mean Gradients : 263.93502537983426
# discriminator Mean Gradients : 0.6869714358828363
# Mean Running Discriminator Loss : 0.01623956202294544
# Mean Running Generator Loss : 0.5310736508977417
# Generating and Saving Images to ./images/epoch70_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 671 Summary
# Epoch time duration : 642.8576939105988
# generator Mean Gradients : 265.20931329365027
# discriminator Mean Gradients : 0.6855398609309454
# Mean Running Discriminator Loss : 0.01622647148721333
# Mean Running Generator Loss : 0.5310707486665789
# Generating and Saving Images to ./images/epoch71_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 672 Summary
# Epoch time duration : 864.2861497402191
# generator Mean Gradients : 267.0148069924437
# discriminator Mean Gradients : 0.6830807144648849
# Mean Running Discriminator Loss : 0.01621381926732582
# Mean Running Generator Loss : 0.5310607668486063
# Generating and Saving Images to ./images/epoch72_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 673 Summary
# Epoch time duration : 684.338933467865
# generator Mean Gradients : 267.11827678838785
# discriminator Mean Gradients : 0.6791058091139504
# Mean Running Discriminator Loss : 0.016199019318101294
# Mean Running Generator Loss : 0.5310550943970971
# Generating and Saving Images to ./images/epoch73_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 674 Summary
# Epoch time duration : 660.4165604114532
# generator Mean Gradients : 266.85940422049185
# discriminator Mean Gradients : 0.6740701570728024
# Mean Running Discriminator Loss : 0.016182138646358906
# Mean Running Generator Loss : 0.5310401841777015
# Generating and Saving Images to ./images/epoch74_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 675 Summary
# Epoch time duration : 657.782577753067
# generator Mean Gradients : 265.45285151349043
# discriminator Mean Gradients : 0.681209873524718
# Mean Running Discriminator Loss : 0.01617333108402856
# Mean Running Generator Loss : 0.5310462912761668
# Generating and Saving Images to ./images/epoch75_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 676 Summary
# Epoch time duration : 645.8297870159149
# generator Mean Gradients : 264.17384153354044
# discriminator Mean Gradients : 0.6802566832229668
# Mean Running Discriminator Loss : 0.0161614647741977
# Mean Running Generator Loss : 0.5310467904771994
# Generating and Saving Images to ./images/epoch76_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 677 Summary
# Epoch time duration : 893.7532336711884
# generator Mean Gradients : 262.9501668195979
# discriminator Mean Gradients : 0.6816261751282401
# Mean Running Discriminator Loss : 0.016150428641093516
# Mean Running Generator Loss : 0.5310405436997486
# Generating and Saving Images to ./images/epoch77_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 678 Summary
# Epoch time duration : 790.316392660141
# generator Mean Gradients : 263.91896650671856
# discriminator Mean Gradients : 0.6832588847513822
# Mean Running Discriminator Loss : 0.0161397240953038
# Mean Running Generator Loss : 0.5310419106456524
# Generating and Saving Images to ./images/epoch78_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 679 Summary
# Epoch time duration : 642.6029334068298
# generator Mean Gradients : 264.7269157879396
# discriminator Mean Gradients : 0.682487047160965
# Mean Running Discriminator Loss : 0.01612733582774019
# Mean Running Generator Loss : 0.5310327583083169
# Generating and Saving Images to ./images/epoch79_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 680 Summary
# Epoch time duration : 642.2376828193665
# generator Mean Gradients : 265.0235909437421
# discriminator Mean Gradients : 0.6782868545962476
# Mean Running Discriminator Loss : 0.016112491052773476
# Mean Running Generator Loss : 0.53103014147028
# Generating and Saving Images to ./images/epoch80_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 681 Summary
# Epoch time duration : 644.7528038024902
# generator Mean Gradients : 266.1568233649887
# discriminator Mean Gradients : 0.6768364635557835
# Mean Running Discriminator Loss : 0.016100174905341203
# Mean Running Generator Loss : 0.5310300175902375
# Generating and Saving Images to ./images/epoch81_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 682 Summary
# Epoch time duration : 1104.0132057666779
# generator Mean Gradients : 266.9175129005118
# discriminator Mean Gradients : 0.6747846798978833
# Mean Running Discriminator Loss : 0.01608622746608036
# Mean Running Generator Loss : 0.5310185151298903
# Generating and Saving Images to ./images/epoch82_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 683 Summary
# Epoch time duration : 774.0485427379608
# generator Mean Gradients : 266.65174264451434
# discriminator Mean Gradients : 0.6767417771410483
# Mean Running Discriminator Loss : 0.016075154081098993
# Mean Running Generator Loss : 0.5310146627662033
# Generating and Saving Images to ./images/epoch83_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 684 Summary
# Epoch time duration : 644.0550196170807
# generator Mean Gradients : 267.7759289344042
# discriminator Mean Gradients : 0.676061761592087
# Mean Running Discriminator Loss : 0.01606314055488377
# Mean Running Generator Loss : 0.5310167993698026
# Generating and Saving Images to ./images/epoch84_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 685 Summary
# Epoch time duration : 647.3344724178314
# generator Mean Gradients : 268.20558027656585
# discriminator Mean Gradients : 0.6726964404325328
# Mean Running Discriminator Loss : 0.016048664582147935
# Mean Running Generator Loss : 0.5310098894076756
# Generating and Saving Images to ./images/epoch85_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 686 Summary
# Epoch time duration : 704.6482608318329
# generator Mean Gradients : 269.3321566340372
# discriminator Mean Gradients : 0.6709699403713477
# Mean Running Discriminator Loss : 0.016035806350280866
# Mean Running Generator Loss : 0.5310055080361036
# Generating and Saving Images to ./images/epoch86_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 687 Summary
# Epoch time duration : 792.4312686920166
# generator Mean Gradients : 268.49275370101765
# discriminator Mean Gradients : 0.6690290496985125
# Mean Running Discriminator Loss : 0.016021818109790482
# Mean Running Generator Loss : 0.530994408203894
# Generating and Saving Images to ./images/epoch87_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 688 Summary
# Epoch time duration : 664.4687347412109
# generator Mean Gradients : 269.41752436480346
# discriminator Mean Gradients : 0.6658012936080201
# Mean Running Discriminator Loss : 0.016007499514991926
# Mean Running Generator Loss : 0.530988751210453
# Generating and Saving Images to ./images/epoch88_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 689 Summary
# Epoch time duration : 639.3737711906433
# generator Mean Gradients : 269.16156289280843
# discriminator Mean Gradients : 0.6688096737344326
# Mean Running Discriminator Loss : 0.015996576079229517
# Mean Running Generator Loss : 0.5309752425532916
# Generating and Saving Images to ./images/epoch89_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 690 Summary
# Epoch time duration : 638.464747428894
# generator Mean Gradients : 269.76754726819166
# discriminator Mean Gradients : 0.6723824829820696
# Mean Running Discriminator Loss : 0.01598733866799794
# Mean Running Generator Loss : 0.5309754599464039
# Generating and Saving Images to ./images/epoch90_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 691 Summary
# Epoch time duration : 644.2636427879333
# generator Mean Gradients : 269.4414746943836
# discriminator Mean Gradients : 0.6696153713287232
# Mean Running Discriminator Loss : 0.01597293286879498
# Mean Running Generator Loss : 0.5309665145049832
# Generating and Saving Images to ./images/epoch91_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 692 Summary
# Epoch time duration : 868.6294875144958
# generator Mean Gradients : 269.63115351086435
# discriminator Mean Gradients : 0.6687143657415966
# Mean Running Discriminator Loss : 0.015960527442959022
# Mean Running Generator Loss : 0.5309657365675636
# Generating and Saving Images to ./images/epoch92_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 693 Summary
# Epoch time duration : 718.0660529136658
# generator Mean Gradients : 270.4834785885633
# discriminator Mean Gradients : 0.6683962984414024
# Mean Running Discriminator Loss : 0.015948682181819055
# Mean Running Generator Loss : 0.5309602019327214
# Generating and Saving Images to ./images/epoch93_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 694 Summary
# Epoch time duration : 637.3964624404907
# generator Mean Gradients : 270.44373809834434
# discriminator Mean Gradients : 0.6647764628055088
# Mean Running Discriminator Loss : 0.01593293786520775
# Mean Running Generator Loss : 0.5309478415596222
# Generating and Saving Images to ./images/epoch94_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 695 Summary
# Epoch time duration : 639.4387457370758
# generator Mean Gradients : 268.7947631600977
# discriminator Mean Gradients : 0.6598380359933326
# Mean Running Discriminator Loss : 0.01591531071881197
# Mean Running Generator Loss : 0.5309336470033972
# Generating and Saving Images to ./images/epoch95_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 696 Summary
# Epoch time duration : 645.7585470676422
# generator Mean Gradients : 268.7924231478334
# discriminator Mean Gradients : 0.6611984194482614
# Mean Running Discriminator Loss : 0.01590464375106578
# Mean Running Generator Loss : 0.5309283410522182
# Generating and Saving Images to ./images/epoch96_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 697 Summary
# Epoch time duration : 872.0956172943115
# generator Mean Gradients : 267.54804301817865
# discriminator Mean Gradients : 0.6615003100230546
# Mean Running Discriminator Loss : 0.015893835173738418
# Mean Running Generator Loss : 0.5309227399519612
# Generating and Saving Images to ./images/epoch97_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 698 Summary
# Epoch time duration : 849.638433933258
# generator Mean Gradients : 267.1887067010354
# discriminator Mean Gradients : 0.6605727417881128
# Mean Running Discriminator Loss : 0.015881739026501036
# Mean Running Generator Loss : 0.530927797595368
# Generating and Saving Images to ./images/epoch98_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 699 Summary
# Epoch time duration : 642.0784366130829
# generator Mean Gradients : 266.45300685186174
# discriminator Mean Gradients : 0.6585853541619544
# Mean Running Discriminator Loss : 0.015868563515736584
# Mean Running Generator Loss : 0.5309265405768779
# Generating and Saving Images to ./images/epoch99_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 700 Summary
# Epoch time duration : 641.5909388065338
# generator Mean Gradients : 265.50320012316394
# discriminator Mean Gradients : 0.6565728850795647
# Mean Running Discriminator Loss : 0.015855175407121443
# Mean Running Generator Loss : 0.530931719957967
# Generating and Saving Images to ./images/epoch100_generator.png
#
# Training of the Model is Complete
