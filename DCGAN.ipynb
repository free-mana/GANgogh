# %% [markdown]
# This first cell makes sure that torchgan is installed. It's primarily here for use with colab, since colab doesn't have torchgan installed by default.

# %%
# from torchGAN tutorial

try:
    import torchgan

    print(f"Existing TorchGAN {torchgan.__version__} installation found")
except ImportError:
    import subprocess
    import sys

    subprocess.check_call([sys.executable, "-m", "pip", "install", "torchgan"])
    import torchgan

    print(f"Installed TorchGAN {torchgan.__version__}")
# Out:
# Existing TorchGAN v0.1.0 installation found

# %%
import torch
import torch.nn as nn
import torch.backends.cudnn
import torch.utils.data as tdata
from torch.optim import Adam
import torchvision
import torchvision.datasets as dsets
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import torchgan
from torchgan.models import *
from torchgan.losses import *
from torchgan.trainer import Trainer

# %% [markdown]
# This cell takes care of creating the dataset. Any PNG or JPEG image files are acceptable. The models require that the width and height of the images are equal, and that the dimensions of the image are a perfect power of 2, but those can both be overcome by scaling the images.
#
# The size variable is how big the generated images will be. Larger images can be more detailed, but dramatically slow down the training process. Additionally, as mentioned above, this value must be a perfect power of 2.
#
# If your images are in black and white, or if you wish to convert them to black and white, set grayscale to True in line 2.
#
# Due to the way that torchvision works, the file path provided in line 3 cannot be the exact folder that holds the images. In order for the path to be recognized properly, you must specify the folder that contains the folder with the images.
#
# For copyright reasons, the images that I am training from are not included with the GitHub repo. If you are interested in learning more, the citations for all of the images are included in the bibliography of the accompanying report.

# %%
size = 128
grayscale = False   # change this to True if your images are in black and white
folder = "./data/otherGANGogh/images/landscape/"

if grayscale:
    channels = 1
    data = ImageFolder(
        root=folder,
        transform=transforms.Compose([
            transforms.Resize((size, size)),
            transforms.ToTensor(),
            transforms.Grayscale(),
            transforms.Normalize(mean=.5, std=.5)
        ])
    )
else:
    channels = 3
    data = ImageFolder(
        root=folder,
        transform=transforms.Compose([
            transforms.Resize((size, size)),
            transforms.ToTensor(),
            transforms.Normalize(mean=.5, std=.5)
        ])
    )
print(len(data))
# Out:
# 15000

# %%
dataloader = tdata.DataLoader(data, batch_size=64, shuffle=True)

# %%
# adapted from torchgan tutorial

dcgan_network = {
    "generator": {
        "name": DCGANGenerator,
        "args": {
            "encoding_dims": 100,
            "out_size": size,           # this is how many pixels wide and tall the generated images will be
            "out_channels": channels,
            "step_channels": 32,
            "nonlinearity": nn.LeakyReLU(0.2),
            "last_nonlinearity": nn.Tanh(),
        },
        "optimizer": {"name": Adam, "args": {"lr": 0.0001, "betas": (0.5, 0.999)}},
    },
    "discriminator": {
        "name": DCGANDiscriminator,
        "args": {
            "in_size": size,            # this is how many pixels wide and tall we resized the images to be.
            "in_channels": channels,
            "step_channels": 32,
            "nonlinearity": nn.LeakyReLU(0.2),
            "last_nonlinearity": nn.LeakyReLU(0.2),
        },
        "optimizer": {"name": Adam, "args": {"lr": 0.0003, "betas": (0.5, 0.999)}},
    },
}

# %%
# from torchgan tutorial

minimax_losses = [MinimaxGeneratorLoss(), MinimaxDiscriminatorLoss()]
wgangp_losses = [
    WassersteinGeneratorLoss(),
    WassersteinDiscriminatorLoss(),
    WassersteinGradientPenalty(),
]
lsgan_losses = [LeastSquaresGeneratorLoss(), LeastSquaresDiscriminatorLoss()]

# %% [markdown]
# If you're running this on colab, be sure to select a GPU runtime for the best performance.

# %%
# more from torchgan tutorial

if torch.cuda.is_available():
    device = torch.device("cuda:0")
    # Use deterministic cudnn algorithms
    torch.backends.cudnn.deterministic = True
    epochs = 10
else:
    device = torch.device("cpu")
    epochs = 5

print("Device: {}".format(device))
print("Epochs: {}".format(epochs))
# Out:
# Device: cpu
# Epochs: 5

# %%
# from torchgan tutorial
epochs = 600    # you can override the number of epochs here if you want to try to get better results

trainer = Trainer(
    dcgan_network,
    lsgan_losses,
    sample_size=64,
    epochs=epochs,
    device=device
)

# %% [markdown]
# This is the cell that actually does the training. After it finishes, use the next cell if you want to keep training the same model.

# %%
trainer(dataloader)
# Out:
# c:\users\leafy\pycharmprojects\gangogh\venv\lib\site-packages\PIL\TiffImagePlugin.py:845: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# Saving Model at './model/gan0.model'
# Epoch 1 Summary
# Epoch time duration : 1003.3898904323578
# generator Mean Gradients : 36.18075446934572
# discriminator Mean Gradients : 367.2088514130637
# Mean Running Discriminator Loss : 0.36510538287619326
# Mean Running Generator Loss : 0.8458863792901343
# c:\users\leafy\pycharmprojects\gangogh\venv\lib\site-packages\torchvision\utils.py:68: UserWarning: The parameter 'range' is deprecated since 0.12 and will be removed in 0.14. Please use 'value_range' instead.
#   warnings.warn(
# Generating and Saving Images to ./images/epoch1_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 2 Summary
# Epoch time duration : 856.2223539352417
# generator Mean Gradients : 19.761261659166436
# discriminator Mean Gradients : 256.79356252814733
# Mean Running Discriminator Loss : 0.2177339577472749
# Mean Running Generator Loss : 0.7154120697937113
# Generating and Saving Images to ./images/epoch2_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 3 Summary
# Epoch time duration : 669.5286500453949
# generator Mean Gradients : 13.850664039708674
# discriminator Mean Gradients : 220.01047040482334
# Mean Running Discriminator Loss : 0.1688748215080787
# Mean Running Generator Loss : 0.6690223753663666
# Generating and Saving Images to ./images/epoch3_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 4 Summary
# Epoch time duration : 720.5223140716553
# generator Mean Gradients : 10.758290492662736
# discriminator Mean Gradients : 191.93496075266353
# Mean Running Discriminator Loss : 0.1394829614855785
# Mean Running Generator Loss : 0.6447378350540679
# Generating and Saving Images to ./images/epoch4_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 5 Summary
# Epoch time duration : 709.4125661849976
# generator Mean Gradients : 8.886492547201936
# discriminator Mean Gradients : 171.54267443770553
# Mean Running Discriminator Loss : 0.11929052387007531
# Mean Running Generator Loss : 0.6316478937103394
# Generating and Saving Images to ./images/epoch5_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 6 Summary
# Epoch time duration : 638.6733846664429
# generator Mean Gradients : 7.578489533742412
# discriminator Mean Gradients : 158.52084717295375
# Mean Running Discriminator Loss : 0.10537700273165915
# Mean Running Generator Loss : 0.620856658543678
# Generating and Saving Images to ./images/epoch6_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 7 Summary
# Epoch time duration : 638.7959151268005
# generator Mean Gradients : 6.622244679571095
# discriminator Mean Gradients : 147.2284286660172
# Mean Running Discriminator Loss : 0.09527790586203676
# Mean Running Generator Loss : 0.6126432205315419
# Generating and Saving Images to ./images/epoch7_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 8 Summary
# Epoch time duration : 641.0729598999023
# generator Mean Gradients : 5.885809913857862
# discriminator Mean Gradients : 136.60091991479382
# Mean Running Discriminator Loss : 0.0868942148810094
# Mean Running Generator Loss : 0.6052941916708616
# Generating and Saving Images to ./images/epoch8_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 9 Summary
# Epoch time duration : 640.4323379993439
# generator Mean Gradients : 5.2938261693440625
# discriminator Mean Gradients : 128.87989400914495
# Mean Running Discriminator Loss : 0.08042447085549558
# Mean Running Generator Loss : 0.5995297863057882
# Generating and Saving Images to ./images/epoch9_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 10 Summary
# Epoch time duration : 755.0260453224182
# generator Mean Gradients : 4.840512738693249
# discriminator Mean Gradients : 130.0406417869379
# Mean Running Discriminator Loss : 0.08051809779834002
# Mean Running Generator Loss : 0.5958385660990756
# Generating and Saving Images to ./images/epoch10_generator.png
#
# Training of the Model is Complete

# %% [markdown]
# Use this cell instead of the previous one if you want to resume training a model that you saved from a previous session. Be sure to use the correct file path and file name when you call the function.

# %%
model = "./model/gan4.model"

trainer.load_model(model)
trainer(dataloader)
# Out:
# Loading Model From './model/gan4.model' to cpu
# Saving Model at './model/gan0.model'
# Epoch 401 Summary
# Epoch time duration : 1104.1352400779724
# generator Mean Gradients : 264.09970181668075
# discriminator Mean Gradients : 1.1998140013504839
# Mean Running Discriminator Loss : 0.020867900715737343
# Mean Running Generator Loss : 0.5324752453332533
# Generating and Saving Images to ./images/epoch1_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 402 Summary
# Epoch time duration : 643.661075592041
# generator Mean Gradients : 257.36827449619744
# discriminator Mean Gradients : 1.1339003481644934
# Mean Running Discriminator Loss : 0.020842049115519713
# Mean Running Generator Loss : 0.532455406356392
# Generating and Saving Images to ./images/epoch2_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 403 Summary
# Epoch time duration : 639.7084698677063
# generator Mean Gradients : 250.96846078040005
# discriminator Mean Gradients : 1.0391486872118436
# Mean Running Discriminator Loss : 0.020812675916907383
# Mean Running Generator Loss : 0.5324460237751393
# Generating and Saving Images to ./images/epoch3_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 404 Summary
# Epoch time duration : 637.8527438640594
# generator Mean Gradients : 235.827661738769
# discriminator Mean Gradients : 1.0306462269225287
# Mean Running Discriminator Loss : 0.02078491588788135
# Mean Running Generator Loss : 0.5324435868482368
# Generating and Saving Images to ./images/epoch4_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 405 Summary
# Epoch time duration : 1034.8349690437317
# generator Mean Gradients : 236.08064510528408
# discriminator Mean Gradients : 1.0539229324574222
# Mean Running Discriminator Loss : 0.020759148169548644
# Mean Running Generator Loss : 0.5324292328632392
# Generating and Saving Images to ./images/epoch5_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 406 Summary
# Epoch time duration : 697.1891317367554
# generator Mean Gradients : 231.48828089180995
# discriminator Mean Gradients : 1.0461021376354134
# Mean Running Discriminator Loss : 0.020731338244586513
# Mean Running Generator Loss : 0.5324139618156182
# Generating and Saving Images to ./images/epoch6_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 407 Summary
# Epoch time duration : 638.795090675354
# generator Mean Gradients : 224.4909420107826
# discriminator Mean Gradients : 1.0313607323445055
# Mean Running Discriminator Loss : 0.020702758835388312
# Mean Running Generator Loss : 0.5324010328461322
# Generating and Saving Images to ./images/epoch7_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 408 Summary
# Epoch time duration : 640.9480271339417
# generator Mean Gradients : 221.98715025277764
# discriminator Mean Gradients : 1.1190791269291174
# Mean Running Discriminator Loss : 0.020687515794908184
# Mean Running Generator Loss : 0.5324027571217559
# Generating and Saving Images to ./images/epoch8_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 409 Summary
# Epoch time duration : 638.0503714084625
# generator Mean Gradients : 234.8242790698128
# discriminator Mean Gradients : 1.081870173915559
# Mean Running Discriminator Loss : 0.020661632446442344
# Mean Running Generator Loss : 0.5323990970093034
# Generating and Saving Images to ./images/epoch9_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 410 Summary
# Epoch time duration : 785.6367037296295
# generator Mean Gradients : 240.2683597025843
# discriminator Mean Gradients : 1.0882493387315595
# Mean Running Discriminator Loss : 0.020636929804536543
# Mean Running Generator Loss : 0.5323769044168931
# Generating and Saving Images to ./images/epoch10_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 411 Summary
# Epoch time duration : 643.3042407035828
# generator Mean Gradients : 234.53295504111753
# discriminator Mean Gradients : 1.0957671734944985
# Mean Running Discriminator Loss : 0.020613675449256033
# Mean Running Generator Loss : 0.5323616409173937
# Generating and Saving Images to ./images/epoch11_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 412 Summary
# Epoch time duration : 676.9329061508179
# generator Mean Gradients : 232.64034046411385
# discriminator Mean Gradients : 1.1150662931196882
# Mean Running Discriminator Loss : 0.02059459516513245
# Mean Running Generator Loss : 0.5323623226506897
# Generating and Saving Images to ./images/epoch12_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 413 Summary
# Epoch time duration : 640.2012856006622
# generator Mean Gradients : 224.06830058681527
# discriminator Mean Gradients : 1.108039849093107
# Mean Running Discriminator Loss : 0.020570264599032162
# Mean Running Generator Loss : 0.5323604588783415
# Generating and Saving Images to ./images/epoch13_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 414 Summary
# Epoch time duration : 637.6583471298218
# generator Mean Gradients : 217.80191342318523
# discriminator Mean Gradients : 1.0934346944005422
# Mean Running Discriminator Loss : 0.020545508337237006
# Mean Running Generator Loss : 0.5323755506586151
# Generating and Saving Images to ./images/epoch14_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 415 Summary
# Epoch time duration : 837.9232635498047
# generator Mean Gradients : 215.4911352677655
# discriminator Mean Gradients : 1.0863351376944599
# Mean Running Discriminator Loss : 0.02052103606888046
# Mean Running Generator Loss : 0.5323700775183934
# Generating and Saving Images to ./images/epoch15_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 416 Summary
# Epoch time duration : 849.0835013389587
# generator Mean Gradients : 219.2465357919202
# discriminator Mean Gradients : 1.0607621291905382
# Mean Running Discriminator Loss : 0.020493322158743055
# Mean Running Generator Loss : 0.5323664642810599
# Generating and Saving Images to ./images/epoch16_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 417 Summary
# Epoch time duration : 638.1818675994873
# generator Mean Gradients : 216.60560761013568
# discriminator Mean Gradients : 1.055729295104634
# Mean Running Discriminator Loss : 0.020468957104054292
# Mean Running Generator Loss : 0.5323596655161879
# Generating and Saving Images to ./images/epoch17_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 418 Summary
# Epoch time duration : 631.8945226669312
# generator Mean Gradients : 216.7018112843153
# discriminator Mean Gradients : 1.046051734827575
# Mean Running Discriminator Loss : 0.020444350695326356
# Mean Running Generator Loss : 0.532354332482954
# Generating and Saving Images to ./images/epoch18_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 419 Summary
# Epoch time duration : 637.7542176246643
# generator Mean Gradients : 209.8731218702133
# discriminator Mean Gradients : 1.0478271194735826
# Mean Running Discriminator Loss : 0.020421088749815897
# Mean Running Generator Loss : 0.532356756802964
# Generating and Saving Images to ./images/epoch19_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 420 Summary
# Epoch time duration : 819.601348400116
# generator Mean Gradients : 211.7030077744999
# discriminator Mean Gradients : 1.0379853269145096
# Mean Running Discriminator Loss : 0.02039597648987122
# Mean Running Generator Loss : 0.5323545977681226
# Generating and Saving Images to ./images/epoch20_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 421 Summary
# Epoch time duration : 766.4693632125854
# generator Mean Gradients : 209.28698015834792
# discriminator Mean Gradients : 1.0153310560556104
# Mean Running Discriminator Loss : 0.02036570654386918
# Mean Running Generator Loss : 0.5323390948562396
# Generating and Saving Images to ./images/epoch21_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 422 Summary
# Epoch time duration : 639.0956344604492
# generator Mean Gradients : 203.5995207755921
# discriminator Mean Gradients : 1.013579338656417
# Mean Running Discriminator Loss : 0.020341071149129256
# Mean Running Generator Loss : 0.5323333787344628
# Generating and Saving Images to ./images/epoch22_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 423 Summary
# Epoch time duration : 640.3580305576324
# generator Mean Gradients : 199.39472169614376
# discriminator Mean Gradients : 1.0075114233530595
# Mean Running Discriminator Loss : 0.020315659482918226
# Mean Running Generator Loss : 0.5323286482548532
# Generating and Saving Images to ./images/epoch23_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 424 Summary
# Epoch time duration : 638.7780826091766
# generator Mean Gradients : 194.8229891260263
# discriminator Mean Gradients : 1.0145909404849598
# Mean Running Discriminator Loss : 0.020295565447672432
# Mean Running Generator Loss : 0.5323252089020644
# Generating and Saving Images to ./images/epoch24_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 425 Summary
# Epoch time duration : 717.2651062011719
# generator Mean Gradients : 192.2154882078962
# discriminator Mean Gradients : 1.020346507194701
# Mean Running Discriminator Loss : 0.020274769499962066
# Mean Running Generator Loss : 0.5323203754020349
# Generating and Saving Images to ./images/epoch25_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 426 Summary
# Epoch time duration : 1097.3408515453339
# generator Mean Gradients : 190.7524849423355
# discriminator Mean Gradients : 1.0198886519634376
# Mean Running Discriminator Loss : 0.02025217386818132
# Mean Running Generator Loss : 0.5323051948265549
# Generating and Saving Images to ./images/epoch26_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 427 Summary
# Epoch time duration : 638.5558519363403
# generator Mean Gradients : 186.69118952181114
# discriminator Mean Gradients : 1.037535225303981
# Mean Running Discriminator Loss : 0.020231702080466978
# Mean Running Generator Loss : 0.5323075860114685
# Generating and Saving Images to ./images/epoch27_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 428 Summary
# Epoch time duration : 638.4234819412231
# generator Mean Gradients : 183.66594643098261
# discriminator Mean Gradients : 1.0365224860628994
# Mean Running Discriminator Loss : 0.02020763996332845
# Mean Running Generator Loss : 0.5322974376442298
# Generating and Saving Images to ./images/epoch28_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 429 Summary
# Epoch time duration : 642.2210896015167
# generator Mean Gradients : 181.34255977628663
# discriminator Mean Gradients : 1.036684202335475
# Mean Running Discriminator Loss : 0.02018606460726618
# Mean Running Generator Loss : 0.5322929980884494
# Generating and Saving Images to ./images/epoch29_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 430 Summary
# Epoch time duration : 758.2826678752899
# generator Mean Gradients : 178.97725413825756
# discriminator Mean Gradients : 1.0398215810507772
# Mean Running Discriminator Loss : 0.02016501691533743
# Mean Running Generator Loss : 0.532290523365833
# Generating and Saving Images to ./images/epoch30_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 431 Summary
# Epoch time duration : 719.9089179039001
# generator Mean Gradients : 177.36673907271893
# discriminator Mean Gradients : 1.0372451083907428
# Mean Running Discriminator Loss : 0.02014196619416659
# Mean Running Generator Loss : 0.5322963192412002
# Generating and Saving Images to ./images/epoch31_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 432 Summary
# Epoch time duration : 634.6585664749146
# generator Mean Gradients : 176.35901369141177
# discriminator Mean Gradients : 1.0332366330702476
# Mean Running Discriminator Loss : 0.020118264489382396
# Mean Running Generator Loss : 0.5322861104233042
# Generating and Saving Images to ./images/epoch32_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 433 Summary
# Epoch time duration : 629.665896654129
# generator Mean Gradients : 174.89317084971046
# discriminator Mean Gradients : 1.0307057715038912
# Mean Running Discriminator Loss : 0.020095905686051272
# Mean Running Generator Loss : 0.5322914861270772
# Generating and Saving Images to ./images/epoch33_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 434 Summary
# Epoch time duration : 634.5438385009766
# generator Mean Gradients : 175.43544869442138
# discriminator Mean Gradients : 1.0262905796135509
# Mean Running Discriminator Loss : 0.02007292433549874
# Mean Running Generator Loss : 0.5322985180559852
# Generating and Saving Images to ./images/epoch34_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 435 Summary
# Epoch time duration : 634.5584106445312
# generator Mean Gradients : 176.4861678242895
# discriminator Mean Gradients : 1.0167969920415947
# Mean Running Discriminator Loss : 0.02004889456308694
# Mean Running Generator Loss : 0.5322936185353702
# Generating and Saving Images to ./images/epoch35_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 436 Summary
# Epoch time duration : 904.1879246234894
# generator Mean Gradients : 174.4392181944455
# discriminator Mean Gradients : 1.0254397498724035
# Mean Running Discriminator Loss : 0.02002988503920128
# Mean Running Generator Loss : 0.5322919585582624
# Generating and Saving Images to ./images/epoch36_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 437 Summary
# Epoch time duration : 710.4178218841553
# generator Mean Gradients : 173.4708733406894
# discriminator Mean Gradients : 1.0310054147627534
# Mean Running Discriminator Loss : 0.020008627564451414
# Mean Running Generator Loss : 0.532282283377011
# Generating and Saving Images to ./images/epoch37_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 438 Summary
# Epoch time duration : 635.7709698677063
# generator Mean Gradients : 172.49690056901318
# discriminator Mean Gradients : 1.0225991670738481
# Mean Running Discriminator Loss : 0.019982814667328177
# Mean Running Generator Loss : 0.5322698130527215
# Generating and Saving Images to ./images/epoch38_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 439 Summary
# Epoch time duration : 637.3849468231201
# generator Mean Gradients : 171.8085578627358
# discriminator Mean Gradients : 1.0225293096612886
# Mean Running Discriminator Loss : 0.019960776237998273
# Mean Running Generator Loss : 0.5322630588789461
# Generating and Saving Images to ./images/epoch39_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 440 Summary
# Epoch time duration : 635.8484570980072
# generator Mean Gradients : 171.0846374021682
# discriminator Mean Gradients : 1.0200242941824373
# Mean Running Discriminator Loss : 0.019936849616389817
# Mean Running Generator Loss : 0.5322658041946418
# Generating and Saving Images to ./images/epoch40_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 441 Summary
# Epoch time duration : 920.9286794662476
# generator Mean Gradients : 170.83958513747808
# discriminator Mean Gradients : 1.0238532875196724
# Mean Running Discriminator Loss : 0.019916729850018255
# Mean Running Generator Loss : 0.5322582313530038
# Generating and Saving Images to ./images/epoch41_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 442 Summary
# Epoch time duration : 690.6888191699982
# generator Mean Gradients : 170.64722732201122
# discriminator Mean Gradients : 1.0181403314709427
# Mean Running Discriminator Loss : 0.019892258339891167
# Mean Running Generator Loss : 0.5322574899844016
# Generating and Saving Images to ./images/epoch42_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 443 Summary
# Epoch time duration : 639.5692894458771
# generator Mean Gradients : 170.86510676178324
# discriminator Mean Gradients : 1.0106898636411736
# Mean Running Discriminator Loss : 0.019866521508245687
# Mean Running Generator Loss : 0.5322511774264814
# Generating and Saving Images to ./images/epoch43_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 444 Summary
# Epoch time duration : 636.5019657611847
# generator Mean Gradients : 172.28623891453964
# discriminator Mean Gradients : 1.0048090483664844
# Mean Running Discriminator Loss : 0.01984219850989321
# Mean Running Generator Loss : 0.5322390097943727
# Generating and Saving Images to ./images/epoch44_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 445 Summary
# Epoch time duration : 636.0958278179169
# generator Mean Gradients : 172.77015748419083
# discriminator Mean Gradients : 1.0025761038437735
# Mean Running Discriminator Loss : 0.0198184520698549
# Mean Running Generator Loss : 0.5322389313913819
# Generating and Saving Images to ./images/epoch45_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 446 Summary
# Epoch time duration : 1156.884176492691
# generator Mean Gradients : 173.79156247828905
# discriminator Mean Gradients : 0.9962526438879729
# Mean Running Discriminator Loss : 0.01979221996764562
# Mean Running Generator Loss : 0.5322311790682238
# Generating and Saving Images to ./images/epoch46_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 447 Summary
# Epoch time duration : 747.6337196826935
# generator Mean Gradients : 172.79905456436967
# discriminator Mean Gradients : 0.9952871624221591
# Mean Running Discriminator Loss : 0.019767697425278334
# Mean Running Generator Loss : 0.5322289257811478
# Generating and Saving Images to ./images/epoch47_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 448 Summary
# Epoch time duration : 638.3405857086182
# generator Mean Gradients : 173.810558734382
# discriminator Mean Gradients : 0.9945469556593486
# Mean Running Discriminator Loss : 0.01974575164695733
# Mean Running Generator Loss : 0.5322314720892058
# Generating and Saving Images to ./images/epoch48_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 449 Summary
# Epoch time duration : 637.4201989173889
# generator Mean Gradients : 174.85076911336992
# discriminator Mean Gradients : 0.9917006232448963
# Mean Running Discriminator Loss : 0.0197227267987017
# Mean Running Generator Loss : 0.5322271080356915
# Generating and Saving Images to ./images/epoch49_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 450 Summary
# Epoch time duration : 637.2225515842438
# generator Mean Gradients : 174.28768234539143
# discriminator Mean Gradients : 0.9845932365950962
# Mean Running Discriminator Loss : 0.019695916355408103
# Mean Running Generator Loss : 0.5322302190710396
# Generating and Saving Images to ./images/epoch50_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 451 Summary
# Epoch time duration : 851.9264771938324
# generator Mean Gradients : 175.4520948809879
# discriminator Mean Gradients : 0.9724221370195656
# Mean Running Discriminator Loss : 0.01966497410894815
# Mean Running Generator Loss : 0.5322154755625063
# Generating and Saving Images to ./images/epoch51_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 452 Summary
# Epoch time duration : 672.0820050239563
# generator Mean Gradients : 175.38502671583106
# discriminator Mean Gradients : 0.9686636234242552
# Mean Running Discriminator Loss : 0.01964065615277287
# Mean Running Generator Loss : 0.532201060677388
# Generating and Saving Images to ./images/epoch52_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 453 Summary
# Epoch time duration : 641.1336190700531
# generator Mean Gradients : 175.93763821555044
# discriminator Mean Gradients : 0.9708102164383916
# Mean Running Discriminator Loss : 0.019620016895889717
# Mean Running Generator Loss : 0.5322076205665833
# Generating and Saving Images to ./images/epoch53_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 454 Summary
# Epoch time duration : 684.8243162631989
# generator Mean Gradients : 176.6120940266594
# discriminator Mean Gradients : 0.9678481091894926
# Mean Running Discriminator Loss : 0.01959735440939632
# Mean Running Generator Loss : 0.5322046570706481
# Generating and Saving Images to ./images/epoch54_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 455 Summary
# Epoch time duration : 638.120228767395
# generator Mean Gradients : 176.61452099973295
# discriminator Mean Gradients : 0.9667058551601357
# Mean Running Discriminator Loss : 0.019575366234699267
# Mean Running Generator Loss : 0.5321984828471343
# Generating and Saving Images to ./images/epoch55_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 456 Summary
# Epoch time duration : 891.0270845890045
# generator Mean Gradients : 176.114451157338
# discriminator Mean Gradients : 0.9657727442659766
# Mean Running Discriminator Loss : 0.019552841830538518
# Mean Running Generator Loss : 0.5321922024443938
# Generating and Saving Images to ./images/epoch56_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 457 Summary
# Epoch time duration : 678.1657435894012
# generator Mean Gradients : 175.03054358460705
# discriminator Mean Gradients : 0.9693623006227108
# Mean Running Discriminator Loss : 0.019533614118093016
# Mean Running Generator Loss : 0.5322074103140829
# Generating and Saving Images to ./images/epoch57_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 458 Summary
# Epoch time duration : 630.9121170043945
# generator Mean Gradients : 174.10797783997245
# discriminator Mean Gradients : 0.9736621016957753
# Mean Running Discriminator Loss : 0.019514772990445007
# Mean Running Generator Loss : 0.5322034340060386
# Generating and Saving Images to ./images/epoch58_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 459 Summary
# Epoch time duration : 666.164558172226
# generator Mean Gradients : 172.7777786527076
# discriminator Mean Gradients : 0.9729654082689431
# Mean Running Discriminator Loss : 0.019493546691397745
# Mean Running Generator Loss : 0.532202423292157
# Generating and Saving Images to ./images/epoch59_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 460 Summary
# Epoch time duration : 642.6441850662231
# generator Mean Gradients : 172.56234629996158
# discriminator Mean Gradients : 0.9707638852736821
# Mean Running Discriminator Loss : 0.019472086738105167
# Mean Running Generator Loss : 0.5321975998388505
# Generating and Saving Images to ./images/epoch60_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 461 Summary
# Epoch time duration : 882.0640349388123
# generator Mean Gradients : 172.79079944440045
# discriminator Mean Gradients : 0.9732721617381854
# Mean Running Discriminator Loss : 0.019452469819319935
# Mean Running Generator Loss : 0.5321920869954416
# Generating and Saving Images to ./images/epoch61_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 462 Summary
# Epoch time duration : 665.8269305229187
# generator Mean Gradients : 173.11692344274246
# discriminator Mean Gradients : 0.9740778344024228
# Mean Running Discriminator Loss : 0.019432601811824466
# Mean Running Generator Loss : 0.5321873101319418
# Generating and Saving Images to ./images/epoch62_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 463 Summary
# Epoch time duration : 640.4284892082214
# generator Mean Gradients : 174.17918548947517
# discriminator Mean Gradients : 0.9708791081573315
# Mean Running Discriminator Loss : 0.019410561255017056
# Mean Running Generator Loss : 0.5321855572158909
# Generating and Saving Images to ./images/epoch63_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 464 Summary
# Epoch time duration : 648.1339185237885
# generator Mean Gradients : 174.77837577042027
# discriminator Mean Gradients : 0.973869032404806
# Mean Running Discriminator Loss : 0.01939393220634861
# Mean Running Generator Loss : 0.5321768428068143
# Generating and Saving Images to ./images/epoch64_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 465 Summary
# Epoch time duration : 661.0046434402466
# generator Mean Gradients : 175.58772864121204
# discriminator Mean Gradients : 0.9716103591861703
# Mean Running Discriminator Loss : 0.01937321581378655
# Mean Running Generator Loss : 0.5321535879266845
# Generating and Saving Images to ./images/epoch65_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 466 Summary
# Epoch time duration : 1072.4780304431915
# generator Mean Gradients : 176.66415494920136
# discriminator Mean Gradients : 0.9682777929932261
# Mean Running Discriminator Loss : 0.019351589577251062
# Mean Running Generator Loss : 0.5321348420293521
# Generating and Saving Images to ./images/epoch66_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 467 Summary
# Epoch time duration : 740.9067695140839
# generator Mean Gradients : 178.56150267976238
# discriminator Mean Gradients : 0.9660892233479904
# Mean Running Discriminator Loss : 0.01933146466926451
# Mean Running Generator Loss : 0.5321245218653334
# Generating and Saving Images to ./images/epoch67_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 468 Summary
# Epoch time duration : 638.1706049442291
# generator Mean Gradients : 178.11655671599124
# discriminator Mean Gradients : 0.9706930099918973
# Mean Running Discriminator Loss : 0.01931487735838187
# Mean Running Generator Loss : 0.532120200414004
# Generating and Saving Images to ./images/epoch68_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 469 Summary
# Epoch time duration : 639.9505252838135
# generator Mean Gradients : 179.57518125457227
# discriminator Mean Gradients : 0.9665843765141502
# Mean Running Discriminator Loss : 0.019292641693083937
# Mean Running Generator Loss : 0.5321100314392526
# Generating and Saving Images to ./images/epoch69_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 470 Summary
# Epoch time duration : 637.171279668808
# generator Mean Gradients : 180.69188203616127
# discriminator Mean Gradients : 0.9661549425145484
# Mean Running Discriminator Loss : 0.019273657123084972
# Mean Running Generator Loss : 0.5321105272841634
# Generating and Saving Images to ./images/epoch70_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 471 Summary
# Epoch time duration : 794.6877336502075
# generator Mean Gradients : 183.6574876758568
# discriminator Mean Gradients : 0.9626800108904704
# Mean Running Discriminator Loss : 0.019253217441273604
# Mean Running Generator Loss : 0.5321010058498112
# Generating and Saving Images to ./images/epoch71_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 472 Summary
# Epoch time duration : 656.4851229190826
# generator Mean Gradients : 184.44735513154433
# discriminator Mean Gradients : 0.964650269449952
# Mean Running Discriminator Loss : 0.019236842915960478
# Mean Running Generator Loss : 0.5320963101741296
# Generating and Saving Images to ./images/epoch72_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 473 Summary
# Epoch time duration : 676.7536625862122
# generator Mean Gradients : 185.85633718654353
# discriminator Mean Gradients : 0.9614536289959859
# Mean Running Discriminator Loss : 0.019215230255260035
# Mean Running Generator Loss : 0.5320873993743965
# Generating and Saving Images to ./images/epoch73_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 474 Summary
# Epoch time duration : 681.7173347473145
# generator Mean Gradients : 186.8128501316203
# discriminator Mean Gradients : 0.9607983070911889
# Mean Running Discriminator Loss : 0.019196038453462266
# Mean Running Generator Loss : 0.5320824612542052
# Generating and Saving Images to ./images/epoch74_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 475 Summary
# Epoch time duration : 674.2393155097961
# generator Mean Gradients : 188.20235098542756
# discriminator Mean Gradients : 0.9632497495057565
# Mean Running Discriminator Loss : 0.019179719099644593
# Mean Running Generator Loss : 0.5320793625405694
# Generating and Saving Images to ./images/epoch75_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 476 Summary
# Epoch time duration : 868.317929983139
# generator Mean Gradients : 189.17753266534024
# discriminator Mean Gradients : 0.9637435139165508
# Mean Running Discriminator Loss : 0.019160108957152214
# Mean Running Generator Loss : 0.5320678303916732
# Generating and Saving Images to ./images/epoch76_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 477 Summary
# Epoch time duration : 752.2620639801025
# generator Mean Gradients : 189.98293032637494
# discriminator Mean Gradients : 0.9604547448388108
# Mean Running Discriminator Loss : 0.019138429784543335
# Mean Running Generator Loss : 0.5320590832551712
# Generating and Saving Images to ./images/epoch77_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 478 Summary
# Epoch time duration : 656.4386937618256
# generator Mean Gradients : 191.33467604528695
# discriminator Mean Gradients : 0.9587550389010796
# Mean Running Discriminator Loss : 0.019117928458862368
# Mean Running Generator Loss : 0.5320513888939832
# Generating and Saving Images to ./images/epoch78_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 479 Summary
# Epoch time duration : 652.0216255187988
# generator Mean Gradients : 191.71265349695688
# discriminator Mean Gradients : 0.9600076380422626
# Mean Running Discriminator Loss : 0.01909889832348607
# Mean Running Generator Loss : 0.5320566009316253
# Generating and Saving Images to ./images/epoch79_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 480 Summary
# Epoch time duration : 647.4709987640381
# generator Mean Gradients : 193.0713361892109
# discriminator Mean Gradients : 0.9607554678813667
# Mean Running Discriminator Loss : 0.019081680283070324
# Mean Running Generator Loss : 0.5320510072131305
# Generating and Saving Images to ./images/epoch80_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 481 Summary
# Epoch time duration : 807.0243074893951
# generator Mean Gradients : 193.47535085207787
# discriminator Mean Gradients : 0.9564595370488161
# Mean Running Discriminator Loss : 0.019059108759284973
# Mean Running Generator Loss : 0.5320407460607924
# Generating and Saving Images to ./images/epoch81_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 482 Summary
# Epoch time duration : 709.4364159107208
# generator Mean Gradients : 193.48999273239235
# discriminator Mean Gradients : 0.955348798896725
# Mean Running Discriminator Loss : 0.0190401147419614
# Mean Running Generator Loss : 0.5320253826051929
# Generating and Saving Images to ./images/epoch82_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 483 Summary
# Epoch time duration : 888.0451257228851
# generator Mean Gradients : 195.32075208390256
# discriminator Mean Gradients : 0.9524737323796769
# Mean Running Discriminator Loss : 0.01901918812643733
# Mean Running Generator Loss : 0.5320160975238402
# Generating and Saving Images to ./images/epoch83_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 484 Summary
# Epoch time duration : 653.8326575756073
# generator Mean Gradients : 196.4972062568337
# discriminator Mean Gradients : 0.9506951945739234
# Mean Running Discriminator Loss : 0.01899873919642487
# Mean Running Generator Loss : 0.5320066310783365
# Generating and Saving Images to ./images/epoch84_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 485 Summary
# Epoch time duration : 660.6046767234802
# generator Mean Gradients : 195.71629218399679
# discriminator Mean Gradients : 0.9600817220779466
# Mean Running Discriminator Loss : 0.018987084806075125
# Mean Running Generator Loss : 0.5320132762113601
# Generating and Saving Images to ./images/epoch85_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 486 Summary
# Epoch time duration : 1014.522625207901
# generator Mean Gradients : 196.43246885087157
# discriminator Mean Gradients : 0.9576650020550118
# Mean Running Discriminator Loss : 0.01896700401177611
# Mean Running Generator Loss : 0.5320127768747828
# Generating and Saving Images to ./images/epoch86_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 487 Summary
# Epoch time duration : 655.7048726081848
# generator Mean Gradients : 196.9982580580486
# discriminator Mean Gradients : 0.9557181563200486
# Mean Running Discriminator Loss : 0.018947450271683104
# Mean Running Generator Loss : 0.5320133435350333
# Generating and Saving Images to ./images/epoch87_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 488 Summary
# Epoch time duration : 669.7902891635895
# generator Mean Gradients : 198.48992357012656
# discriminator Mean Gradients : 0.9520696985295873
# Mean Running Discriminator Loss : 0.018926025606072972
# Mean Running Generator Loss : 0.5320064961179678
# Generating and Saving Images to ./images/epoch88_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 489 Summary
# Epoch time duration : 651.5313403606415
# generator Mean Gradients : 199.15064123902454
# discriminator Mean Gradients : 0.9505923834558727
# Mean Running Discriminator Loss : 0.018904707026706793
# Mean Running Generator Loss : 0.5319974220621352
# Generating and Saving Images to ./images/epoch89_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 490 Summary
# Epoch time duration : 640.864883184433
# generator Mean Gradients : 200.38763346589963
# discriminator Mean Gradients : 0.9498480957159896
# Mean Running Discriminator Loss : 0.01888511011161333
# Mean Running Generator Loss : 0.5319929460817855
# Generating and Saving Images to ./images/epoch90_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 491 Summary
# Epoch time duration : 789.1449046134949
# generator Mean Gradients : 201.65659216606406
# discriminator Mean Gradients : 0.9493899161055398
# Mean Running Discriminator Loss : 0.018866699410491426
# Mean Running Generator Loss : 0.5319786947906152
# Generating and Saving Images to ./images/epoch91_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 492 Summary
# Epoch time duration : 648.9858751296997
# generator Mean Gradients : 204.01925101991355
# discriminator Mean Gradients : 0.9488867025759701
# Mean Running Discriminator Loss : 0.018848844803953296
# Mean Running Generator Loss : 0.5319781405364077
# Generating and Saving Images to ./images/epoch92_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 493 Summary
# Epoch time duration : 641.1914558410645
# generator Mean Gradients : 205.02304321594704
# discriminator Mean Gradients : 0.9480912039342281
# Mean Running Discriminator Loss : 0.018831822167212253
# Mean Running Generator Loss : 0.5319787055022147
# Generating and Saving Images to ./images/epoch93_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 494 Summary
# Epoch time duration : 633.2117609977722
# generator Mean Gradients : 207.31611849556404
# discriminator Mean Gradients : 0.9478453211844344
# Mean Running Discriminator Loss : 0.018815596144186843
# Mean Running Generator Loss : 0.5319767766788336
# Generating and Saving Images to ./images/epoch94_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 495 Summary
# Epoch time duration : 646.0685381889343
# generator Mean Gradients : 206.90689722920823
# discriminator Mean Gradients : 0.9485772762740444
# Mean Running Discriminator Loss : 0.018799086662305387
# Mean Running Generator Loss : 0.5319726820598167
# Generating and Saving Images to ./images/epoch95_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 496 Summary
# Epoch time duration : 910.625581741333
# generator Mean Gradients : 207.009661249386
# discriminator Mean Gradients : 0.9461753682738306
# Mean Running Discriminator Loss : 0.018779625518072864
# Mean Running Generator Loss : 0.5319704456650828
# Generating and Saving Images to ./images/epoch96_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 497 Summary
# Epoch time duration : 838.9050908088684
# generator Mean Gradients : 207.49192903170717
# discriminator Mean Gradients : 0.9444293293147547
# Mean Running Discriminator Loss : 0.018760181775455863
# Mean Running Generator Loss : 0.5319554124813248
# Generating and Saving Images to ./images/epoch97_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 498 Summary
# Epoch time duration : 680.6067366600037
# generator Mean Gradients : 208.1911360129241
# discriminator Mean Gradients : 0.943740438344167
# Mean Running Discriminator Loss : 0.018741771403328198
# Mean Running Generator Loss : 0.5319463144131543
# Generating and Saving Images to ./images/epoch98_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 499 Summary
# Epoch time duration : 672.7242288589478
# generator Mean Gradients : 208.80108251288905
# discriminator Mean Gradients : 0.9414276599229421
# Mean Running Discriminator Loss : 0.01872157546694396
# Mean Running Generator Loss : 0.5319434964093073
# Generating and Saving Images to ./images/epoch99_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 500 Summary
# Epoch time duration : 654.6698195934296
# generator Mean Gradients : 209.3531121925417
# discriminator Mean Gradients : 0.9412121669848788
# Mean Running Discriminator Loss : 0.018703193387124648
# Mean Running Generator Loss : 0.5319402755537883
# Generating and Saving Images to ./images/epoch100_generator.png
#
# Training of the Model is Complete
