# %% [markdown]
# This first cell makes sure that torchgan is installed. It's primarily here for use with colab, since colab doesn't have torchgan installed by default.

# %%
# from torchGAN tutorial

try:
    import torchgan

    print(f"Existing TorchGAN {torchgan.__version__} installation found")
except ImportError:
    import subprocess
    import sys

    subprocess.check_call([sys.executable, "-m", "pip", "install", "torchgan"])
    import torchgan

    print(f"Installed TorchGAN {torchgan.__version__}")
# Out:
# Existing TorchGAN v0.1.0 installation found

# %%
import torch
import torch.nn as nn
import torch.backends.cudnn
import torch.utils.data as tdata
from torch.optim import Adam
import torchvision
import torchvision.datasets as dsets
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import torchgan
from torchgan.models import *
from torchgan.losses import *
from torchgan.trainer import Trainer

# %% [markdown]
# This cell takes care of creating the dataset. Any PNG or JPEG image files are acceptable. The models require that the width and height of the images are equal, and that the dimensions of the image are a perfect power of 2, but those can both be overcome by scaling the images.
#
# The size variable is how big the generated images will be. Larger images can be more detailed, but dramatically slow down the training process. Additionally, as mentioned above, this value must be a perfect power of 2.
#
# If your images are in black and white, or if you wish to convert them to black and white, set grayscale to True in line 2.
#
# Due to the way that torchvision works, the file path provided in line 3 cannot be the exact folder that holds the images. In order for the path to be recognized properly, you must specify the folder that contains the folder with the images.
#
# For copyright reasons, the images that I am training from are not included with the GitHub repo. If you are interested in learning more, the citations for all of the images are included in the bibliography of the accompanying report.

# %%
size = 128
grayscale = False   # change this to True if your images are in black and white
folder = "./data/otherGANGogh/images/landscape/"

if grayscale:
    channels = 1
    data = ImageFolder(
        root=folder,
        transform=transforms.Compose([
            transforms.Resize((size, size)),
            transforms.ToTensor(),
            transforms.Grayscale(),
            transforms.Normalize(mean=.5, std=.5)
        ])
    )
else:
    channels = 3
    data = ImageFolder(
        root=folder,
        transform=transforms.Compose([
            transforms.Resize((size, size)),
            transforms.ToTensor(),
            transforms.Normalize(mean=.5, std=.5)
        ])
    )
print(len(data))
# Out:
# 15000

# %%
dataloader = tdata.DataLoader(data, batch_size=64, shuffle=True)

# %%
# adapted from torchgan tutorial

dcgan_network = {
    "generator": {
        "name": DCGANGenerator,
        "args": {
            "encoding_dims": 100,
            "out_size": size,           # this is how many pixels wide and tall the generated images will be
            "out_channels": channels,
            "step_channels": 32,
            "nonlinearity": nn.LeakyReLU(0.2),
            "last_nonlinearity": nn.Tanh(),
        },
        "optimizer": {"name": Adam, "args": {"lr": 0.0001, "betas": (0.5, 0.999)}},
    },
    "discriminator": {
        "name": DCGANDiscriminator,
        "args": {
            "in_size": size,            # this is how many pixels wide and tall we resized the images to be.
            "in_channels": channels,
            "step_channels": 32,
            "nonlinearity": nn.LeakyReLU(0.2),
            "last_nonlinearity": nn.LeakyReLU(0.2),
        },
        "optimizer": {"name": Adam, "args": {"lr": 0.0003, "betas": (0.5, 0.999)}},
    },
}

# %%
# from torchgan tutorial

minimax_losses = [MinimaxGeneratorLoss(), MinimaxDiscriminatorLoss()]
wgangp_losses = [
    WassersteinGeneratorLoss(),
    WassersteinDiscriminatorLoss(),
    WassersteinGradientPenalty(),
]
lsgan_losses = [LeastSquaresGeneratorLoss(), LeastSquaresDiscriminatorLoss()]

# %% [markdown]
# If you're running this on colab, be sure to select a GPU runtime for the best performance.

# %%
# more from torchgan tutorial

if torch.cuda.is_available():
    device = torch.device("cuda:0")
    # Use deterministic cudnn algorithms
    torch.backends.cudnn.deterministic = True
    epochs = 10
else:
    device = torch.device("cpu")
    epochs = 5

print("Device: {}".format(device))
print("Epochs: {}".format(epochs))
# Out:
# Device: cpu
# Epochs: 5

# %%
# from torchgan tutorial

trainer = Trainer(
    dcgan_network,
    lsgan_losses,
    sample_size=64,
    epochs=400,             # you can override the number of epochs here if you want to try to get better results
    device=device
)

# %% [markdown]
# This is the cell that actually does the training. After it finishes, use the next cell if you want to keep training the same model.

# %%
trainer(dataloader)
# Out:
# c:\users\leafy\pycharmprojects\gangogh\venv\lib\site-packages\PIL\TiffImagePlugin.py:845: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# Saving Model at './model/gan0.model'
# Epoch 1 Summary
# Epoch time duration : 1003.3898904323578
# generator Mean Gradients : 36.18075446934572
# discriminator Mean Gradients : 367.2088514130637
# Mean Running Discriminator Loss : 0.36510538287619326
# Mean Running Generator Loss : 0.8458863792901343
# c:\users\leafy\pycharmprojects\gangogh\venv\lib\site-packages\torchvision\utils.py:68: UserWarning: The parameter 'range' is deprecated since 0.12 and will be removed in 0.14. Please use 'value_range' instead.
#   warnings.warn(
# Generating and Saving Images to ./images/epoch1_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 2 Summary
# Epoch time duration : 856.2223539352417
# generator Mean Gradients : 19.761261659166436
# discriminator Mean Gradients : 256.79356252814733
# Mean Running Discriminator Loss : 0.2177339577472749
# Mean Running Generator Loss : 0.7154120697937113
# Generating and Saving Images to ./images/epoch2_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 3 Summary
# Epoch time duration : 669.5286500453949
# generator Mean Gradients : 13.850664039708674
# discriminator Mean Gradients : 220.01047040482334
# Mean Running Discriminator Loss : 0.1688748215080787
# Mean Running Generator Loss : 0.6690223753663666
# Generating and Saving Images to ./images/epoch3_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 4 Summary
# Epoch time duration : 720.5223140716553
# generator Mean Gradients : 10.758290492662736
# discriminator Mean Gradients : 191.93496075266353
# Mean Running Discriminator Loss : 0.1394829614855785
# Mean Running Generator Loss : 0.6447378350540679
# Generating and Saving Images to ./images/epoch4_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 5 Summary
# Epoch time duration : 709.4125661849976
# generator Mean Gradients : 8.886492547201936
# discriminator Mean Gradients : 171.54267443770553
# Mean Running Discriminator Loss : 0.11929052387007531
# Mean Running Generator Loss : 0.6316478937103394
# Generating and Saving Images to ./images/epoch5_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 6 Summary
# Epoch time duration : 638.6733846664429
# generator Mean Gradients : 7.578489533742412
# discriminator Mean Gradients : 158.52084717295375
# Mean Running Discriminator Loss : 0.10537700273165915
# Mean Running Generator Loss : 0.620856658543678
# Generating and Saving Images to ./images/epoch6_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 7 Summary
# Epoch time duration : 638.7959151268005
# generator Mean Gradients : 6.622244679571095
# discriminator Mean Gradients : 147.2284286660172
# Mean Running Discriminator Loss : 0.09527790586203676
# Mean Running Generator Loss : 0.6126432205315419
# Generating and Saving Images to ./images/epoch7_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 8 Summary
# Epoch time duration : 641.0729598999023
# generator Mean Gradients : 5.885809913857862
# discriminator Mean Gradients : 136.60091991479382
# Mean Running Discriminator Loss : 0.0868942148810094
# Mean Running Generator Loss : 0.6052941916708616
# Generating and Saving Images to ./images/epoch8_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 9 Summary
# Epoch time duration : 640.4323379993439
# generator Mean Gradients : 5.2938261693440625
# discriminator Mean Gradients : 128.87989400914495
# Mean Running Discriminator Loss : 0.08042447085549558
# Mean Running Generator Loss : 0.5995297863057882
# Generating and Saving Images to ./images/epoch9_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 10 Summary
# Epoch time duration : 755.0260453224182
# generator Mean Gradients : 4.840512738693249
# discriminator Mean Gradients : 130.0406417869379
# Mean Running Discriminator Loss : 0.08051809779834002
# Mean Running Generator Loss : 0.5958385660990756
# Generating and Saving Images to ./images/epoch10_generator.png
#
# Training of the Model is Complete

# %% [markdown]
# Use this cell instead of the previous one if you want to resume training a model that you saved from a previous session. Be sure to use the correct file path and file name when you call the function.

# %%
trainer.load_model("./model/gan4.model")
trainer(dataloader)
# Out:
# Loading Model From './model/gan4.model' to cpu
# Saving Model at './model/gan0.model'
# Epoch 101 Summary
# Epoch time duration : 805.1774735450745
# generator Mean Gradients : 92.26681429559125
# discriminator Mean Gradients : 6.818267191452721
# Mean Running Discriminator Loss : 0.04367372289124177
# Mean Running Generator Loss : 0.5357761636275931
# Generating and Saving Images to ./images/epoch1_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 102 Summary
# Epoch time duration : 644.1538641452789
# generator Mean Gradients : 81.65010997238097
# discriminator Mean Gradients : 6.632567143789018
# Mean Running Discriminator Loss : 0.043427157248187735
# Mean Running Generator Loss : 0.5357590975835889
# Generating and Saving Images to ./images/epoch2_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 103 Summary
# Epoch time duration : 807.4820041656494
# generator Mean Gradients : 81.4511583044265
# discriminator Mean Gradients : 6.617286662456192
# Mean Running Discriminator Loss : 0.04318922416378598
# Mean Running Generator Loss : 0.535758954113893
# Generating and Saving Images to ./images/epoch3_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 104 Summary
# Epoch time duration : 638.3865904808044
# generator Mean Gradients : 81.6553780339745
# discriminator Mean Gradients : 6.408802988476269
# Mean Running Discriminator Loss : 0.04293706539427479
# Mean Running Generator Loss : 0.5357452160826657
# Generating and Saving Images to ./images/epoch4_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 105 Summary
# Epoch time duration : 635.0098302364349
# generator Mean Gradients : 83.69014640798798
# discriminator Mean Gradients : 6.256012527554848
# Mean Running Discriminator Loss : 0.042698802113176344
# Mean Running Generator Loss : 0.5357175663065282
# Generating and Saving Images to ./images/epoch5_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 106 Summary
# Epoch time duration : 636.5097272396088
# generator Mean Gradients : 87.61703319311339
# discriminator Mean Gradients : 6.1292775000964035
# Mean Running Discriminator Loss : 0.04246048314182072
# Mean Running Generator Loss : 0.5357277180019965
# Generating and Saving Images to ./images/epoch6_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 107 Summary
# Epoch time duration : 644.3315722942352
# generator Mean Gradients : 87.78894068652707
# discriminator Mean Gradients : 5.9584328993941424
# Mean Running Discriminator Loss : 0.04222062722261092
# Mean Running Generator Loss : 0.535693468074067
# Generating and Saving Images to ./images/epoch7_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 108 Summary
# Epoch time duration : 862.0481998920441
# generator Mean Gradients : 88.95016001225966
# discriminator Mean Gradients : 5.916004006463865
# Mean Running Discriminator Loss : 0.04199677424401139
# Mean Running Generator Loss : 0.5356990016207182
# Generating and Saving Images to ./images/epoch8_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 109 Summary
# Epoch time duration : 736.1718182563782
# generator Mean Gradients : 90.53347095355888
# discriminator Mean Gradients : 5.875807614387375
# Mean Running Discriminator Loss : 0.041763346527508405
# Mean Running Generator Loss : 0.535627928882017
# Generating and Saving Images to ./images/epoch9_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 110 Summary
# Epoch time duration : 669.3095633983612
# generator Mean Gradients : 90.93957751214703
# discriminator Mean Gradients : 5.868265743649719
# Mean Running Discriminator Loss : 0.041541258480770935
# Mean Running Generator Loss : 0.5355947406820564
# Generating and Saving Images to ./images/epoch10_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 111 Summary
# Epoch time duration : 678.5971901416779
# generator Mean Gradients : 91.04483479004519
# discriminator Mean Gradients : 5.916341728671576
# Mean Running Discriminator Loss : 0.04133018478457522
# Mean Running Generator Loss : 0.5355936178127445
# Generating and Saving Images to ./images/epoch11_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 112 Summary
# Epoch time duration : 674.6571371555328
# generator Mean Gradients : 89.66419633956454
# discriminator Mean Gradients : 5.911632451960211
# Mean Running Discriminator Loss : 0.041112521075127695
# Mean Running Generator Loss : 0.5356208531217123
# Generating and Saving Images to ./images/epoch12_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 113 Summary
# Epoch time duration : 770.6598882675171
# generator Mean Gradients : 90.09838817416414
# discriminator Mean Gradients : 5.8924611422508475
# Mean Running Discriminator Loss : 0.040903659627463014
# Mean Running Generator Loss : 0.5356292141278435
# Generating and Saving Images to ./images/epoch13_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 114 Summary
# Epoch time duration : 671.5045030117035
# generator Mean Gradients : 90.64463810746786
# discriminator Mean Gradients : 5.886433728719154
# Mean Running Discriminator Loss : 0.04069793163992558
# Mean Running Generator Loss : 0.5355824374994621
# Generating and Saving Images to ./images/epoch14_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 115 Summary
# Epoch time duration : 658.7669010162354
# generator Mean Gradients : 90.52780614226005
# discriminator Mean Gradients : 5.895484952085728
# Mean Running Discriminator Loss : 0.040505131414447886
# Mean Running Generator Loss : 0.535597555335201
# Generating and Saving Images to ./images/epoch15_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 116 Summary
# Epoch time duration : 658.2448573112488
# generator Mean Gradients : 90.15365533167802
# discriminator Mean Gradients : 5.841550286065348
# Mean Running Discriminator Loss : 0.040296551982000314
# Mean Running Generator Loss : 0.5355469302704076
# Generating and Saving Images to ./images/epoch16_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 117 Summary
# Epoch time duration : 654.2789173126221
# generator Mean Gradients : 90.2488465302953
# discriminator Mean Gradients : 5.829013233228435
# Mean Running Discriminator Loss : 0.04010142674722126
# Mean Running Generator Loss : 0.5354812507093722
# Generating and Saving Images to ./images/epoch17_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 118 Summary
# Epoch time duration : 649.9105627536774
# generator Mean Gradients : 90.3763602457945
# discriminator Mean Gradients : 5.868639724860491
# Mean Running Discriminator Loss : 0.039917657735565756
# Mean Running Generator Loss : 0.5354748308148102
# Generating and Saving Images to ./images/epoch18_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 119 Summary
# Epoch time duration : 723.972104549408
# generator Mean Gradients : 91.81955273036746
# discriminator Mean Gradients : 5.804972979617756
# Mean Running Discriminator Loss : 0.039718475040423355
# Mean Running Generator Loss : 0.5354379016764151
# Generating and Saving Images to ./images/epoch19_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 120 Summary
# Epoch time duration : 656.4261465072632
# generator Mean Gradients : 93.05001639004786
# discriminator Mean Gradients : 5.775480736688109
# Mean Running Discriminator Loss : 0.039525129180492384
# Mean Running Generator Loss : 0.5354186258982894
# Generating and Saving Images to ./images/epoch20_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 121 Summary
# Epoch time duration : 667.5974142551422
# generator Mean Gradients : 95.26171565851647
# discriminator Mean Gradients : 5.745277106239438
# Mean Running Discriminator Loss : 0.03933341468716146
# Mean Running Generator Loss : 0.5353815933098289
# Generating and Saving Images to ./images/epoch21_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 122 Summary
# Epoch time duration : 641.1213827133179
# generator Mean Gradients : 95.2183319923818
# discriminator Mean Gradients : 5.817019205181688
# Mean Running Discriminator Loss : 0.03918211283257252
# Mean Running Generator Loss : 0.535368934584009
# Generating and Saving Images to ./images/epoch22_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 123 Summary
# Epoch time duration : 645.353892326355
# generator Mean Gradients : 96.12397622624378
# discriminator Mean Gradients : 5.766392827957541
# Mean Running Discriminator Loss : 0.03899323251366627
# Mean Running Generator Loss : 0.5353515317475707
# Generating and Saving Images to ./images/epoch23_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 124 Summary
# Epoch time duration : 836.0528333187103
# generator Mean Gradients : 97.38178013726976
# discriminator Mean Gradients : 5.7409819862185145
# Mean Running Discriminator Loss : 0.038812412658708544
# Mean Running Generator Loss : 0.5353423015556478
# Generating and Saving Images to ./images/epoch24_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 125 Summary
# Epoch time duration : 721.8613758087158
# generator Mean Gradients : 97.42465548095177
# discriminator Mean Gradients : 5.7083930488197225
# Mean Running Discriminator Loss : 0.038631875974645326
# Mean Running Generator Loss : 0.5353212153541281
# Generating and Saving Images to ./images/epoch25_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 126 Summary
# Epoch time duration : 642.9381794929504
# generator Mean Gradients : 96.96431094786395
# discriminator Mean Gradients : 5.675457820830394
# Mean Running Discriminator Loss : 0.03845166819474739
# Mean Running Generator Loss : 0.5353079571514788
# Generating and Saving Images to ./images/epoch26_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 127 Summary
# Epoch time duration : 679.251035451889
# generator Mean Gradients : 97.12296910813838
# discriminator Mean Gradients : 5.620836105463458
# Mean Running Discriminator Loss : 0.03826348597306616
# Mean Running Generator Loss : 0.5352692140983085
# Generating and Saving Images to ./images/epoch27_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 128 Summary
# Epoch time duration : 646.7136306762695
# generator Mean Gradients : 96.81019832993199
# discriminator Mean Gradients : 5.593208111339804
# Mean Running Discriminator Loss : 0.03809935696636843
# Mean Running Generator Loss : 0.5352494179484176
# Generating and Saving Images to ./images/epoch28_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 129 Summary
# Epoch time duration : 785.5880129337311
# generator Mean Gradients : 97.11957355369995
# discriminator Mean Gradients : 5.558565013380883
# Mean Running Discriminator Loss : 0.037930231917572395
# Mean Running Generator Loss : 0.5352368507682344
# Generating and Saving Images to ./images/epoch29_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 130 Summary
# Epoch time duration : 656.3805260658264
# generator Mean Gradients : 97.93900033362806
# discriminator Mean Gradients : 5.537831185644365
# Mean Running Discriminator Loss : 0.037790462334058056
# Mean Running Generator Loss : 0.535171453175295
# Generating and Saving Images to ./images/epoch30_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 131 Summary
# Epoch time duration : 646.3333563804626
# generator Mean Gradients : 98.06617048795378
# discriminator Mean Gradients : 5.486736036982843
# Mean Running Discriminator Loss : 0.0376202254941536
# Mean Running Generator Loss : 0.5351373293182187
# Generating and Saving Images to ./images/epoch31_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 132 Summary
# Epoch time duration : 642.3245701789856
# generator Mean Gradients : 97.76212942244621
# discriminator Mean Gradients : 5.512889475058076
# Mean Running Discriminator Loss : 0.03751383468152644
# Mean Running Generator Loss : 0.5351081956839663
# Generating and Saving Images to ./images/epoch32_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 133 Summary
# Epoch time duration : 644.1959064006805
# generator Mean Gradients : 99.39728904314191
# discriminator Mean Gradients : 5.477940252212066
# Mean Running Discriminator Loss : 0.037356440920187264
# Mean Running Generator Loss : 0.5350670935808086
# Generating and Saving Images to ./images/epoch33_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 134 Summary
# Epoch time duration : 674.9627320766449
# generator Mean Gradients : 100.03705137692157
# discriminator Mean Gradients : 5.440176281002862
# Mean Running Discriminator Loss : 0.037204641133925985
# Mean Running Generator Loss : 0.5350318361083196
# Generating and Saving Images to ./images/epoch34_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 135 Summary
# Epoch time duration : 865.2293169498444
# generator Mean Gradients : 101.46900704569468
# discriminator Mean Gradients : 5.399091037776177
# Mean Running Discriminator Loss : 0.03704209208550112
# Mean Running Generator Loss : 0.5349935332935236
# Generating and Saving Images to ./images/epoch35_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 136 Summary
# Epoch time duration : 645.9890344142914
# generator Mean Gradients : 103.8134831445017
# discriminator Mean Gradients : 5.359847678846181
# Mean Running Discriminator Loss : 0.03689164096296932
# Mean Running Generator Loss : 0.5349608608952797
# Generating and Saving Images to ./images/epoch36_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 137 Summary
# Epoch time duration : 648.8623254299164
# generator Mean Gradients : 105.03728909170833
# discriminator Mean Gradients : 5.296998146563684
# Mean Running Discriminator Loss : 0.03672806502506889
# Mean Running Generator Loss : 0.534907105654515
# Generating and Saving Images to ./images/epoch37_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 138 Summary
# Epoch time duration : 649.1283228397369
# generator Mean Gradients : 104.9598605800252
# discriminator Mean Gradients : 5.260070457051904
# Mean Running Discriminator Loss : 0.03658204117579218
# Mean Running Generator Loss : 0.5348913213771699
# Generating and Saving Images to ./images/epoch38_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 139 Summary
# Epoch time duration : 650.479743719101
# generator Mean Gradients : 105.11085461784766
# discriminator Mean Gradients : 5.204343976573527
# Mean Running Discriminator Loss : 0.03641793294983678
# Mean Running Generator Loss : 0.5349007412270065
# Generating and Saving Images to ./images/epoch39_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 140 Summary
# Epoch time duration : 745.1663970947266
# generator Mean Gradients : 105.3789372249585
# discriminator Mean Gradients : 5.169184604939025
# Mean Running Discriminator Loss : 0.03626806664113578
# Mean Running Generator Loss : 0.5349013887029878
# Generating and Saving Images to ./images/epoch40_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 141 Summary
# Epoch time duration : 640.4755110740662
# generator Mean Gradients : 105.51384297894187
# discriminator Mean Gradients : 5.1552051179275455
# Mean Running Discriminator Loss : 0.03613353794395235
# Mean Running Generator Loss : 0.5348948749349194
# Generating and Saving Images to ./images/epoch41_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 142 Summary
# Epoch time duration : 637.9134118556976
# generator Mean Gradients : 105.83848277612044
# discriminator Mean Gradients : 5.1298213906502586
# Mean Running Discriminator Loss : 0.03599292273466565
# Mean Running Generator Loss : 0.5348758482727858
# Generating and Saving Images to ./images/epoch42_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 143 Summary
# Epoch time duration : 640.0867726802826
# generator Mean Gradients : 105.84838052408816
# discriminator Mean Gradients : 5.107399058372565
# Mean Running Discriminator Loss : 0.03585469771456209
# Mean Running Generator Loss : 0.534849487225018
# Generating and Saving Images to ./images/epoch43_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 144 Summary
# Epoch time duration : 642.0116477012634
# generator Mean Gradients : 105.49184472314427
# discriminator Mean Gradients : 5.089095004725387
# Mean Running Discriminator Loss : 0.0357196330142661
# Mean Running Generator Loss : 0.5348539407020457
# Generating and Saving Images to ./images/epoch44_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 145 Summary
# Epoch time duration : 818.4089937210083
# generator Mean Gradients : 105.17967539390578
# discriminator Mean Gradients : 5.094136592714687
# Mean Running Discriminator Loss : 0.03560597340624181
# Mean Running Generator Loss : 0.5348345775677059
# Generating and Saving Images to ./images/epoch45_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 146 Summary
# Epoch time duration : 782.6480464935303
# generator Mean Gradients : 105.99583237334336
# discriminator Mean Gradients : 5.05324299264326
# Mean Running Discriminator Loss : 0.03546112398931844
# Mean Running Generator Loss : 0.5347857788558024
# Generating and Saving Images to ./images/epoch46_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 147 Summary
# Epoch time duration : 647.7750232219696
# generator Mean Gradients : 105.82754711332966
# discriminator Mean Gradients : 5.040920148000227
# Mean Running Discriminator Loss : 0.035327533072826905
# Mean Running Generator Loss : 0.5347707313392568
# Generating and Saving Images to ./images/epoch47_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 148 Summary
# Epoch time duration : 648.8059639930725
# generator Mean Gradients : 105.82436147968318
# discriminator Mean Gradients : 5.009770816542802
# Mean Running Discriminator Loss : 0.03519269902994288
# Mean Running Generator Loss : 0.5347629899161216
# Generating and Saving Images to ./images/epoch48_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 149 Summary
# Epoch time duration : 649.6855590343475
# generator Mean Gradients : 105.86570030727889
# discriminator Mean Gradients : 4.985647134783772
# Mean Running Discriminator Loss : 0.03505303426002029
# Mean Running Generator Loss : 0.5347444383874078
# Generating and Saving Images to ./images/epoch49_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 150 Summary
# Epoch time duration : 775.6402723789215
# generator Mean Gradients : 106.27913421983861
# discriminator Mean Gradients : 4.963158133335011
# Mean Running Discriminator Loss : 0.03492398261722072
# Mean Running Generator Loss : 0.5346999014929888
# Generating and Saving Images to ./images/epoch50_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 151 Summary
# Epoch time duration : 716.4131433963776
# generator Mean Gradients : 105.88537796797293
# discriminator Mean Gradients : 4.960879780521201
# Mean Running Discriminator Loss : 0.03480421867786135
# Mean Running Generator Loss : 0.5346490022535684
# Generating and Saving Images to ./images/epoch51_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 152 Summary
# Epoch time duration : 646.0037860870361
# generator Mean Gradients : 106.24163728880494
# discriminator Mean Gradients : 4.939233260789876
# Mean Running Discriminator Loss : 0.0346739304989179
# Mean Running Generator Loss : 0.5346229678244108
# Generating and Saving Images to ./images/epoch52_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 153 Summary
# Epoch time duration : 663.3540217876434
# generator Mean Gradients : 105.93017930317312
# discriminator Mean Gradients : 4.917077320616976
# Mean Running Discriminator Loss : 0.03454572344915026
# Mean Running Generator Loss : 0.5346067924652895
# Generating and Saving Images to ./images/epoch53_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 154 Summary
# Epoch time duration : 645.4565811157227
# generator Mean Gradients : 105.97929217435177
# discriminator Mean Gradients : 4.882213637639071
# Mean Running Discriminator Loss : 0.034407475607162924
# Mean Running Generator Loss : 0.534580524156344
# Generating and Saving Images to ./images/epoch54_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 155 Summary
# Epoch time duration : 685.4877007007599
# generator Mean Gradients : 106.0824538183495
# discriminator Mean Gradients : 4.851516680067215
# Mean Running Discriminator Loss : 0.03427619028125692
# Mean Running Generator Loss : 0.5345609241127763
# Generating and Saving Images to ./images/epoch55_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 156 Summary
# Epoch time duration : 884.0425155162811
# generator Mean Gradients : 106.09139756277456
# discriminator Mean Gradients : 4.834495985940449
# Mean Running Discriminator Loss : 0.034152670458187304
# Mean Running Generator Loss : 0.5345308622957065
# Generating and Saving Images to ./images/epoch56_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 157 Summary
# Epoch time duration : 646.7923300266266
# generator Mean Gradients : 106.13256386877461
# discriminator Mean Gradients : 4.808745322081286
# Mean Running Discriminator Loss : 0.03402965083830755
# Mean Running Generator Loss : 0.5344972416987739
# Generating and Saving Images to ./images/epoch57_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 158 Summary
# Epoch time duration : 650.6790616512299
# generator Mean Gradients : 106.21619079340272
# discriminator Mean Gradients : 4.779925068428596
# Mean Running Discriminator Loss : 0.0339084978022949
# Mean Running Generator Loss : 0.5344871123618083
# Generating and Saving Images to ./images/epoch58_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 159 Summary
# Epoch time duration : 650.2069056034088
# generator Mean Gradients : 105.92677011473344
# discriminator Mean Gradients : 4.7623083017102825
# Mean Running Discriminator Loss : 0.033782001747322904
# Mean Running Generator Loss : 0.5344605666347357
# Generating and Saving Images to ./images/epoch59_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 160 Summary
# Epoch time duration : 648.1701745986938
# generator Mean Gradients : 107.04399602593674
# discriminator Mean Gradients : 4.727100276836997
# Mean Running Discriminator Loss : 0.033655949011116855
# Mean Running Generator Loss : 0.5344190056175192
# Generating and Saving Images to ./images/epoch60_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 161 Summary
# Epoch time duration : 911.7138237953186
# generator Mean Gradients : 107.64325207552726
# discriminator Mean Gradients : 4.696250355308146
# Mean Running Discriminator Loss : 0.03353087386676139
# Mean Running Generator Loss : 0.5343904403785277
# Generating and Saving Images to ./images/epoch61_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 162 Summary
# Epoch time duration : 641.6663193702698
# generator Mean Gradients : 107.98804248514227
# discriminator Mean Gradients : 4.664658288631927
# Mean Running Discriminator Loss : 0.03340833811478365
# Mean Running Generator Loss : 0.5344200561832444
# Generating and Saving Images to ./images/epoch62_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 163 Summary
# Epoch time duration : 640.4867532253265
# generator Mean Gradients : 108.89776385611219
# discriminator Mean Gradients : 4.635266047497499
# Mean Running Discriminator Loss : 0.033294984389820065
# Mean Running Generator Loss : 0.534385284946495
# Generating and Saving Images to ./images/epoch63_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 164 Summary
# Epoch time duration : 692.8096430301666
# generator Mean Gradients : 109.67666890270833
# discriminator Mean Gradients : 4.6002781903587024
# Mean Running Discriminator Loss : 0.03317539148702884
# Mean Running Generator Loss : 0.5343734675896565
# Generating and Saving Images to ./images/epoch64_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 165 Summary
# Epoch time duration : 643.0143480300903
# generator Mean Gradients : 109.41061735201053
# discriminator Mean Gradients : 4.603027914206553
# Mean Running Discriminator Loss : 0.03310723360235785
# Mean Running Generator Loss : 0.5343888132792953
# Generating and Saving Images to ./images/epoch65_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 166 Summary
# Epoch time duration : 856.8362562656403
# generator Mean Gradients : 110.27694441835429
# discriminator Mean Gradients : 4.569582177655538
# Mean Running Discriminator Loss : 0.03299427205022621
# Mean Running Generator Loss : 0.5344014959935537
# Generating and Saving Images to ./images/epoch66_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 167 Summary
# Epoch time duration : 637.6073379516602
# generator Mean Gradients : 110.56750350877574
# discriminator Mean Gradients : 4.552260905222647
# Mean Running Discriminator Loss : 0.03289130101892145
# Mean Running Generator Loss : 0.5343721572177313
# Generating and Saving Images to ./images/epoch67_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 168 Summary
# Epoch time duration : 637.3917469978333
# generator Mean Gradients : 110.88487954672067
# discriminator Mean Gradients : 4.522279306286819
# Mean Running Discriminator Loss : 0.03277597499836997
# Mean Running Generator Loss : 0.5343525276902455
# Generating and Saving Images to ./images/epoch68_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 169 Summary
# Epoch time duration : 642.8014829158783
# generator Mean Gradients : 111.57231071197535
# discriminator Mean Gradients : 4.498097287796671
# Mean Running Discriminator Loss : 0.03266508367577884
# Mean Running Generator Loss : 0.5343195996807104
# Generating and Saving Images to ./images/epoch69_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 170 Summary
# Epoch time duration : 687.3625304698944
# generator Mean Gradients : 112.31304659486248
# discriminator Mean Gradients : 4.460664610104852
# Mean Running Discriminator Loss : 0.03255436710165918
# Mean Running Generator Loss : 0.5342779011355808
# Generating and Saving Images to ./images/epoch70_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 171 Summary
# Epoch time duration : 876.0916373729706
# generator Mean Gradients : 113.28029683819922
# discriminator Mean Gradients : 4.427377036119741
# Mean Running Discriminator Loss : 0.032444667225490144
# Mean Running Generator Loss : 0.5342528837081381
# Generating and Saving Images to ./images/epoch71_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 172 Summary
# Epoch time duration : 649.5007545948029
# generator Mean Gradients : 114.65499569401788
# discriminator Mean Gradients : 4.397229383229818
# Mean Running Discriminator Loss : 0.03233818791194725
# Mean Running Generator Loss : 0.5342110789004475
# Generating and Saving Images to ./images/epoch72_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 173 Summary
# Epoch time duration : 648.4966523647308
# generator Mean Gradients : 115.64342614380342
# discriminator Mean Gradients : 4.368020846275922
# Mean Running Discriminator Loss : 0.032231058749399945
# Mean Running Generator Loss : 0.5341769990483863
# Generating and Saving Images to ./images/epoch73_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 174 Summary
# Epoch time duration : 647.0084447860718
# generator Mean Gradients : 117.43740663935071
# discriminator Mean Gradients : 4.338355037034034
# Mean Running Discriminator Loss : 0.032127092251935406
# Mean Running Generator Loss : 0.5341747543819414
# Generating and Saving Images to ./images/epoch74_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 175 Summary
# Epoch time duration : 645.2648725509644
# generator Mean Gradients : 118.25877538386845
# discriminator Mean Gradients : 4.3035851271735455
# Mean Running Discriminator Loss : 0.032012519272763315
# Mean Running Generator Loss : 0.5341549699278407
# Generating and Saving Images to ./images/epoch75_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 176 Summary
# Epoch time duration : 913.9473941326141
# generator Mean Gradients : 119.47179962964768
# discriminator Mean Gradients : 4.283574312977355
# Mean Running Discriminator Loss : 0.031909105549364915
# Mean Running Generator Loss : 0.534118819231081
# Generating and Saving Images to ./images/epoch76_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 177 Summary
# Epoch time duration : 703.3951506614685
# generator Mean Gradients : 120.79528112841496
# discriminator Mean Gradients : 4.254202324353521
# Mean Running Discriminator Loss : 0.03180451609923865
# Mean Running Generator Loss : 0.5340974249173198
# Generating and Saving Images to ./images/epoch77_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 178 Summary
# Epoch time duration : 645.3252835273743
# generator Mean Gradients : 122.23062288959989
# discriminator Mean Gradients : 4.232660064489172
# Mean Running Discriminator Loss : 0.031705901599429036
# Mean Running Generator Loss : 0.5340939633575867
# Generating and Saving Images to ./images/epoch78_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 179 Summary
# Epoch time duration : 648.2634418010712
# generator Mean Gradients : 123.05818616637958
# discriminator Mean Gradients : 4.2125738744380135
# Mean Running Discriminator Loss : 0.03160770638923019
# Mean Running Generator Loss : 0.534089191143091
# Generating and Saving Images to ./images/epoch79_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 180 Summary
# Epoch time duration : 648.7592165470123
# generator Mean Gradients : 123.26481746524247
# discriminator Mean Gradients : 4.195229392831182
# Mean Running Discriminator Loss : 0.03151612514030545
# Mean Running Generator Loss : 0.5340802333668649
# Generating and Saving Images to ./images/epoch80_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 181 Summary
# Epoch time duration : 757.6803522109985
# generator Mean Gradients : 123.30986502383116
# discriminator Mean Gradients : 4.169162334596161
# Mean Running Discriminator Loss : 0.031411867610320006
# Mean Running Generator Loss : 0.5340732223625236
# Generating and Saving Images to ./images/epoch81_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 182 Summary
# Epoch time duration : 700.11021733284
# generator Mean Gradients : 122.96082499571489
# discriminator Mean Gradients : 4.159116416170285
# Mean Running Discriminator Loss : 0.031322643727735675
# Mean Running Generator Loss : 0.5340646743824061
# Generating and Saving Images to ./images/epoch82_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 183 Summary
# Epoch time duration : 643.5367982387543
# generator Mean Gradients : 123.45580950733628
# discriminator Mean Gradients : 4.133226484900493
# Mean Running Discriminator Loss : 0.031220480820362023
# Mean Running Generator Loss : 0.5340566967944359
# Generating and Saving Images to ./images/epoch83_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 184 Summary
# Epoch time duration : 643.5544068813324
# generator Mean Gradients : 123.95720355612502
# discriminator Mean Gradients : 4.108357601150264
# Mean Running Discriminator Loss : 0.031115544603893725
# Mean Running Generator Loss : 0.5340196449093342
# Generating and Saving Images to ./images/epoch84_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 185 Summary
# Epoch time duration : 649.3880660533905
# generator Mean Gradients : 123.82628373604959
# discriminator Mean Gradients : 4.088460893884136
# Mean Running Discriminator Loss : 0.03101691963750914
# Mean Running Generator Loss : 0.5340114224965611
# Generating and Saving Images to ./images/epoch85_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 186 Summary
# Epoch time duration : 649.5432205200195
# generator Mean Gradients : 123.347607644258
# discriminator Mean Gradients : 4.069782774042449
# Mean Running Discriminator Loss : 0.030918369938232076
# Mean Running Generator Loss : 0.5340047464106216
# Generating and Saving Images to ./images/epoch86_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 187 Summary
# Epoch time duration : 883.7052311897278
# generator Mean Gradients : 123.08894316436553
# discriminator Mean Gradients : 4.058561907409502
# Mean Running Discriminator Loss : 0.030831688721699748
# Mean Running Generator Loss : 0.534002926463929
# Generating and Saving Images to ./images/epoch87_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 188 Summary
# Epoch time duration : 674.4453485012054
# generator Mean Gradients : 122.95340081042158
# discriminator Mean Gradients : 4.039854661244686
# Mean Running Discriminator Loss : 0.030738133926443322
# Mean Running Generator Loss : 0.5340011018155932
# Generating and Saving Images to ./images/epoch88_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 189 Summary
# Epoch time duration : 643.4171485900879
# generator Mean Gradients : 122.63087376379006
# discriminator Mean Gradients : 4.028182084570172
# Mean Running Discriminator Loss : 0.030656030026149056
# Mean Running Generator Loss : 0.5339925326854846
# Generating and Saving Images to ./images/epoch89_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 190 Summary
# Epoch time duration : 644.9398908615112
# generator Mean Gradients : 122.45762540275796
# discriminator Mean Gradients : 4.019088000488614
# Mean Running Discriminator Loss : 0.030571740115867576
# Mean Running Generator Loss : 0.534006701306443
# Generating and Saving Images to ./images/epoch90_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 191 Summary
# Epoch time duration : 649.4042534828186
# generator Mean Gradients : 122.49935492376541
# discriminator Mean Gradients : 4.003142884227222
# Mean Running Discriminator Loss : 0.03047892850353941
# Mean Running Generator Loss : 0.5339996105518329
# Generating and Saving Images to ./images/epoch91_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 192 Summary
# Epoch time duration : 912.7634944915771
# generator Mean Gradients : 122.53286035983257
# discriminator Mean Gradients : 3.98717939000963
# Mean Running Discriminator Loss : 0.030386379384925936
# Mean Running Generator Loss : 0.533973458928885
# Generating and Saving Images to ./images/epoch92_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 193 Summary
# Epoch time duration : 642.6076793670654
# generator Mean Gradients : 122.75806176409101
# discriminator Mean Gradients : 3.9714807524082207
# Mean Running Discriminator Loss : 0.030293456812165064
# Mean Running Generator Loss : 0.5339340936016772
# Generating and Saving Images to ./images/epoch93_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 194 Summary
# Epoch time duration : 650.2965180873871
# generator Mean Gradients : 122.71935347309567
# discriminator Mean Gradients : 3.9663179223099303
# Mean Running Discriminator Loss : 0.030215301662610966
# Mean Running Generator Loss : 0.5339305133242785
# Generating and Saving Images to ./images/epoch94_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 195 Summary
# Epoch time duration : 648.66046667099
# generator Mean Gradients : 122.622624450151
# discriminator Mean Gradients : 3.950812590747535
# Mean Running Discriminator Loss : 0.030127784187666182
# Mean Running Generator Loss : 0.5339293437257239
# Generating and Saving Images to ./images/epoch95_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 196 Summary
# Epoch time duration : 649.0848104953766
# generator Mean Gradients : 122.54336788601111
# discriminator Mean Gradients : 3.9313599950414937
# Mean Running Discriminator Loss : 0.030038653442468713
# Mean Running Generator Loss : 0.5338960273818955
# Generating and Saving Images to ./images/epoch96_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 197 Summary
# Epoch time duration : 972.4922323226929
# generator Mean Gradients : 122.5420644127631
# discriminator Mean Gradients : 3.9135790547873808
# Mean Running Discriminator Loss : 0.029951187245817742
# Mean Running Generator Loss : 0.5338775054346969
# Generating and Saving Images to ./images/epoch97_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 198 Summary
# Epoch time duration : 645.9143259525299
# generator Mean Gradients : 122.32674655067754
# discriminator Mean Gradients : 3.8950145262964204
# Mean Running Discriminator Loss : 0.029861063265965045
# Mean Running Generator Loss : 0.5338585025898499
# Generating and Saving Images to ./images/epoch98_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 199 Summary
# Epoch time duration : 644.8244442939758
# generator Mean Gradients : 122.5081698820911
# discriminator Mean Gradients : 3.8862030574197832
# Mean Running Discriminator Loss : 0.029784437687714067
# Mean Running Generator Loss : 0.533862684733945
# Generating and Saving Images to ./images/epoch99_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 200 Summary
# Epoch time duration : 643.6695868968964
# generator Mean Gradients : 122.40857350290243
# discriminator Mean Gradients : 3.8731008178286954
# Mean Running Discriminator Loss : 0.029696994150651895
# Mean Running Generator Loss : 0.5338416763963376
# Generating and Saving Images to ./images/epoch100_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 201 Summary
# Epoch time duration : 643.775262594223
# generator Mean Gradients : 122.14297620657672
# discriminator Mean Gradients : 3.8560162754614162
# Mean Running Discriminator Loss : 0.029608591712381904
# Mean Running Generator Loss : 0.5338248131477108
# Generating and Saving Images to ./images/epoch101_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 202 Summary
# Epoch time duration : 809.0966954231262
# generator Mean Gradients : 121.67842002145096
# discriminator Mean Gradients : 3.8551751205778517
# Mean Running Discriminator Loss : 0.02954211636710883
# Mean Running Generator Loss : 0.5338299941999808
# Generating and Saving Images to ./images/epoch102_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 203 Summary
# Epoch time duration : 663.1270403862
# generator Mean Gradients : 121.58621919759126
# discriminator Mean Gradients : 3.836316637529341
# Mean Running Discriminator Loss : 0.029452452590049114
# Mean Running Generator Loss : 0.5337961974690519
# Generating and Saving Images to ./images/epoch103_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 204 Summary
# Epoch time duration : 637.50812458992
# generator Mean Gradients : 121.69293414526017
# discriminator Mean Gradients : 3.816089046395265
# Mean Running Discriminator Loss : 0.029370382164736482
# Mean Running Generator Loss : 0.5337939104980691
# Generating and Saving Images to ./images/epoch104_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 205 Summary
# Epoch time duration : 638.6065413951874
# generator Mean Gradients : 122.34509962875117
# discriminator Mean Gradients : 3.7942372878770545
# Mean Running Discriminator Loss : 0.029288490395350204
# Mean Running Generator Loss : 0.5337927463405573
# Generating and Saving Images to ./images/epoch105_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 206 Summary
# Epoch time duration : 649.9380714893341
# generator Mean Gradients : 122.91155596521625
# discriminator Mean Gradients : 3.776475878169538
# Mean Running Discriminator Loss : 0.029211240758610733
# Mean Running Generator Loss : 0.5337947086808732
# Generating and Saving Images to ./images/epoch106_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 207 Summary
# Epoch time duration : 725.186445236206
# generator Mean Gradients : 123.5747953248386
# discriminator Mean Gradients : 3.7513370052019805
# Mean Running Discriminator Loss : 0.029119314150654045
# Mean Running Generator Loss : 0.5337742283412671
# Generating and Saving Images to ./images/epoch107_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 208 Summary
# Epoch time duration : 853.2469832897186
# generator Mean Gradients : 124.40201463301946
# discriminator Mean Gradients : 3.7337047971688437
# Mean Running Discriminator Loss : 0.029038882981616176
# Mean Running Generator Loss : 0.5337772273820552
# Generating and Saving Images to ./images/epoch108_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 209 Summary
# Epoch time duration : 639.1207046508789
# generator Mean Gradients : 124.74462915575154
# discriminator Mean Gradients : 3.7189526288964845
# Mean Running Discriminator Loss : 0.02897139661549095
# Mean Running Generator Loss : 0.5338025862217757
# Generating and Saving Images to ./images/epoch109_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 210 Summary
# Epoch time duration : 650.7108421325684
# generator Mean Gradients : 124.58659578549873
# discriminator Mean Gradients : 3.7053142098836185
# Mean Running Discriminator Loss : 0.028909258003702355
# Mean Running Generator Loss : 0.533831333475227
# Generating and Saving Images to ./images/epoch110_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 211 Summary
# Epoch time duration : 646.207700252533
# generator Mean Gradients : 124.4850109490736
# discriminator Mean Gradients : 3.6985784555147356
# Mean Running Discriminator Loss : 0.0288537572724678
# Mean Running Generator Loss : 0.5338333352008083
# Generating and Saving Images to ./images/epoch111_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 212 Summary
# Epoch time duration : 687.97212266922
# generator Mean Gradients : 126.30812136723212
# discriminator Mean Gradients : 3.681846860229344
# Mean Running Discriminator Loss : 0.02878319676907057
# Mean Running Generator Loss : 0.5338209963842198
# Generating and Saving Images to ./images/epoch112_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 213 Summary
# Epoch time duration : 890.5268805027008
# generator Mean Gradients : 127.82922863583069
# discriminator Mean Gradients : 3.6660102308705955
# Mean Running Discriminator Loss : 0.02871665373789605
# Mean Running Generator Loss : 0.533835011447447
# Generating and Saving Images to ./images/epoch113_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 214 Summary
# Epoch time duration : 648.5379016399384
# generator Mean Gradients : 129.63390236571615
# discriminator Mean Gradients : 3.644654223359625
# Mean Running Discriminator Loss : 0.02863718231555299
# Mean Running Generator Loss : 0.5338616913375269
# Generating and Saving Images to ./images/epoch114_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 215 Summary
# Epoch time duration : 648.4660029411316
# generator Mean Gradients : 131.36864081631552
# discriminator Mean Gradients : 3.6266184931036647
# Mean Running Discriminator Loss : 0.02856546657371442
# Mean Running Generator Loss : 0.5338823585048547
# Generating and Saving Images to ./images/epoch115_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 216 Summary
# Epoch time duration : 645.2730944156647
# generator Mean Gradients : 132.554135016282
# discriminator Mean Gradients : 3.6122570023143066
# Mean Running Discriminator Loss : 0.02850083080304778
# Mean Running Generator Loss : 0.5338718342226383
# Generating and Saving Images to ./images/epoch116_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 217 Summary
# Epoch time duration : 647.0654816627502
# generator Mean Gradients : 133.6895687160575
# discriminator Mean Gradients : 3.5994173519919452
# Mean Running Discriminator Loss : 0.0284375608848476
# Mean Running Generator Loss : 0.5338866062750155
# Generating and Saving Images to ./images/epoch117_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 218 Summary
# Epoch time duration : 957.0431392192841
# generator Mean Gradients : 134.78116992979895
# discriminator Mean Gradients : 3.5838071227782407
# Mean Running Discriminator Loss : 0.02836858493739693
# Mean Running Generator Loss : 0.5338884615803455
# Generating and Saving Images to ./images/epoch118_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 219 Summary
# Epoch time duration : 647.0106868743896
# generator Mean Gradients : 135.7204398638376
# discriminator Mean Gradients : 3.566976217895925
# Mean Running Discriminator Loss : 0.028296735261918095
# Mean Running Generator Loss : 0.5338722391905462
# Generating and Saving Images to ./images/epoch119_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 220 Summary
# Epoch time duration : 641.8800675868988
# generator Mean Gradients : 136.58621069247752
# discriminator Mean Gradients : 3.5510542248982317
# Mean Running Discriminator Loss : 0.028226054577558612
# Mean Running Generator Loss : 0.5338664113570949
# Generating and Saving Images to ./images/epoch120_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 221 Summary
# Epoch time duration : 644.4680728912354
# generator Mean Gradients : 137.00262385676052
# discriminator Mean Gradients : 3.5366717895594704
# Mean Running Discriminator Loss : 0.02815937679559993
# Mean Running Generator Loss : 0.5338378431456425
# Generating and Saving Images to ./images/epoch121_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 222 Summary
# Epoch time duration : 643.6738710403442
# generator Mean Gradients : 137.54106659702742
# discriminator Mean Gradients : 3.523082179261786
# Mean Running Discriminator Loss : 0.0280948923365753
# Mean Running Generator Loss : 0.5338390305641884
# Generating and Saving Images to ./images/epoch122_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 223 Summary
# Epoch time duration : 844.7772786617279
# generator Mean Gradients : 138.51473732358005
# discriminator Mean Gradients : 3.5098392991794207
# Mean Running Discriminator Loss : 0.028033103456731552
# Mean Running Generator Loss : 0.533815015255822
# Generating and Saving Images to ./images/epoch123_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 224 Summary
# Epoch time duration : 658.0230038166046
# generator Mean Gradients : 139.90221877181426
# discriminator Mean Gradients : 3.4942288513393636
# Mean Running Discriminator Loss : 0.027967891415056883
# Mean Running Generator Loss : 0.5338444040228377
# Generating and Saving Images to ./images/epoch124_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 225 Summary
# Epoch time duration : 687.6880302429199
# generator Mean Gradients : 139.70048487634094
# discriminator Mean Gradients : 3.481491673751947
# Mean Running Discriminator Loss : 0.027905406376628764
# Mean Running Generator Loss : 0.5338305478355986
# Generating and Saving Images to ./images/epoch125_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 226 Summary
# Epoch time duration : 642.1598138809204
# generator Mean Gradients : 139.79418284784367
# discriminator Mean Gradients : 3.4647235954475306
# Mean Running Discriminator Loss : 0.027839419157107487
# Mean Running Generator Loss : 0.53381869777121
# Generating and Saving Images to ./images/epoch126_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 227 Summary
# Epoch time duration : 640.8881611824036
# generator Mean Gradients : 139.5893639048035
# discriminator Mean Gradients : 3.454499106783991
# Mean Running Discriminator Loss : 0.027784408941425538
# Mean Running Generator Loss : 0.5338346062962911
# Generating and Saving Images to ./images/epoch127_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 228 Summary
# Epoch time duration : 871.9826271533966
# generator Mean Gradients : 139.86395253727574
# discriminator Mean Gradients : 3.439501822691056
# Mean Running Discriminator Loss : 0.027719424272403845
# Mean Running Generator Loss : 0.5338217331179963
# Generating and Saving Images to ./images/epoch128_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 229 Summary
# Epoch time duration : 707.5522472858429
# generator Mean Gradients : 139.75259075455298
# discriminator Mean Gradients : 3.424627226225504
# Mean Running Discriminator Loss : 0.027652475985634455
# Mean Running Generator Loss : 0.5338010605152246
# Generating and Saving Images to ./images/epoch129_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 230 Summary
# Epoch time duration : 640.3248660564423
# generator Mean Gradients : 139.90696246679906
# discriminator Mean Gradients : 3.4103588170449504
# Mean Running Discriminator Loss : 0.027587703554305204
# Mean Running Generator Loss : 0.5337707524709437
# Generating and Saving Images to ./images/epoch130_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 231 Summary
# Epoch time duration : 671.0729157924652
# generator Mean Gradients : 140.44008903598402
# discriminator Mean Gradients : 3.3954194617502433
# Mean Running Discriminator Loss : 0.02752616383100406
# Mean Running Generator Loss : 0.5337673423105816
# Generating and Saving Images to ./images/epoch131_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 232 Summary
# Epoch time duration : 644.3202044963837
# generator Mean Gradients : 140.66474634291197
# discriminator Mean Gradients : 3.3803316165754795
# Mean Running Discriminator Loss : 0.027461854449973146
# Mean Running Generator Loss : 0.533760644385136
# Generating and Saving Images to ./images/epoch132_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 233 Summary
# Epoch time duration : 852.2754836082458
# generator Mean Gradients : 140.65949269827973
# discriminator Mean Gradients : 3.367821221716446
# Mean Running Discriminator Loss : 0.027403122929818082
# Mean Running Generator Loss : 0.5337864226494851
# Generating and Saving Images to ./images/epoch133_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 234 Summary
# Epoch time duration : 664.1148393154144
# generator Mean Gradients : 140.96240914095512
# discriminator Mean Gradients : 3.3554628582175927
# Mean Running Discriminator Loss : 0.02735071014767456
# Mean Running Generator Loss : 0.5337892224665668
# Generating and Saving Images to ./images/epoch134_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 235 Summary
# ...
# Mean Running Discriminator Loss : 0.022110316422271438
# Mean Running Generator Loss : 0.5328291676962134
# Generating and Saving Images to ./images/epoch256_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 357 Summary
# Epoch time duration : 640.5292174816132
# generator Mean Gradients : 159.7174079852161
# discriminator Mean Gradients : 2.430678193655266
# Mean Running Discriminator Loss : 0.02207600049181291
# Mean Running Generator Loss : 0.5328246479726436
# Generating and Saving Images to ./images/epoch257_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 358 Summary
# Epoch time duration : 643.063663482666
# generator Mean Gradients : 159.4119016806866
# discriminator Mean Gradients : 2.426862299249198
# Mean Running Discriminator Loss : 0.02204944495052258
# Mean Running Generator Loss : 0.5328282043662396
# Generating and Saving Images to ./images/epoch258_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 359 Summary
# Epoch time duration : 1106.7676572799683
# generator Mean Gradients : 159.06370724032737
# discriminator Mean Gradients : 2.4225952869642335
# Mean Running Discriminator Loss : 0.022020927308671407
# Mean Running Generator Loss : 0.5328398609609746
# Generating and Saving Images to ./images/epoch259_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 360 Summary
# Epoch time duration : 741.3074896335602
# generator Mean Gradients : 158.94763024413874
# discriminator Mean Gradients : 2.4165743922047986
# Mean Running Discriminator Loss : 0.02198764065385688
# Mean Running Generator Loss : 0.5328369327555752
# Generating and Saving Images to ./images/epoch260_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 361 Summary
# Epoch time duration : 638.6989951133728
# generator Mean Gradients : 158.58624295912475
# discriminator Mean Gradients : 2.4119456978329006
# Mean Running Discriminator Loss : 0.021959269945926622
# Mean Running Generator Loss : 0.5328314970812762
# Generating and Saving Images to ./images/epoch261_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 362 Summary
# Epoch time duration : 641.3730971813202
# generator Mean Gradients : 158.4544725467703
# discriminator Mean Gradients : 2.4075359866401116
# Mean Running Discriminator Loss : 0.021933527899894764
# Mean Running Generator Loss : 0.532839659604384
# Generating and Saving Images to ./images/epoch262_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 363 Summary
# Epoch time duration : 638.8553695678711
# generator Mean Gradients : 158.4942755063786
# discriminator Mean Gradients : 2.402004926959929
# Mean Running Discriminator Loss : 0.021903816911822995
# Mean Running Generator Loss : 0.5328255890961895
# Generating and Saving Images to ./images/epoch263_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 364 Summary
# Epoch time duration : 871.6305720806122
# generator Mean Gradients : 158.77910463750473
# discriminator Mean Gradients : 2.396185074384954
# Mean Running Discriminator Loss : 0.021872261527427404
# Mean Running Generator Loss : 0.5328290153695029
# Generating and Saving Images to ./images/epoch264_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 365 Summary
# Epoch time duration : 682.697587966919
# generator Mean Gradients : 159.45953812243656
# discriminator Mean Gradients : 2.3910076465146517
# Mean Running Discriminator Loss : 0.021845003690839866
# Mean Running Generator Loss : 0.5328137211280969
# Generating and Saving Images to ./images/epoch265_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 366 Summary
# Epoch time duration : 636.4249424934387
# generator Mean Gradients : 160.06575635528344
# discriminator Mean Gradients : 2.385550154639104
# Mean Running Discriminator Loss : 0.021816516535604822
# Mean Running Generator Loss : 0.5328100860815761
# Generating and Saving Images to ./images/epoch266_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 367 Summary
# Epoch time duration : 635.7767326831818
# generator Mean Gradients : 160.6323671616816
# discriminator Mean Gradients : 2.381900563819439
# Mean Running Discriminator Loss : 0.021791251999923697
# Mean Running Generator Loss : 0.5328142563618762
# Generating and Saving Images to ./images/epoch267_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 368 Summary
# Epoch time duration : 683.557614326477
# generator Mean Gradients : 160.9998234873119
# discriminator Mean Gradients : 2.3765618825437236
# Mean Running Discriminator Loss : 0.02176195429445259
# Mean Running Generator Loss : 0.5328135891019296
# Generating and Saving Images to ./images/epoch268_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 369 Summary
# Epoch time duration : 980.4209415912628
# generator Mean Gradients : 161.61946242786112
# discriminator Mean Gradients : 2.37327258230059
# Mean Running Discriminator Loss : 0.021737692191122735
# Mean Running Generator Loss : 0.5328102606339833
# Generating and Saving Images to ./images/epoch269_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 370 Summary
# Epoch time duration : 717.4100391864777
# generator Mean Gradients : 161.3690745136904
# discriminator Mean Gradients : 2.3685752896720835
# Mean Running Discriminator Loss : 0.02170859739585507
# Mean Running Generator Loss : 0.5327904919923089
# Generating and Saving Images to ./images/epoch270_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 371 Summary
# Epoch time duration : 641.3222413063049
# generator Mean Gradients : 161.5169002235079
# discriminator Mean Gradients : 2.3651046758286576
# Mean Running Discriminator Loss : 0.021680845876297032
# Mean Running Generator Loss : 0.5327822031925723
# Generating and Saving Images to ./images/epoch271_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 372 Summary
# Epoch time duration : 639.2030653953552
# generator Mean Gradients : 161.67186700258947
# discriminator Mean Gradients : 2.3604407098032882
# Mean Running Discriminator Loss : 0.02165219085885223
# Mean Running Generator Loss : 0.5327698179065339
# Generating and Saving Images to ./images/epoch272_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 373 Summary
# Epoch time duration : 643.0737962722778
# generator Mean Gradients : 161.91368280878754
# discriminator Mean Gradients : 2.355544504291997
# Mean Running Discriminator Loss : 0.021623263447644547
# Mean Running Generator Loss : 0.5327597121039951
# Generating and Saving Images to ./images/epoch273_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 374 Summary
# Epoch time duration : 909.8572399616241
# generator Mean Gradients : 162.03791393331485
# discriminator Mean Gradients : 2.353047634214491
# Mean Running Discriminator Loss : 0.02159762520836913
# Mean Running Generator Loss : 0.5327459953543503
# Generating and Saving Images to ./images/epoch274_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 375 Summary
# Epoch time duration : 689.4754986763
# generator Mean Gradients : 162.3100632696661
# discriminator Mean Gradients : 2.3489977725745743
# Mean Running Discriminator Loss : 0.021569256048681255
# Mean Running Generator Loss : 0.5327332210159048
# Generating and Saving Images to ./images/epoch275_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 376 Summary
# Epoch time duration : 931.7834467887878
# generator Mean Gradients : 162.43328592684549
# discriminator Mean Gradients : 2.344283504177603
# Mean Running Discriminator Loss : 0.021538812579993846
# Mean Running Generator Loss : 0.5327284696814636
# Generating and Saving Images to ./images/epoch276_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 377 Summary
# Epoch time duration : 694.275390625
# generator Mean Gradients : 162.5272656334729
# discriminator Mean Gradients : 2.3402226796654335
# Mean Running Discriminator Loss : 0.02150947208159623
# Mean Running Generator Loss : 0.5327199146874357
# Generating and Saving Images to ./images/epoch277_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 378 Summary
# Epoch time duration : 730.2147796154022
# generator Mean Gradients : 162.56626349644648
# discriminator Mean Gradients : 2.3366295372706123
# Mean Running Discriminator Loss : 0.02148182265908224
# Mean Running Generator Loss : 0.5326943449242825
# Generating and Saving Images to ./images/epoch278_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 379 Summary
# Epoch time duration : 1031.5381968021393
# generator Mean Gradients : 162.95164372574428
# discriminator Mean Gradients : 2.3317134807684035
# Mean Running Discriminator Loss : 0.02145239492331539
# Mean Running Generator Loss : 0.5326904007036832
# Generating and Saving Images to ./images/epoch279_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 380 Summary
# Epoch time duration : 646.2665452957153
# generator Mean Gradients : 163.16727068455452
# discriminator Mean Gradients : 2.3275438271810476
# Mean Running Discriminator Loss : 0.02142496334062159
# Mean Running Generator Loss : 0.5326833313543763
# Generating and Saving Images to ./images/epoch280_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 381 Summary
# Epoch time duration : 642.4047408103943
# generator Mean Gradients : 163.06260862240356
# discriminator Mean Gradients : 2.321609538124452
# Mean Running Discriminator Loss : 0.021390256305849457
# Mean Running Generator Loss : 0.5326743291485511
# Generating and Saving Images to ./images/epoch281_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 382 Summary
# Epoch time duration : 643.5474462509155
# generator Mean Gradients : 163.39115714331083
# discriminator Mean Gradients : 2.316068776946951
# Mean Running Discriminator Loss : 0.021359472428228558
# Mean Running Generator Loss : 0.5326590066576281
# Generating and Saving Images to ./images/epoch282_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 383 Summary
# Epoch time duration : 838.7982375621796
# generator Mean Gradients : 163.47546517942317
# discriminator Mean Gradients : 2.3117968256903936
# Mean Running Discriminator Loss : 0.02133248961562651
# Mean Running Generator Loss : 0.5326505097665973
# Generating and Saving Images to ./images/epoch283_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 384 Summary
# Epoch time duration : 751.9617547988892
# generator Mean Gradients : 163.70067622004214
# discriminator Mean Gradients : 2.3068919999073683
# Mean Running Discriminator Loss : 0.021302886930946487
# Mean Running Generator Loss : 0.5326419155123719
# Generating and Saving Images to ./images/epoch284_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 385 Summary
# Epoch time duration : 656.620281457901
# generator Mean Gradients : 163.88101663230483
# discriminator Mean Gradients : 2.3027764094061642
# Mean Running Discriminator Loss : 0.021276734488421517
# Mean Running Generator Loss : 0.5326280694958271
# Generating and Saving Images to ./images/epoch285_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 386 Summary
# Epoch time duration : 633.085545539856
# generator Mean Gradients : 163.95270269889144
# discriminator Mean Gradients : 2.299030743577193
# Mean Running Discriminator Loss : 0.021252782939011877
# Mean Running Generator Loss : 0.532619988816825
# Generating and Saving Images to ./images/epoch286_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 387 Summary
# Epoch time duration : 634.4045298099518
# generator Mean Gradients : 164.49284664789798
# discriminator Mean Gradients : 2.2939521666379683
# Mean Running Discriminator Loss : 0.021224110797057345
# Mean Running Generator Loss : 0.5326227404504885
# Generating and Saving Images to ./images/epoch287_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 388 Summary
# Epoch time duration : 705.3242335319519
# generator Mean Gradients : 164.68706763276933
# discriminator Mean Gradients : 2.2894458538969102
# Mean Running Discriminator Loss : 0.021197299528396645
# Mean Running Generator Loss : 0.532615077478783
# Generating and Saving Images to ./images/epoch288_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 389 Summary
# Epoch time duration : 888.1758127212524
# generator Mean Gradients : 165.04632962894635
# discriminator Mean Gradients : 2.2862762029900345
# Mean Running Discriminator Loss : 0.021173275217199142
# Mean Running Generator Loss : 0.5326008293368356
# Generating and Saving Images to ./images/epoch289_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 390 Summary
# Epoch time duration : 643.1540944576263
# generator Mean Gradients : 165.4935763256686
# discriminator Mean Gradients : 2.282968499975021
# Mean Running Discriminator Loss : 0.021150415388227577
# Mean Running Generator Loss : 0.5325918640106494
# Generating and Saving Images to ./images/epoch290_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 391 Summary
# Epoch time duration : 672.0203428268433
# generator Mean Gradients : 165.28492242240026
# discriminator Mean Gradients : 2.2781961464140177
# Mean Running Discriminator Loss : 0.02112127283897496
# Mean Running Generator Loss : 0.5325772476002413
# Generating and Saving Images to ./images/epoch291_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 392 Summary
# Epoch time duration : 639.2359828948975
# generator Mean Gradients : 165.46817923236247
# discriminator Mean Gradients : 2.274008184041541
# Mean Running Discriminator Loss : 0.021093450408583892
# Mean Running Generator Loss : 0.5325667764703996
# Generating and Saving Images to ./images/epoch292_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 393 Summary
# Epoch time duration : 685.0985231399536
# generator Mean Gradients : 165.31241721384404
# discriminator Mean Gradients : 2.269597796006941
# Mean Running Discriminator Loss : 0.021065874855051146
# Mean Running Generator Loss : 0.5325556512380126
# Generating and Saving Images to ./images/epoch293_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 394 Summary
# Epoch time duration : 945.3349940776825
# generator Mean Gradients : 165.19241973503057
# discriminator Mean Gradients : 2.2662609570690404
# Mean Running Discriminator Loss : 0.021041317418693327
# Mean Running Generator Loss : 0.5325457918779862
# Generating and Saving Images to ./images/epoch294_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 395 Summary
# Epoch time duration : 652.1583940982819
# generator Mean Gradients : 164.88025874369987
# discriminator Mean Gradients : 2.2640337540243016
# Mean Running Discriminator Loss : 0.021019545534466125
# Mean Running Generator Loss : 0.5325463920588077
# Generating and Saving Images to ./images/epoch295_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 396 Summary
# Epoch time duration : 645.8101477622986
# generator Mean Gradients : 164.8980655243639
# discriminator Mean Gradients : 2.2608343291105144
# Mean Running Discriminator Loss : 0.02099694213307279
# Mean Running Generator Loss : 0.5325469996331409
# Generating and Saving Images to ./images/epoch296_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 397 Summary
# Epoch time duration : 643.5346391201019
# generator Mean Gradients : 164.96775819185405
# discriminator Mean Gradients : 2.2564764952432537
# Mean Running Discriminator Loss : 0.020971899139828887
# Mean Running Generator Loss : 0.5325195411615202
# Generating and Saving Images to ./images/epoch297_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 398 Summary
# Epoch time duration : 646.4794204235077
# generator Mean Gradients : 165.24781849934047
# discriminator Mean Gradients : 2.252480156459589
# Mean Running Discriminator Loss : 0.02094632763245352
# Mean Running Generator Loss : 0.5325066228651206
# Generating and Saving Images to ./images/epoch298_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 399 Summary
# Epoch time duration : 1216.0973689556122
# generator Mean Gradients : 165.17275128343206
# discriminator Mean Gradients : 2.2479428848991154
# Mean Running Discriminator Loss : 0.020918010457500354
# Mean Running Generator Loss : 0.5324884639318206
# Generating and Saving Images to ./images/epoch299_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 400 Summary
# Epoch time duration : 684.9025213718414
# generator Mean Gradients : 165.39848373919511
# discriminator Mean Gradients : 2.243838390151593
# Mean Running Discriminator Loss : 0.0208913470805583
# Mean Running Generator Loss : 0.5324795175087341
# Generating and Saving Images to ./images/epoch300_generator.png
#
# Training of the Model is Complete
