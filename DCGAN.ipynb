# %% [markdown]
# This first cell makes sure that torchgan is installed. It's primarily here for use with colab, since colab doesn't have torchgan installed by default.

# %%
# from torchGAN tutorial

try:
    import torchgan

    print(f"Existing TorchGAN {torchgan.__version__} installation found")
except ImportError:
    import subprocess
    import sys

    subprocess.check_call([sys.executable, "-m", "pip", "install", "torchgan"])
    import torchgan

    print(f"Installed TorchGAN {torchgan.__version__}")
# Out:
# Existing TorchGAN v0.1.0 installation found

# %%
import torch
import torch.nn as nn
import torch.backends.cudnn
import torch.utils.data as tdata
from torch.optim import Adam
import torchvision
import torchvision.datasets as dsets
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import torchgan
from torchgan.models import *
from torchgan.losses import *
from torchgan.trainer import Trainer

# %% [markdown]
# This cell takes care of creating the dataset. Any PNG or JPEG image files are acceptable. The models require that the width and height of the images are equal, and that the dimensions of the image are a perfect power of 2, but those can both be overcome by scaling the images.
#
# The size variable is how big the generated images will be. Larger images can be more detailed, but dramatically slow down the training process. Additionally, as mentioned above, this value must be a perfect power of 2.
#
# If your images are in black and white, or if you wish to convert them to black and white, set grayscale to True in line 2.
#
# Due to the way that torchvision works, the file path provided in line 3 cannot be the exact folder that holds the images. In order for the path to be recognized properly, you must specify the folder that contains the folder with the images.
#
# For copyright reasons, the images that I am training from are not included with the GitHub repo. If you are interested in learning more, the citations for all of the images are included in the bibliography of the accompanying report.

# %%
size = 128
grayscale = False   # change this to True if your images are in black and white
folder = "./data/otherGANGogh/images/landscape/"

if grayscale:
    channels = 1
    data = ImageFolder(
        root=folder,
        transform=transforms.Compose([
            transforms.Resize((size, size)),
            transforms.ToTensor(),
            transforms.Grayscale(),
            transforms.Normalize(mean=.5, std=.5)
        ])
    )
else:
    channels = 3
    data = ImageFolder(
        root=folder,
        transform=transforms.Compose([
            transforms.Resize((size, size)),
            transforms.ToTensor(),
            transforms.Normalize(mean=.5, std=.5)
        ])
    )
print(len(data))
# Out:
# 15000

# %%
dataloader = tdata.DataLoader(data, batch_size=64, shuffle=True)

# %%
# adapted from torchgan tutorial

dcgan_network = {
    "generator": {
        "name": DCGANGenerator,
        "args": {
            "encoding_dims": 100,
            "out_size": size,           # this is how many pixels wide and tall the generated images will be
            "out_channels": channels,
            "step_channels": 32,
            "nonlinearity": nn.LeakyReLU(0.2),
            "last_nonlinearity": nn.Tanh(),
        },
        "optimizer": {"name": Adam, "args": {"lr": 0.0001, "betas": (0.5, 0.999)}},
    },
    "discriminator": {
        "name": DCGANDiscriminator,
        "args": {
            "in_size": size,            # this is how many pixels wide and tall we resized the images to be.
            "in_channels": channels,
            "step_channels": 32,
            "nonlinearity": nn.LeakyReLU(0.2),
            "last_nonlinearity": nn.LeakyReLU(0.2),
        },
        "optimizer": {"name": Adam, "args": {"lr": 0.0003, "betas": (0.5, 0.999)}},
    },
}

# %%
# from torchgan tutorial

minimax_losses = [MinimaxGeneratorLoss(), MinimaxDiscriminatorLoss()]
wgangp_losses = [
    WassersteinGeneratorLoss(),
    WassersteinDiscriminatorLoss(),
    WassersteinGradientPenalty(),
]
lsgan_losses = [LeastSquaresGeneratorLoss(), LeastSquaresDiscriminatorLoss()]

# %% [markdown]
# If you're running this on colab, be sure to select a GPU runtime for the best performance.

# %%
# more from torchgan tutorial

if torch.cuda.is_available():
    device = torch.device("cuda:0")
    # Use deterministic cudnn algorithms
    torch.backends.cudnn.deterministic = True
    epochs = 10
else:
    device = torch.device("cpu")
    epochs = 5

print("Device: {}".format(device))
print("Epochs: {}".format(epochs))
# Out:
# Device: cpu
# Epochs: 5

# %%
# from torchgan tutorial
epochs = 600    # you can override the number of epochs here if you want to try to get better results

trainer = Trainer(
    dcgan_network,
    lsgan_losses,
    sample_size=64,
    epochs=epochs,
    device=device
)

# %% [markdown]
# This is the cell that actually does the training. After it finishes, use the next cell if you want to keep training the same model.

# %%
trainer(dataloader)
# Out:
# c:\users\leafy\pycharmprojects\gangogh\venv\lib\site-packages\PIL\TiffImagePlugin.py:845: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# Saving Model at './model/gan0.model'
# Epoch 1 Summary
# Epoch time duration : 1003.3898904323578
# generator Mean Gradients : 36.18075446934572
# discriminator Mean Gradients : 367.2088514130637
# Mean Running Discriminator Loss : 0.36510538287619326
# Mean Running Generator Loss : 0.8458863792901343
# c:\users\leafy\pycharmprojects\gangogh\venv\lib\site-packages\torchvision\utils.py:68: UserWarning: The parameter 'range' is deprecated since 0.12 and will be removed in 0.14. Please use 'value_range' instead.
#   warnings.warn(
# Generating and Saving Images to ./images/epoch1_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 2 Summary
# Epoch time duration : 856.2223539352417
# generator Mean Gradients : 19.761261659166436
# discriminator Mean Gradients : 256.79356252814733
# Mean Running Discriminator Loss : 0.2177339577472749
# Mean Running Generator Loss : 0.7154120697937113
# Generating and Saving Images to ./images/epoch2_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 3 Summary
# Epoch time duration : 669.5286500453949
# generator Mean Gradients : 13.850664039708674
# discriminator Mean Gradients : 220.01047040482334
# Mean Running Discriminator Loss : 0.1688748215080787
# Mean Running Generator Loss : 0.6690223753663666
# Generating and Saving Images to ./images/epoch3_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 4 Summary
# Epoch time duration : 720.5223140716553
# generator Mean Gradients : 10.758290492662736
# discriminator Mean Gradients : 191.93496075266353
# Mean Running Discriminator Loss : 0.1394829614855785
# Mean Running Generator Loss : 0.6447378350540679
# Generating and Saving Images to ./images/epoch4_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 5 Summary
# Epoch time duration : 709.4125661849976
# generator Mean Gradients : 8.886492547201936
# discriminator Mean Gradients : 171.54267443770553
# Mean Running Discriminator Loss : 0.11929052387007531
# Mean Running Generator Loss : 0.6316478937103394
# Generating and Saving Images to ./images/epoch5_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 6 Summary
# Epoch time duration : 638.6733846664429
# generator Mean Gradients : 7.578489533742412
# discriminator Mean Gradients : 158.52084717295375
# Mean Running Discriminator Loss : 0.10537700273165915
# Mean Running Generator Loss : 0.620856658543678
# Generating and Saving Images to ./images/epoch6_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 7 Summary
# Epoch time duration : 638.7959151268005
# generator Mean Gradients : 6.622244679571095
# discriminator Mean Gradients : 147.2284286660172
# Mean Running Discriminator Loss : 0.09527790586203676
# Mean Running Generator Loss : 0.6126432205315419
# Generating and Saving Images to ./images/epoch7_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 8 Summary
# Epoch time duration : 641.0729598999023
# generator Mean Gradients : 5.885809913857862
# discriminator Mean Gradients : 136.60091991479382
# Mean Running Discriminator Loss : 0.0868942148810094
# Mean Running Generator Loss : 0.6052941916708616
# Generating and Saving Images to ./images/epoch8_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 9 Summary
# Epoch time duration : 640.4323379993439
# generator Mean Gradients : 5.2938261693440625
# discriminator Mean Gradients : 128.87989400914495
# Mean Running Discriminator Loss : 0.08042447085549558
# Mean Running Generator Loss : 0.5995297863057882
# Generating and Saving Images to ./images/epoch9_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 10 Summary
# Epoch time duration : 755.0260453224182
# generator Mean Gradients : 4.840512738693249
# discriminator Mean Gradients : 130.0406417869379
# Mean Running Discriminator Loss : 0.08051809779834002
# Mean Running Generator Loss : 0.5958385660990756
# Generating and Saving Images to ./images/epoch10_generator.png
#
# Training of the Model is Complete

# %% [markdown]
# Use this cell instead of the previous one if you want to resume training a model that you saved from a previous session. Be sure to use the correct file path and file name when you call the function.

# %%
model = "./model/gan4.model"

trainer.load_model(model)
trainer(dataloader)
# Out:
# Loading Model From './model/gan4.model' to cpu
# Saving Model at './model/gan0.model'
# Epoch 501 Summary
# Epoch time duration : 849.099627494812
# generator Mean Gradients : 343.6072481685793
# discriminator Mean Gradients : 0.8343204645079003
# Mean Running Discriminator Loss : 0.01868517240765389
# Mean Running Generator Loss : 0.5319313378890768
# Generating and Saving Images to ./images/epoch1_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 502 Summary
# Epoch time duration : 646.4704420566559
# generator Mean Gradients : 327.3514797824977
# discriminator Mean Gradients : 0.8690548850574932
# Mean Running Discriminator Loss : 0.018668995128791242
# Mean Running Generator Loss : 0.5319344092815397
# Generating and Saving Images to ./images/epoch2_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 503 Summary
# Epoch time duration : 643.3590445518494
# generator Mean Gradients : 326.77904700835614
# discriminator Mean Gradients : 0.827618076718517
# Mean Running Discriminator Loss : 0.018650542335379477
# Mean Running Generator Loss : 0.5319225420449952
# Generating and Saving Images to ./images/epoch3_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 504 Summary
# Epoch time duration : 645.6147499084473
# generator Mean Gradients : 317.264476975237
# discriminator Mean Gradients : 0.8110449574678835
# Mean Running Discriminator Loss : 0.01863133465958674
# Mean Running Generator Loss : 0.5319146562261681
# Generating and Saving Images to ./images/epoch4_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 505 Summary
# Epoch time duration : 649.1409964561462
# generator Mean Gradients : 332.8588694479571
# discriminator Mean Gradients : 0.7975093422959191
# Mean Running Discriminator Loss : 0.01861201722753747
# Mean Running Generator Loss : 0.5319037196409622
# Generating and Saving Images to ./images/epoch5_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 506 Summary
# Epoch time duration : 1019.3526446819305
# generator Mean Gradients : 327.05165693227394
# discriminator Mean Gradients : 0.817450518685728
# Mean Running Discriminator Loss : 0.018594828896324477
# Mean Running Generator Loss : 0.5318995553402388
# Generating and Saving Images to ./images/epoch6_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 507 Summary
# Epoch time duration : 663.6656877994537
# generator Mean Gradients : 346.32770253501883
# discriminator Mean Gradients : 0.8186512500535293
# Mean Running Discriminator Loss : 0.018577572986755556
# Mean Running Generator Loss : 0.5318919376206999
# Generating and Saving Images to ./images/epoch7_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 508 Summary
# Epoch time duration : 641.2533144950867
# generator Mean Gradients : 338.02869311682434
# discriminator Mean Gradients : 0.8666977185383558
# Mean Running Discriminator Loss : 0.018563329862140442
# Mean Running Generator Loss : 0.5318807738314341
# Generating and Saving Images to ./images/epoch8_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 509 Summary
# Epoch time duration : 643.1747894287109
# generator Mean Gradients : 328.1569152641493
# discriminator Mean Gradients : 0.8582605237383184
# Mean Running Discriminator Loss : 0.018545635077165966
# Mean Running Generator Loss : 0.5318816546709964
# Generating and Saving Images to ./images/epoch9_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 510 Summary
# Epoch time duration : 641.4662039279938
# generator Mean Gradients : 326.56120525671236
# discriminator Mean Gradients : 0.8373829174188886
# Mean Running Discriminator Loss : 0.018527284144907823
# Mean Running Generator Loss : 0.5318761882449209
# Generating and Saving Images to ./images/epoch10_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 511 Summary
# Epoch time duration : 802.416109085083
# generator Mean Gradients : 324.0858229334128
# discriminator Mean Gradients : 0.8232702749396091
# Mean Running Discriminator Loss : 0.018509134472598766
# Mean Running Generator Loss : 0.5318777230031354
# Generating and Saving Images to ./images/epoch11_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 512 Summary
# Epoch time duration : 709.5782327651978
# generator Mean Gradients : 318.64397319144405
# discriminator Mean Gradients : 0.8085506794585501
# Mean Running Discriminator Loss : 0.018489486914256517
# Mean Running Generator Loss : 0.531864536409062
# Generating and Saving Images to ./images/epoch12_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 513 Summary
# Epoch time duration : 641.5139904022217
# generator Mean Gradients : 319.79134770811544
# discriminator Mean Gradients : 0.7957639631799461
# Mean Running Discriminator Loss : 0.018470198135918766
# Mean Running Generator Loss : 0.5318574211158436
# Generating and Saving Images to ./images/epoch13_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 514 Summary
# Epoch time duration : 641.1890051364899
# generator Mean Gradients : 322.3527289300559
# discriminator Mean Gradients : 0.8026919930688519
# Mean Running Discriminator Loss : 0.018453748372024077
# Mean Running Generator Loss : 0.5318523339170049
# Generating and Saving Images to ./images/epoch14_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 515 Summary
# Epoch time duration : 649.777402639389
# generator Mean Gradients : 327.32477893333345
# discriminator Mean Gradients : 0.8040729633862755
# Mean Running Discriminator Loss : 0.018436533333074767
# Mean Running Generator Loss : 0.5318515988240321
# Generating and Saving Images to ./images/epoch15_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 516 Summary
# Epoch time duration : 833.3787786960602
# generator Mean Gradients : 319.25501719498186
# discriminator Mean Gradients : 0.8141906172067904
# Mean Running Discriminator Loss : 0.018419845523507193
# Mean Running Generator Loss : 0.5318466516692113
# Generating and Saving Images to ./images/epoch16_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 517 Summary
# Epoch time duration : 859.2401812076569
# generator Mean Gradients : 317.1809953307006
# discriminator Mean Gradients : 0.8308350424701656
# Mean Running Discriminator Loss : 0.01840443194143219
# Mean Running Generator Loss : 0.5318370325634254
# Generating and Saving Images to ./images/epoch17_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 518 Summary
# Epoch time duration : 673.6640145778656
# generator Mean Gradients : 316.17679469916345
# discriminator Mean Gradients : 0.8484668627987341
# Mean Running Discriminator Loss : 0.018390687521557827
# Mean Running Generator Loss : 0.5318339561017585
# Generating and Saving Images to ./images/epoch18_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 519 Summary
# Epoch time duration : 670.1201705932617
# generator Mean Gradients : 314.9012454107054
# discriminator Mean Gradients : 0.8402478805236933
# Mean Running Discriminator Loss : 0.01837219054966305
# Mean Running Generator Loss : 0.5318214443659597
# Generating and Saving Images to ./images/epoch19_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 520 Summary
# Epoch time duration : 651.4438409805298
# generator Mean Gradients : 312.28315972786555
# discriminator Mean Gradients : 0.8450279187865725
# Mean Running Discriminator Loss : 0.018355862341352294
# Mean Running Generator Loss : 0.5318088661579022
# Generating and Saving Images to ./images/epoch20_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 521 Summary
# Epoch time duration : 955.7379004955292
# generator Mean Gradients : 311.187393716619
# discriminator Mean Gradients : 0.8375147079589346
# Mean Running Discriminator Loss : 0.018338327162135216
# Mean Running Generator Loss : 0.5318005469130392
# Generating and Saving Images to ./images/epoch21_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 522 Summary
# Epoch time duration : 732.269957780838
# generator Mean Gradients : 314.473956310303
# discriminator Mean Gradients : 0.8350361100281172
# Mean Running Discriminator Loss : 0.01832112516973588
# Mean Running Generator Loss : 0.5317920656553327
# Generating and Saving Images to ./images/epoch22_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 523 Summary
# Epoch time duration : 653.1033837795258
# generator Mean Gradients : 313.28403189393794
# discriminator Mean Gradients : 0.8286275554716899
# Mean Running Discriminator Loss : 0.01830230445348542
# Mean Running Generator Loss : 0.5317789580571591
# Generating and Saving Images to ./images/epoch23_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 524 Summary
# Epoch time duration : 645.9923377037048
# generator Mean Gradients : 311.7174306733085
# discriminator Mean Gradients : 0.8197183620741899
# Mean Running Discriminator Loss : 0.01828277614824653
# Mean Running Generator Loss : 0.5317607516176612
# Generating and Saving Images to ./images/epoch24_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 525 Summary
# Epoch time duration : 647.8876852989197
# generator Mean Gradients : 311.2566061879495
# discriminator Mean Gradients : 0.8276559595074976
# Mean Running Discriminator Loss : 0.018267178584166672
# Mean Running Generator Loss : 0.531754167547674
# Generating and Saving Images to ./images/epoch25_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 526 Summary
# Epoch time duration : 1039.2347271442413
# generator Mean Gradients : 311.7454392103903
# discriminator Mean Gradients : 0.8352790401948226
# Mean Running Discriminator Loss : 0.018251391401073916
# Mean Running Generator Loss : 0.5317466154863025
# Generating and Saving Images to ./images/epoch26_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 527 Summary
# Epoch time duration : 694.5104787349701
# generator Mean Gradients : 313.64763087892715
# discriminator Mean Gradients : 0.8370332702418991
# Mean Running Discriminator Loss : 0.01823522354234628
# Mean Running Generator Loss : 0.5317439641466454
# Generating and Saving Images to ./images/epoch27_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 528 Summary
# Epoch time duration : 645.9949817657471
# generator Mean Gradients : 315.5259527986076
# discriminator Mean Gradients : 0.8406311145685662
# Mean Running Discriminator Loss : 0.01821924584793334
# Mean Running Generator Loss : 0.531740793049291
# Generating and Saving Images to ./images/epoch28_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 529 Summary
# Epoch time duration : 645.5705604553223
# generator Mean Gradients : 317.00666724370575
# discriminator Mean Gradients : 0.8350840475709274
# Mean Running Discriminator Loss : 0.018201593481578585
# Mean Running Generator Loss : 0.5317338326248355
# Generating and Saving Images to ./images/epoch29_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 530 Summary
# Epoch time duration : 645.2052156925201
# generator Mean Gradients : 317.8891940642267
# discriminator Mean Gradients : 0.8331088638954817
# Mean Running Discriminator Loss : 0.01818463466251613
# Mean Running Generator Loss : 0.531721856020382
# Generating and Saving Images to ./images/epoch30_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 531 Summary
# Epoch time duration : 806.2757575511932
# generator Mean Gradients : 313.28329755196427
# discriminator Mean Gradients : 0.8168545927594413
# Mean Running Discriminator Loss : 0.018160230845067623
# Mean Running Generator Loss : 0.5317034342603975
# Generating and Saving Images to ./images/epoch31_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 532 Summary
# Epoch time duration : 680.2962348461151
# generator Mean Gradients : 316.5766299238685
# discriminator Mean Gradients : 0.8191676935819578
# Mean Running Discriminator Loss : 0.018143190425084128
# Mean Running Generator Loss : 0.5316957071946478
# Generating and Saving Images to ./images/epoch32_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 533 Summary
# Epoch time duration : 641.6234865188599
# generator Mean Gradients : 315.3181234839174
# discriminator Mean Gradients : 0.823935626333233
# Mean Running Discriminator Loss : 0.01812687302514251
# Mean Running Generator Loss : 0.5316929879434406
# Generating and Saving Images to ./images/epoch33_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 534 Summary
# Epoch time duration : 643.3755309581757
# generator Mean Gradients : 318.05825303537796
# discriminator Mean Gradients : 0.8188252319146757
# Mean Running Discriminator Loss : 0.018108768366528694
# Mean Running Generator Loss : 0.5316830114199578
# Generating and Saving Images to ./images/epoch34_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 535 Summary
# Epoch time duration : 644.5714185237885
# generator Mean Gradients : 318.0225311972631
# discriminator Mean Gradients : 0.8238126375768282
# Mean Running Discriminator Loss : 0.018093230252681593
# Mean Running Generator Loss : 0.5316814743525218
# Generating and Saving Images to ./images/epoch35_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 536 Summary
# Epoch time duration : 922.4859323501587
# generator Mean Gradients : 318.5493956233494
# discriminator Mean Gradients : 0.8201605309975666
# Mean Running Discriminator Loss : 0.01807586366379977
# Mean Running Generator Loss : 0.5316718677593831
# Generating and Saving Images to ./images/epoch36_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 537 Summary
# Epoch time duration : 748.7579154968262
# generator Mean Gradients : 319.27080612141606
# discriminator Mean Gradients : 0.8241691685598385
# Mean Running Discriminator Loss : 0.01806139021388853
# Mean Running Generator Loss : 0.531659853710949
# Generating and Saving Images to ./images/epoch37_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 538 Summary
# Epoch time duration : 639.052985906601
# generator Mean Gradients : 320.44356923678015
# discriminator Mean Gradients : 0.8254420058431866
# Mean Running Discriminator Loss : 0.018044269174207334
# Mean Running Generator Loss : 0.5316574410374588
# Generating and Saving Images to ./images/epoch38_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 539 Summary
# Epoch time duration : 635.5920238494873
# generator Mean Gradients : 319.9766385297846
# discriminator Mean Gradients : 0.8334047461116968
# Mean Running Discriminator Loss : 0.01803176446478546
# Mean Running Generator Loss : 0.5316530439686663
# Generating and Saving Images to ./images/epoch39_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 540 Summary
# Epoch time duration : 640.0897746086121
# generator Mean Gradients : 320.71161761271327
# discriminator Mean Gradients : 0.838946641180173
# Mean Running Discriminator Loss : 0.018017339469464804
# Mean Running Generator Loss : 0.5316572080792124
# Generating and Saving Images to ./images/epoch40_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 541 Summary
# Epoch time duration : 872.4668726921082
# generator Mean Gradients : 323.9207722054613
# discriminator Mean Gradients : 0.8337472835169113
# Mean Running Discriminator Loss : 0.01799983992908764
# Mean Running Generator Loss : 0.5316604830058882
# Generating and Saving Images to ./images/epoch41_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 542 Summary
# Epoch time duration : 814.6887304782867
# generator Mean Gradients : 328.29209830313994
# discriminator Mean Gradients : 0.8269275141366889
# Mean Running Discriminator Loss : 0.017981999410861857
# Mean Running Generator Loss : 0.5316593681156396
# Generating and Saving Images to ./images/epoch42_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 543 Summary
# Epoch time duration : 646.8099918365479
# generator Mean Gradients : 327.38475727628116
# discriminator Mean Gradients : 0.8297634430845049
# Mean Running Discriminator Loss : 0.017966426348186588
# Mean Running Generator Loss : 0.5316626815843589
# Generating and Saving Images to ./images/epoch43_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 544 Summary
# Epoch time duration : 645.5458338260651
# generator Mean Gradients : 327.92824973538654
# discriminator Mean Gradients : 0.8263749417186702
# Mean Running Discriminator Loss : 0.017950912872452655
# Mean Running Generator Loss : 0.5316596045760258
# Generating and Saving Images to ./images/epoch44_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 545 Summary
# Epoch time duration : 640.4453103542328
# generator Mean Gradients : 327.24343294681427
# discriminator Mean Gradients : 0.8199417283415883
# Mean Running Discriminator Loss : 0.01793276459396139
# Mean Running Generator Loss : 0.5316454377618591
# Generating and Saving Images to ./images/epoch45_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 546 Summary
# Epoch time duration : 1038.523639678955
# generator Mean Gradients : 327.1854147004589
# discriminator Mean Gradients : 0.8175456483498692
# Mean Running Discriminator Loss : 0.017916437771146328
# Mean Running Generator Loss : 0.53163639228109
# Generating and Saving Images to ./images/epoch46_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 547 Summary
# Epoch time duration : 867.9889039993286
# generator Mean Gradients : 327.11779273799976
# discriminator Mean Gradients : 0.813243322592355
# Mean Running Discriminator Loss : 0.017898790832787566
# Mean Running Generator Loss : 0.5316267042830479
# Generating and Saving Images to ./images/epoch47_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 548 Summary
# Epoch time duration : 642.9381024837494
# generator Mean Gradients : 324.9688034201786
# discriminator Mean Gradients : 0.815782517290733
# Mean Running Discriminator Loss : 0.01788432006902716
# Mean Running Generator Loss : 0.5316149716895686
# Generating and Saving Images to ./images/epoch48_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 549 Summary
# Epoch time duration : 641.9403688907623
# generator Mean Gradients : 324.5718658740747
# discriminator Mean Gradients : 0.815278670456815
# Mean Running Discriminator Loss : 0.017869239618177876
# Mean Running Generator Loss : 0.5316181252351571
# Generating and Saving Images to ./images/epoch49_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 550 Summary
# Epoch time duration : 648.0213096141815
# generator Mean Gradients : 326.1056757476045
# discriminator Mean Gradients : 0.8129637119244324
# Mean Running Discriminator Loss : 0.017853523289174115
# Mean Running Generator Loss : 0.5316172282136616
# Generating and Saving Images to ./images/epoch50_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 551 Summary
# Epoch time duration : 882.7941887378693
# generator Mean Gradients : 328.4358189453102
# discriminator Mean Gradients : 0.8075630727766848
# Mean Running Discriminator Loss : 0.017836650509236426
# Mean Running Generator Loss : 0.5316096117627728
# Generating and Saving Images to ./images/epoch51_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 552 Summary
# Epoch time duration : 700.6979758739471
# generator Mean Gradients : 328.6828405524241
# discriminator Mean Gradients : 0.8076363957843696
# Mean Running Discriminator Loss : 0.01782052798090848
# Mean Running Generator Loss : 0.5316050673635965
# Generating and Saving Images to ./images/epoch52_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 553 Summary
# Epoch time duration : 635.0561368465424
# generator Mean Gradients : 329.1253368034626
# discriminator Mean Gradients : 0.8097289706448776
# Mean Running Discriminator Loss : 0.01780634016797185
# Mean Running Generator Loss : 0.5316069925989726
# Generating and Saving Images to ./images/epoch53_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 554 Summary
# Epoch time duration : 681.7697806358337
# generator Mean Gradients : 330.3919272851328
# discriminator Mean Gradients : 0.8092966133634715
# Mean Running Discriminator Loss : 0.017790135570673174
# Mean Running Generator Loss : 0.5316045204008245
# Generating and Saving Images to ./images/epoch54_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 555 Summary
# Epoch time duration : 637.4782090187073
# generator Mean Gradients : 330.61923704576657
# discriminator Mean Gradients : 0.8099758469371261
# Mean Running Discriminator Loss : 0.017775093120040265
# Mean Running Generator Loss : 0.5316000928501985
# Generating and Saving Images to ./images/epoch55_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 556 Summary
# Epoch time duration : 985.992161989212
# generator Mean Gradients : 331.62743210194856
# discriminator Mean Gradients : 0.8075579491910656
# Mean Running Discriminator Loss : 0.017758206390755354
# Mean Running Generator Loss : 0.5315902151087561
# Generating and Saving Images to ./images/epoch56_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 557 Summary
# Epoch time duration : 728.4169955253601
# generator Mean Gradients : 333.9944074700753
# discriminator Mean Gradients : 0.8062216514730487
# Mean Running Discriminator Loss : 0.01774231541652516
# Mean Running Generator Loss : 0.5315860444162522
# Generating and Saving Images to ./images/epoch57_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 558 Summary
# Epoch time duration : 634.8968632221222
# generator Mean Gradients : 336.58583639421073
# discriminator Mean Gradients : 0.8092345405649808
# Mean Running Discriminator Loss : 0.01772961280403515
# Mean Running Generator Loss : 0.5315772114343322
# Generating and Saving Images to ./images/epoch58_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 559 Summary
# Epoch time duration : 664.5813825130463
# generator Mean Gradients : 338.07020022857455
# discriminator Mean Gradients : 0.8064393832566547
# Mean Running Discriminator Loss : 0.01771317215401211
# Mean Running Generator Loss : 0.531567103101716
# Generating and Saving Images to ./images/epoch59_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 560 Summary
# Epoch time duration : 648.4760916233063
# generator Mean Gradients : 340.73948484998556
# discriminator Mean Gradients : 0.8045982385846512
# Mean Running Discriminator Loss : 0.01769689624678127
# Mean Running Generator Loss : 0.5315588724463726
# Generating and Saving Images to ./images/epoch60_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 561 Summary
# Epoch time duration : 968.4681217670441
# generator Mean Gradients : 343.4130977880028
# discriminator Mean Gradients : 0.8026162295757956
# Mean Running Discriminator Loss : 0.017681316584087652
# Mean Running Generator Loss : 0.5315589699289627
# Generating and Saving Images to ./images/epoch61_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 562 Summary
# Epoch time duration : 767.5450065135956
# generator Mean Gradients : 342.5833181646532
# discriminator Mean Gradients : 0.8032629948627024
# Mean Running Discriminator Loss : 0.01766699333204855
# Mean Running Generator Loss : 0.5315543617509086
# Generating and Saving Images to ./images/epoch62_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 563 Summary
# Epoch time duration : 648.1771156787872
# generator Mean Gradients : 342.2421395030588
# discriminator Mean Gradients : 0.8021863122572757
# Mean Running Discriminator Loss : 0.017652439205471524
# Mean Running Generator Loss : 0.5315486462083084
# Generating and Saving Images to ./images/epoch63_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 564 Summary
# Epoch time duration : 638.6290266513824
# generator Mean Gradients : 338.7170764607626
# discriminator Mean Gradients : 0.8157519055390394
# Mean Running Discriminator Loss : 0.017643991758697262
# Mean Running Generator Loss : 0.5315375804599817
# Generating and Saving Images to ./images/epoch64_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 565 Summary
# Epoch time duration : 639.8423397541046
# generator Mean Gradients : 335.6596588516783
# discriminator Mean Gradients : 0.8218114700056451
# Mean Running Discriminator Loss : 0.017633608646688743
# Mean Running Generator Loss : 0.531544952407729
# Generating and Saving Images to ./images/epoch65_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 566 Summary
# Epoch time duration : 1182.2405188083649
# generator Mean Gradients : 334.06508247645314
# discriminator Mean Gradients : 0.8192135947171572
# Mean Running Discriminator Loss : 0.01761880024164312
# Mean Running Generator Loss : 0.5315374804354415
# Generating and Saving Images to ./images/epoch66_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 567 Summary
# Epoch time duration : 727.1173706054688
# generator Mean Gradients : 333.1267688000785
# discriminator Mean Gradients : 0.8165826586247243
# Mean Running Discriminator Loss : 0.01760283567040992
# Mean Running Generator Loss : 0.5315287669574643
# Generating and Saving Images to ./images/epoch67_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 568 Summary
# Epoch time duration : 647.839371919632
# generator Mean Gradients : 333.218457099724
# discriminator Mean Gradients : 0.8161484775427675
# Mean Running Discriminator Loss : 0.017588638326726757
# Mean Running Generator Loss : 0.5315225519261113
# Generating and Saving Images to ./images/epoch68_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 569 Summary
# Epoch time duration : 642.8879768848419
# generator Mean Gradients : 331.43036985938585
# discriminator Mean Gradients : 0.8167546863298809
# Mean Running Discriminator Loss : 0.01757460827674543
# Mean Running Generator Loss : 0.5315177460315763
# Generating and Saving Images to ./images/epoch69_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 570 Summary
# Epoch time duration : 764.2657022476196
# generator Mean Gradients : 331.5395557715797
# discriminator Mean Gradients : 0.8179884888085296
# Mean Running Discriminator Loss : 0.01756135653852151
# Mean Running Generator Loss : 0.5315094987462375
# Generating and Saving Images to ./images/epoch70_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 571 Summary
# Epoch time duration : 797.5348529815674
# generator Mean Gradients : 330.1825256381938
# discriminator Mean Gradients : 0.8179862549535545
# Mean Running Discriminator Loss : 0.01754696743030336
# Mean Running Generator Loss : 0.5315030971295956
# Generating and Saving Images to ./images/epoch71_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 572 Summary
# Epoch time duration : 647.5090417861938
# generator Mean Gradients : 331.01712430360544
# discriminator Mean Gradients : 0.8164427772552595
# Mean Running Discriminator Loss : 0.01753203623051057
# Mean Running Generator Loss : 0.5314898770968219
# Generating and Saving Images to ./images/epoch72_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 573 Summary
# Epoch time duration : 636.4667532444
# generator Mean Gradients : 330.3319074706207
# discriminator Mean Gradients : 0.8166588005895017
# Mean Running Discriminator Loss : 0.017518905503042494
# Mean Running Generator Loss : 0.531483509669501
# Generating and Saving Images to ./images/epoch73_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 574 Summary
# Epoch time duration : 636.249495267868
# generator Mean Gradients : 327.9484523893943
# discriminator Mean Gradients : 0.8195488772438404
# Mean Running Discriminator Loss : 0.01750624549036234
# Mean Running Generator Loss : 0.5314781561017752
# Generating and Saving Images to ./images/epoch74_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 575 Summary
# Epoch time duration : 684.1692752838135
# generator Mean Gradients : 326.108135963595
# discriminator Mean Gradients : 0.8214955190711781
# Mean Running Discriminator Loss : 0.017492774623176506
# Mean Running Generator Loss : 0.5314762428459693
# Generating and Saving Images to ./images/epoch75_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 576 Summary
# Epoch time duration : 922.4039406776428
# generator Mean Gradients : 325.0045241555574
# discriminator Mean Gradients : 0.8212366324201277
# Mean Running Discriminator Loss : 0.017478398676456917
# Mean Running Generator Loss : 0.5314689019115875
# Generating and Saving Images to ./images/epoch76_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 577 Summary
# Epoch time duration : 676.6340718269348
# generator Mean Gradients : 323.2081219938416
# discriminator Mean Gradients : 0.8222698620133654
# Mean Running Discriminator Loss : 0.017464931185610613
# Mean Running Generator Loss : 0.5314558578852316
# Generating and Saving Images to ./images/epoch77_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 578 Summary
# Epoch time duration : 640.3511295318604
# generator Mean Gradients : 321.57893946404727
# discriminator Mean Gradients : 0.8238851416347434
# Mean Running Discriminator Loss : 0.017451354221514285
# Mean Running Generator Loss : 0.5314434669788444
# Generating and Saving Images to ./images/epoch78_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 579 Summary
# Epoch time duration : 641.2657613754272
# generator Mean Gradients : 319.6739328623258
# discriminator Mean Gradients : 0.8232773660850367
# Mean Running Discriminator Loss : 0.017437188832984386
# Mean Running Generator Loss : 0.5314435616049628
# Generating and Saving Images to ./images/epoch79_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 580 Summary
# Epoch time duration : 671.3851733207703
# generator Mean Gradients : 318.30185420287506
# discriminator Mean Gradients : 0.8205861113900836
# Mean Running Discriminator Loss : 0.01742177062570367
# Mean Running Generator Loss : 0.5314376474235832
# Generating and Saving Images to ./images/epoch80_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 581 Summary
# Epoch time duration : 971.5995979309082
# generator Mean Gradients : 317.3787549743197
# discriminator Mean Gradients : 0.819240998909811
# Mean Running Discriminator Loss : 0.017407237903194903
# Mean Running Generator Loss : 0.5314352268981808
# Generating and Saving Images to ./images/epoch81_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 582 Summary
# Epoch time duration : 674.0737216472626
# generator Mean Gradients : 316.21287524404505
# discriminator Mean Gradients : 0.8149023688967039
# Mean Running Discriminator Loss : 0.017389450409675912
# Mean Running Generator Loss : 0.5314249876754503
# Generating and Saving Images to ./images/epoch82_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 583 Summary
# Epoch time duration : 646.8062219619751
# generator Mean Gradients : 315.5570713361446
# discriminator Mean Gradients : 0.8146740757499931
# Mean Running Discriminator Loss : 0.01737582861006337
# Mean Running Generator Loss : 0.5314197594895598
# Generating and Saving Images to ./images/epoch83_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 584 Summary
# Epoch time duration : 638.725293636322
# generator Mean Gradients : 314.98121083771366
# discriminator Mean Gradients : 0.8141817472944233
# Mean Running Discriminator Loss : 0.017362814056270392
# Mean Running Generator Loss : 0.5314204958809583
# Generating and Saving Images to ./images/epoch84_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 585 Summary
# Epoch time duration : 648.2964696884155
# generator Mean Gradients : 315.2354103370386
# discriminator Mean Gradients : 0.8171487599439496
# Mean Running Discriminator Loss : 0.017353048516114945
# Mean Running Generator Loss : 0.5314192644017981
# Generating and Saving Images to ./images/epoch85_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 586 Summary
# Epoch time duration : 1065.9430694580078
# generator Mean Gradients : 314.32213605494803
# discriminator Mean Gradients : 0.8163030779230157
# Mean Running Discriminator Loss : 0.017338833952696323
# Mean Running Generator Loss : 0.5314103096024541
# Generating and Saving Images to ./images/epoch86_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 587 Summary
# Epoch time duration : 670.6520404815674
# generator Mean Gradients : 314.29931129024885
# discriminator Mean Gradients : 0.8149547959477657
# Mean Running Discriminator Loss : 0.017323783909715434
# Mean Running Generator Loss : 0.5313981413378911
# Generating and Saving Images to ./images/epoch87_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 588 Summary
# Epoch time duration : 644.5795848369598
# generator Mean Gradients : 314.21958219002227
# discriminator Mean Gradients : 0.8127337358556035
# Mean Running Discriminator Loss : 0.01730839003987438
# Mean Running Generator Loss : 0.5313966575629857
# Generating and Saving Images to ./images/epoch88_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 589 Summary
# Epoch time duration : 641.6951508522034
# generator Mean Gradients : 315.21596170534366
# discriminator Mean Gradients : 0.8103237130447184
# Mean Running Discriminator Loss : 0.01729291439686115
# Mean Running Generator Loss : 0.5313942405618831
# Generating and Saving Images to ./images/epoch89_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 590 Summary
# Epoch time duration : 682.5421121120453
# generator Mean Gradients : 315.87497911067896
# discriminator Mean Gradients : 0.8073995024091107
# Mean Running Discriminator Loss : 0.017277409331967097
# Mean Running Generator Loss : 0.5313839977025298
# Generating and Saving Images to ./images/epoch90_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 591 Summary
# Epoch time duration : 786.7055180072784
# generator Mean Gradients : 316.08759435420745
# discriminator Mean Gradients : 0.8082402827046218
# Mean Running Discriminator Loss : 0.017265494598546018
# Mean Running Generator Loss : 0.5313803972047602
# Generating and Saving Images to ./images/epoch91_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 592 Summary
# Epoch time duration : 656.348340511322
# generator Mean Gradients : 315.6014626610826
# discriminator Mean Gradients : 0.8101478869526418
# Mean Running Discriminator Loss : 0.017252854199711443
# Mean Running Generator Loss : 0.5313750237091528
# Generating and Saving Images to ./images/epoch92_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 593 Summary
# Epoch time duration : 645.5256161689758
# generator Mean Gradients : 314.9248430474016
# discriminator Mean Gradients : 0.8074786628535184
# Mean Running Discriminator Loss : 0.017236392073926587
# Mean Running Generator Loss : 0.5313703218957571
# Generating and Saving Images to ./images/epoch93_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 594 Summary
# Epoch time duration : 641.0875799655914
# generator Mean Gradients : 316.1913241693987
# discriminator Mean Gradients : 0.8068045481034397
# Mean Running Discriminator Loss : 0.017222559980070714
# Mean Running Generator Loss : 0.5313709784264175
# Generating and Saving Images to ./images/epoch94_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 595 Summary
# Epoch time duration : 645.7701365947723
# generator Mean Gradients : 315.6663422389916
# discriminator Mean Gradients : 0.8057612056150668
# Mean Running Discriminator Loss : 0.017208625145695954
# Mean Running Generator Loss : 0.5313769522123338
# Generating and Saving Images to ./images/epoch95_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 596 Summary
# Epoch time duration : 843.6800549030304
# generator Mean Gradients : 315.98537244684746
# discriminator Mean Gradients : 0.8041690010761443
# Mean Running Discriminator Loss : 0.01719454423023885
# Mean Running Generator Loss : 0.5313840573257538
# Generating and Saving Images to ./images/epoch96_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 597 Summary
# Epoch time duration : 687.3460614681244
# generator Mean Gradients : 316.77593840105396
# discriminator Mean Gradients : 0.8019441750753988
# Mean Running Discriminator Loss : 0.017179568382740647
# Mean Running Generator Loss : 0.5313770359680425
# Generating and Saving Images to ./images/epoch97_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 598 Summary
# Epoch time duration : 663.1799283027649
# generator Mean Gradients : 316.8273880174886
# discriminator Mean Gradients : 0.7987449930403587
# Mean Running Discriminator Loss : 0.017163093821458232
# Mean Running Generator Loss : 0.5313681062984524
# Generating and Saving Images to ./images/epoch98_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 599 Summary
# Epoch time duration : 676.1891520023346
# generator Mean Gradients : 316.43295766181814
# discriminator Mean Gradients : 0.7999819352705619
# Mean Running Discriminator Loss : 0.017151067294712496
# Mean Running Generator Loss : 0.5313649109262
# Generating and Saving Images to ./images/epoch99_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 600 Summary
# Epoch time duration : 664.9742226600647
# generator Mean Gradients : 317.0251447190932
# discriminator Mean Gradients : 0.7989561803024801
# Mean Running Discriminator Loss : 0.017137005485673533
# Mean Running Generator Loss : 0.5313676947291861
# Generating and Saving Images to ./images/epoch100_generator.png
#
# Training of the Model is Complete
