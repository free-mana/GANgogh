# %% [markdown]
# This first cell makes sure that torchgan is installed. It's primarily here for use with colab, since colab doesn't have torchgan installed by default.

# %%
# from torchGAN tutorial

try:
    import torchgan

    print(f"Existing TorchGAN {torchgan.__version__} installation found")
except ImportError:
    import subprocess
    import sys

    subprocess.check_call([sys.executable, "-m", "pip", "install", "torchgan"])
    import torchgan

    print(f"Installed TorchGAN {torchgan.__version__}")
# Out:
# Existing TorchGAN v0.1.0 installation found

# %%
import torch
import torch.nn as nn
import torch.backends.cudnn
import torch.utils.data as tdata
from torch.optim import Adam
import torchvision
import torchvision.datasets as dsets
from torchvision.datasets import ImageFolder
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt

import torchgan
from torchgan.models import *
from torchgan.losses import *
from torchgan.trainer import Trainer

# %% [markdown]
# This cell takes care of creating the dataset. Any PNG or JPEG image files are acceptable, as long as their width and height are the same. The models also require that the dimensions of the image are a perfect power of 2, but that can be overcome by scaling the images.
#
# Another thing to note is that the file path provided as root cannot be the exact folder that holds the images. In order for the path to be recognized properly, you must specify the folder that contains the folder with the images.
#
# For copyright reasons, the images that I am training from are not included with the GitHub repo. If you are interested in learning more, the citations for all of the images are included in the bibliography of the accompanying report.

# %%
size = 64
channels = 3 # change to 1 if using grayscale
data = ImageFolder(
    root="./data/otherGANGogh/images/landscape/",
    transform=transforms.Compose([
        transforms.Resize((size, size)),
        transforms.ToTensor(),
        #transforms.Grayscale(),
        transforms.Normalize(mean=.5, std=.5)
    ])
)
print(len(data))
# Out:
# 15000

# %%
dataloader = tdata.DataLoader(data, batch_size=64, shuffle=True)

# %%
# adapted from torchgan tutorial

dcgan_network = {
    "generator": {
        "name": DCGANGenerator,
        "args": {
            "encoding_dims": 100,
            "out_size": size,           # this is how many pixels wide and tall the generated images will be
            "out_channels": channels,
            "step_channels": 32,
            "nonlinearity": nn.LeakyReLU(0.2),
            "last_nonlinearity": nn.Tanh(),
        },
        "optimizer": {"name": Adam, "args": {"lr": 0.0001, "betas": (0.5, 0.999)}},
    },
    "discriminator": {
        "name": DCGANDiscriminator,
        "args": {
            "in_size": size,            # this is how many pixels wide and tall we resized the images to be.
            "in_channels": channels,
            "step_channels": 32,
            "nonlinearity": nn.LeakyReLU(0.2),
            "last_nonlinearity": nn.LeakyReLU(0.2),
        },
        "optimizer": {"name": Adam, "args": {"lr": 0.0003, "betas": (0.5, 0.999)}},
    },
}

# %%
# from torchgan tutorial

minimax_losses = [MinimaxGeneratorLoss(), MinimaxDiscriminatorLoss()]
wgangp_losses = [
    WassersteinGeneratorLoss(),
    WassersteinDiscriminatorLoss(),
    WassersteinGradientPenalty(),
]
lsgan_losses = [LeastSquaresGeneratorLoss(), LeastSquaresDiscriminatorLoss()]

# %% [markdown]
# If you're running this on colab, be sure to select a GPU runtime for the best performance.

# %%
# more from torchgan tutorial

if torch.cuda.is_available():
    device = torch.device("cuda:0")
    # Use deterministic cudnn algorithms
    torch.backends.cudnn.deterministic = True
    epochs = 10
else:
    device = torch.device("cpu")
    epochs = 5

print("Device: {}".format(device))
print("Epochs: {}".format(epochs))
# Out:
# Device: cpu
# Epochs: 5

# %%
# from torchgan tutorial

trainer = Trainer(
    dcgan_network,
    lsgan_losses,
    sample_size=64,
    epochs=400,             # you can override the number of epochs here if you want to try to get better results
    device=device
)

# %% [markdown]
# This is the cell that actually does the training. After it finishes, use the next cell if you want to keep training the same model.

# %%
trainer(dataloader)
# Out:
# c:\users\leafy\pycharmprojects\gangogh\venv\lib\site-packages\PIL\TiffImagePlugin.py:845: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# Saving Model at './model/gan0.model'
# Epoch 1 Summary
# Epoch time duration : 1093.5766220092773
# generator Mean Gradients : 15.610295308710686
# discriminator Mean Gradients : 82.22784864744416
# Mean Running Discriminator Loss : 0.14996620954034176
# Mean Running Generator Loss : 0.6748779137717916
# Generating and Saving Images to ./images/epoch1_generator.png
# c:\users\leafy\pycharmprojects\gangogh\venv\lib\site-packages\torchvision\utils.py:68: UserWarning: The parameter 'range' is deprecated since 0.12 and will be removed in 0.14. Please use 'value_range' instead.
#   warnings.warn(
# Saving Model at './model/gan1.model'
# Epoch 2 Summary
# Epoch time duration : 302.0853340625763
# generator Mean Gradients : 9.316171535907346
# discriminator Mean Gradients : 69.06701856266034
# Mean Running Discriminator Loss : 0.09922616566392653
# Mean Running Generator Loss : 0.6092537719201534
# Generating and Saving Images to ./images/epoch2_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 3 Summary
# Epoch time duration : 294.52990198135376
# generator Mean Gradients : 6.831519953119669
# discriminator Mean Gradients : 59.359494262194325
# Mean Running Discriminator Loss : 0.07946761221697567
# Mean Running Generator Loss : 0.5835720143630995
# Generating and Saving Images to ./images/epoch3_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 4 Summary
# Epoch time duration : 295.37965536117554
# generator Mean Gradients : 5.4884254345724255
# discriminator Mean Gradients : 50.85141301663774
# Mean Running Discriminator Loss : 0.06624936669064249
# Mean Running Generator Loss : 0.5722404447166209
# Generating and Saving Images to ./images/epoch4_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 5 Summary
# Epoch time duration : 296.87618350982666
# generator Mean Gradients : 4.6373125468215015
# discriminator Mean Gradients : 49.06578019225314
# Mean Running Discriminator Loss : 0.06120388460642797
# Mean Running Generator Loss : 0.5624927946988573
# Generating and Saving Images to ./images/epoch5_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 6 Summary
# Epoch time duration : 301.0102596282959
# generator Mean Gradients : 4.0952752588121
# discriminator Mean Gradients : 49.458120227859816
# Mean Running Discriminator Loss : 0.058161129841765934
# Mean Running Generator Loss : 0.5549037903230241
# Generating and Saving Images to ./images/epoch6_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 7 Summary
# Epoch time duration : 294.983850479126
# generator Mean Gradients : 3.8252527843161523
# discriminator Mean Gradients : 52.041003797163036
# Mean Running Discriminator Loss : 0.05888169317458131
# Mean Running Generator Loss : 0.5491203260412695
# Generating and Saving Images to ./images/epoch7_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 8 Summary
# Epoch time duration : 295.6050841808319
# generator Mean Gradients : 3.7077398726653996
# discriminator Mean Gradients : 50.63525657087901
# Mean Running Discriminator Loss : 0.05675923715895438
# Mean Running Generator Loss : 0.5476247118310409
# Generating and Saving Images to ./images/epoch8_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 9 Summary
# Epoch time duration : 294.79388451576233
# generator Mean Gradients : 3.615469158932364
# discriminator Mean Gradients : 51.25974737698367
# Mean Running Discriminator Loss : 0.05739672607841327
# Mean Running Generator Loss : 0.5441987899706718
# Generating and Saving Images to ./images/epoch9_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 10 Summary
# Epoch time duration : 447.4788234233856
# generator Mean Gradients : 3.574640440622272
# discriminator Mean Gradients : 51.5250309967112
# Mean Running Discriminator Loss : 0.05759607573911706
# Mean Running Generator Loss : 0.5416325088416009
# Generating and Saving Images to ./images/epoch10_generator.png
#
# Training of the Model is Complete

# %% [markdown]
# Use this cell instead of the previous one if you want to resume training a model that you saved from a previous session. Be sure to use the correct file path and file name when you call the function.

# %%
trainer.load_model("./model/gan4.model")
trainer(dataloader)
# Out:
# Loading Model From './model/gan4.model' to cpu
# Saving Model at './model/gan0.model'
# Epoch 301 Summary
# Epoch time duration : 722.0589020252228
# generator Mean Gradients : 6.46511217412435
# discriminator Mean Gradients : 8.494622940750826
# Mean Running Discriminator Loss : 0.033217040129727954
# Mean Running Generator Loss : 0.49969406692629664
# Generating and Saving Images to ./images/epoch1_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 302 Summary
# Epoch time duration : 901.6521351337433
# generator Mean Gradients : 6.791450095361007
# discriminator Mean Gradients : 9.103027983632733
# Mean Running Discriminator Loss : 0.03317885702537976
# Mean Running Generator Loss : 0.49969091195845683
# Generating and Saving Images to ./images/epoch2_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 303 Summary
# Epoch time duration : 374.27845454216003
# generator Mean Gradients : 7.056884646983044
# discriminator Mean Gradients : 9.619448774844207
# Mean Running Discriminator Loss : 0.03314643085947105
# Mean Running Generator Loss : 0.49967866237662784
# Generating and Saving Images to ./images/epoch3_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 304 Summary
# Epoch time duration : 300.3506474494934
# generator Mean Gradients : 7.322295373167503
# discriminator Mean Gradients : 9.262202759626309
# Mean Running Discriminator Loss : 0.03310408558818269
# Mean Running Generator Loss : 0.49967524633833604
# Generating and Saving Images to ./images/epoch4_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 305 Summary
# Epoch time duration : 764.2184453010559
# generator Mean Gradients : 7.925942867414284
# discriminator Mean Gradients : 9.144485278162263
# Mean Running Discriminator Loss : 0.03306496382766005
# Mean Running Generator Loss : 0.4996587752179481
# Generating and Saving Images to ./images/epoch5_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 306 Summary
# Epoch time duration : 378.1228566169739
# generator Mean Gradients : 7.864606434536809
# discriminator Mean Gradients : 9.407102632223628
# Mean Running Discriminator Loss : 0.0330372128232538
# Mean Running Generator Loss : 0.49964760886677495
# Generating and Saving Images to ./images/epoch6_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 307 Summary
# Epoch time duration : 299.1660442352295
# generator Mean Gradients : 8.132101124173634
# discriminator Mean Gradients : 9.345373138867481
# Mean Running Discriminator Loss : 0.03299934188567783
# Mean Running Generator Loss : 0.4996432020188295
# Generating and Saving Images to ./images/epoch7_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 308 Summary
# Epoch time duration : 301.57767510414124
# generator Mean Gradients : 8.025232055723281
# discriminator Mean Gradients : 9.413998511211913
# Mean Running Discriminator Loss : 0.03296619941453179
# Mean Running Generator Loss : 0.4996250899856008
# Generating and Saving Images to ./images/epoch8_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 309 Summary
# Epoch time duration : 306.9352719783783
# generator Mean Gradients : 7.994455057121393
# discriminator Mean Gradients : 9.260409053798506
# Mean Running Discriminator Loss : 0.03292379995391433
# Mean Running Generator Loss : 0.4996295666595936
# Generating and Saving Images to ./images/epoch9_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 310 Summary
# Epoch time duration : 315.7524974346161
# generator Mean Gradients : 7.958614188756811
# discriminator Mean Gradients : 9.561452669145913
# Mean Running Discriminator Loss : 0.032899133290701744
# Mean Running Generator Loss : 0.4996365177663083
# Generating and Saving Images to ./images/epoch10_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 311 Summary
# Epoch time duration : 299.2327139377594
# generator Mean Gradients : 8.065826433310084
# discriminator Mean Gradients : 9.435671870823768
# Mean Running Discriminator Loss : 0.03286088637912323
# Mean Running Generator Loss : 0.49962731976460406
# Generating and Saving Images to ./images/epoch11_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 312 Summary
# Epoch time duration : 301.8475503921509
# generator Mean Gradients : 8.068980704192358
# discriminator Mean Gradients : 9.449923745706124
# Mean Running Discriminator Loss : 0.032827262611921516
# Mean Running Generator Loss : 0.49962727492019754
# Generating and Saving Images to ./images/epoch12_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 313 Summary
# Epoch time duration : 300.3237760066986
# generator Mean Gradients : 8.051204618000044
# discriminator Mean Gradients : 9.407408346435899
# Mean Running Discriminator Loss : 0.032792254776381966
# Mean Running Generator Loss : 0.4996092074043275
# Generating and Saving Images to ./images/epoch13_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 314 Summary
# Epoch time duration : 301.07621002197266
# generator Mean Gradients : 7.957931109520449
# discriminator Mean Gradients : 9.258637858746939
# Mean Running Discriminator Loss : 0.0327467008705373
# Mean Running Generator Loss : 0.4996198987241707
# Generating and Saving Images to ./images/epoch14_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 315 Summary
# Epoch time duration : 516.9951646327972
# generator Mean Gradients : 8.088570889909972
# discriminator Mean Gradients : 9.258681224680513
# Mean Running Discriminator Loss : 0.03271137143298103
# Mean Running Generator Loss : 0.4996109114784077
# Generating and Saving Images to ./images/epoch15_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 316 Summary
# Epoch time duration : 366.39167165756226
# generator Mean Gradients : 8.056588023057735
# discriminator Mean Gradients : 9.212328840339877
# Mean Running Discriminator Loss : 0.03267311293421975
# Mean Running Generator Loss : 0.4996035272561048
# Generating and Saving Images to ./images/epoch16_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 317 Summary
# Epoch time duration : 300.3620717525482
# generator Mean Gradients : 8.20213473727904
# discriminator Mean Gradients : 9.128264773778097
# Mean Running Discriminator Loss : 0.03263165740559033
# Mean Running Generator Loss : 0.499598266287945
# Generating and Saving Images to ./images/epoch17_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 318 Summary
# Epoch time duration : 301.7111999988556
# generator Mean Gradients : 8.17240427060931
# discriminator Mean Gradients : 9.060983251862636
# Mean Running Discriminator Loss : 0.0325916053835319
# Mean Running Generator Loss : 0.4996020030518915
# Generating and Saving Images to ./images/epoch18_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 319 Summary
# Epoch time duration : 299.66510939598083
# generator Mean Gradients : 8.119319040838134
# discriminator Mean Gradients : 9.12525963257916
# Mean Running Discriminator Loss : 0.03256065154754762
# Mean Running Generator Loss : 0.49961697185577403
# Generating and Saving Images to ./images/epoch19_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 320 Summary
# Epoch time duration : 300.8270785808563
# generator Mean Gradients : 8.06098817544536
# discriminator Mean Gradients : 9.170138080686657
# Mean Running Discriminator Loss : 0.03253108244429546
# Mean Running Generator Loss : 0.4996192139374251
# Generating and Saving Images to ./images/epoch20_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 321 Summary
# Epoch time duration : 307.8475739955902
# generator Mean Gradients : 8.066156196664
# discriminator Mean Gradients : 9.136035979275855
# Mean Running Discriminator Loss : 0.03249404996605381
# Mean Running Generator Loss : 0.4996105741017846
# Generating and Saving Images to ./images/epoch21_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 322 Summary
# Epoch time duration : 298.5906081199646
# generator Mean Gradients : 8.07863643578924
# discriminator Mean Gradients : 9.263559636744764
# Mean Running Discriminator Loss : 0.032472346373682945
# Mean Running Generator Loss : 0.4996041951428061
# Generating and Saving Images to ./images/epoch22_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 323 Summary
# Epoch time duration : 311.4724531173706
# generator Mean Gradients : 8.043253817710243
# discriminator Mean Gradients : 9.222390296389827
# Mean Running Discriminator Loss : 0.03243710862417563
# Mean Running Generator Loss : 0.4996009450126335
# Generating and Saving Images to ./images/epoch23_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 324 Summary
# Epoch time duration : 298.85061955451965
# generator Mean Gradients : 8.062010886576417
# discriminator Mean Gradients : 9.21346038296418
# Mean Running Discriminator Loss : 0.032402961039052124
# Mean Running Generator Loss : 0.49960509781317897
# Generating and Saving Images to ./images/epoch24_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 325 Summary
# Epoch time duration : 298.4193570613861
# generator Mean Gradients : 8.136098682373797
# discriminator Mean Gradients : 9.295635632750383
# Mean Running Discriminator Loss : 0.032378951744232845
# Mean Running Generator Loss : 0.49960272362803865
# Generating and Saving Images to ./images/epoch25_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 326 Summary
# Epoch time duration : 685.2706062793732
# generator Mean Gradients : 8.120627947488948
# discriminator Mean Gradients : 9.244984379457005
# Mean Running Discriminator Loss : 0.03233981218456813
# Mean Running Generator Loss : 0.4996071538617189
# Generating and Saving Images to ./images/epoch26_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 327 Summary
# Epoch time duration : 390.6273682117462
# generator Mean Gradients : 8.116443712905033
# discriminator Mean Gradients : 9.285053032670385
# Mean Running Discriminator Loss : 0.032311068972891065
# Mean Running Generator Loss : 0.4995939820424101
# Generating and Saving Images to ./images/epoch27_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 328 Summary
# Epoch time duration : 301.2423300743103
# generator Mean Gradients : 8.163063238142476
# discriminator Mean Gradients : 9.315474156856316
# Mean Running Discriminator Loss : 0.03228275680238019
# Mean Running Generator Loss : 0.49958043752830683
# Generating and Saving Images to ./images/epoch28_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 329 Summary
# Epoch time duration : 300.0299668312073
# generator Mean Gradients : 8.134408616590168
# discriminator Mean Gradients : 9.226061477167672
# Mean Running Discriminator Loss : 0.03223984062415447
# Mean Running Generator Loss : 0.49957962700397146
# Generating and Saving Images to ./images/epoch29_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 330 Summary
# Epoch time duration : 299.4816310405731
# generator Mean Gradients : 8.188568561413424
# discriminator Mean Gradients : 9.15663894863755
# Mean Running Discriminator Loss : 0.03219830819028523
# Mean Running Generator Loss : 0.49957053771015525
# Generating and Saving Images to ./images/epoch30_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 331 Summary
# Epoch time duration : 299.6127197742462
# generator Mean Gradients : 8.155003540513396
# discriminator Mean Gradients : 9.124039534757221
# Mean Running Discriminator Loss : 0.03216115535490903
# Mean Running Generator Loss : 0.4995793594571008
# Generating and Saving Images to ./images/epoch31_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 332 Summary
# Epoch time duration : 298.8940796852112
# generator Mean Gradients : 8.152231889397052
# discriminator Mean Gradients : 9.18499962916315
# Mean Running Discriminator Loss : 0.03213813790820049
# Mean Running Generator Loss : 0.49956696743842227
# Generating and Saving Images to ./images/epoch32_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 333 Summary
# Epoch time duration : 298.6228868961334
# generator Mean Gradients : 8.124134047276652
# discriminator Mean Gradients : 9.154084936474352
# Mean Running Discriminator Loss : 0.032102704931797454
# Mean Running Generator Loss : 0.49956468015558825
# Generating and Saving Images to ./images/epoch33_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 334 Summary
# Epoch time duration : 299.7798743247986
# generator Mean Gradients : 8.183013030778364
# discriminator Mean Gradients : 9.146697101500905
# Mean Running Discriminator Loss : 0.03207083737617911
# Mean Running Generator Loss : 0.4995526727709949
# Generating and Saving Images to ./images/epoch34_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 335 Summary
# Epoch time duration : 300.7615644931793
# generator Mean Gradients : 8.184173655672895
# discriminator Mean Gradients : 9.068807350632522
# Mean Running Discriminator Loss : 0.03202873119533715
# Mean Running Generator Loss : 0.4995552127282367
# Generating and Saving Images to ./images/epoch35_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 336 Summary
# Epoch time duration : 488.31318163871765
# generator Mean Gradients : 8.155754816240282
# discriminator Mean Gradients : 9.041722163909288
# Mean Running Discriminator Loss : 0.03199213243443108
# Mean Running Generator Loss : 0.4995631678242202
# Generating and Saving Images to ./images/epoch36_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 337 Summary
# Epoch time duration : 733.2186563014984
# generator Mean Gradients : 8.158079307939335
# discriminator Mean Gradients : 9.069988451188909
# Mean Running Discriminator Loss : 0.031966020979174906
# Mean Running Generator Loss : 0.4995517702273772
# Generating and Saving Images to ./images/epoch37_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 338 Summary
# Epoch time duration : 301.41835594177246
# generator Mean Gradients : 8.155502031010123
# discriminator Mean Gradients : 9.017983618049287
# Mean Running Discriminator Loss : 0.03192659382577988
# Mean Running Generator Loss : 0.49955688695573736
# Generating and Saving Images to ./images/epoch38_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 339 Summary
# Epoch time duration : 301.57331919670105
# generator Mean Gradients : 8.187798340784274
# discriminator Mean Gradients : 9.001643242111736
# Mean Running Discriminator Loss : 0.03189075929464908
# Mean Running Generator Loss : 0.4995673723470684
# Generating and Saving Images to ./images/epoch39_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 340 Summary
# Epoch time duration : 301.724552154541
# generator Mean Gradients : 8.198255442367387
# discriminator Mean Gradients : 9.016687044079426
# Mean Running Discriminator Loss : 0.03186325342719617
# Mean Running Generator Loss : 0.4995674991940564
# Generating and Saving Images to ./images/epoch40_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 341 Summary
# Epoch time duration : 306.19512844085693
# generator Mean Gradients : 8.17825801415849
# discriminator Mean Gradients : 8.975893181422283
# Mean Running Discriminator Loss : 0.03182494024087564
# Mean Running Generator Loss : 0.499576387553059
# Generating and Saving Images to ./images/epoch41_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 342 Summary
# Epoch time duration : 301.9591271877289
# generator Mean Gradients : 8.200321364471542
# discriminator Mean Gradients : 8.975458800485182
# Mean Running Discriminator Loss : 0.03179295461839122
# Mean Running Generator Loss : 0.4995692627821282
# Generating and Saving Images to ./images/epoch42_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 343 Summary
# Epoch time duration : 299.35210371017456
# generator Mean Gradients : 8.183333780310788
# discriminator Mean Gradients : 8.978581391658906
# Mean Running Discriminator Loss : 0.03176291447025257
# Mean Running Generator Loss : 0.49956227204725484
# Generating and Saving Images to ./images/epoch43_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 344 Summary
# Epoch time duration : 300.12689304351807
# generator Mean Gradients : 8.245793661845653
# discriminator Mean Gradients : 8.952876994638459
# Mean Running Discriminator Loss : 0.0317293460565257
# Mean Running Generator Loss : 0.499550317354751
# Generating and Saving Images to ./images/epoch44_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 345 Summary
# Epoch time duration : 300.09960770606995
# generator Mean Gradients : 8.250471589160336
# discriminator Mean Gradients : 8.926276056217759
# Mean Running Discriminator Loss : 0.03169447906364722
# Mean Running Generator Loss : 0.49954585546196295
# Generating and Saving Images to ./images/epoch45_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 346 Summary
# Epoch time duration : 592.6232032775879
# generator Mean Gradients : 8.2668595350677
# discriminator Mean Gradients : 8.939314634366687
# Mean Running Discriminator Loss : 0.03166591178101459
# Mean Running Generator Loss : 0.49954237061789913
# Generating and Saving Images to ./images/epoch46_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 347 Summary
# Epoch time duration : 796.6940107345581
# generator Mean Gradients : 8.269283458333037
# discriminator Mean Gradients : 8.950841630833624
# Mean Running Discriminator Loss : 0.031636266878604644
# Mean Running Generator Loss : 0.4995408719527165
# Generating and Saving Images to ./images/epoch47_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 348 Summary
# Epoch time duration : 300.4698603153229
# generator Mean Gradients : 8.257202335522964
# discriminator Mean Gradients : 8.962504528698132
# Mean Running Discriminator Loss : 0.031608976556719764
# Mean Running Generator Loss : 0.49953840726403
# Generating and Saving Images to ./images/epoch48_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 349 Summary
# Epoch time duration : 298.2738130092621
# generator Mean Gradients : 8.241610910966696
# discriminator Mean Gradients : 8.93871499572013
# Mean Running Discriminator Loss : 0.03157244854549513
# Mean Running Generator Loss : 0.4995426683476086
# Generating and Saving Images to ./images/epoch49_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 350 Summary
# Epoch time duration : 299.3199803829193
# generator Mean Gradients : 8.232989418429796
# discriminator Mean Gradients : 8.910589439226086
# Mean Running Discriminator Loss : 0.031536836847215664
# Mean Running Generator Loss : 0.49953885852611174
# Generating and Saving Images to ./images/epoch50_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 351 Summary
# Epoch time duration : 300.77594232559204
# generator Mean Gradients : 8.284303241670944
# discriminator Mean Gradients : 8.870827500400658
# Mean Running Discriminator Loss : 0.03149962425133704
# Mean Running Generator Loss : 0.4995293436549487
# Generating and Saving Images to ./images/epoch51_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 352 Summary
# Epoch time duration : 298.1904077529907
# generator Mean Gradients : 8.269174788912615
# discriminator Mean Gradients : 8.886265234672013
# Mean Running Discriminator Loss : 0.03147236475439758
# Mean Running Generator Loss : 0.4995285926614591
# Generating and Saving Images to ./images/epoch52_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 353 Summary
# Epoch time duration : 297.28651690483093
# generator Mean Gradients : 8.27989610892916
# discriminator Mean Gradients : 8.904844601072567
# Mean Running Discriminator Loss : 0.031447788400654215
# Mean Running Generator Loss : 0.4995167860078356
# Generating and Saving Images to ./images/epoch53_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 354 Summary
# Epoch time duration : 298.8619668483734
# generator Mean Gradients : 8.31333898566593
# discriminator Mean Gradients : 8.887395971829624
# Mean Running Discriminator Loss : 0.03141469864640105
# Mean Running Generator Loss : 0.49952444777086114
# Generating and Saving Images to ./images/epoch54_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 355 Summary
# Epoch time duration : 300.0215599536896
# generator Mean Gradients : 8.321997282783553
# discriminator Mean Gradients : 8.848376860031308
# Mean Running Discriminator Loss : 0.03137740964750383
# Mean Running Generator Loss : 0.4995250731305623
# Generating and Saving Images to ./images/epoch55_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 356 Summary
# Epoch time duration : 559.2602136135101
# generator Mean Gradients : 8.311018846225965
# discriminator Mean Gradients : 8.840656688015711
# Mean Running Discriminator Loss : 0.03134632599135398
# Mean Running Generator Loss : 0.4995309708020582
# Generating and Saving Images to ./images/epoch56_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 357 Summary
# Epoch time duration : 350.07805585861206
# generator Mean Gradients : 8.304829048257893
# discriminator Mean Gradients : 8.79133005131248
# Mean Running Discriminator Loss : 0.03130642688381975
# Mean Running Generator Loss : 0.49953986604519995
# Generating and Saving Images to ./images/epoch57_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 358 Summary
# Epoch time duration : 303.5679335594177
# generator Mean Gradients : 8.301859125454929
# discriminator Mean Gradients : 8.797747268922036
# Mean Running Discriminator Loss : 0.031278272867182835
# Mean Running Generator Loss : 0.49954396491498554
# Generating and Saving Images to ./images/epoch58_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 359 Summary
# Epoch time duration : 310.65189576148987
# generator Mean Gradients : 8.288634047751842
# discriminator Mean Gradients : 8.785613800683116
# Mean Running Discriminator Loss : 0.031247285054949694
# Mean Running Generator Loss : 0.4995407345561059
# Generating and Saving Images to ./images/epoch59_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 360 Summary
# Epoch time duration : 303.0529067516327
# generator Mean Gradients : 8.290949085767418
# discriminator Mean Gradients : 8.768113872870394
# Mean Running Discriminator Loss : 0.031214860001398385
# Mean Running Generator Loss : 0.4995415831648747
# Generating and Saving Images to ./images/epoch60_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 361 Summary
# Epoch time duration : 305.4694256782532
# generator Mean Gradients : 8.293919065550208
# discriminator Mean Gradients : 8.784236419685541
# Mean Running Discriminator Loss : 0.03119197330933973
# Mean Running Generator Loss : 0.4995239674383696
# Generating and Saving Images to ./images/epoch61_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 362 Summary
# Epoch time duration : 300.7128975391388
# generator Mean Gradients : 8.302092133710568
# discriminator Mean Gradients : 8.810105704322936
# Mean Running Discriminator Loss : 0.031171928371802108
# Mean Running Generator Loss : 0.4995074449049028
# Generating and Saving Images to ./images/epoch62_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 363 Summary
# Epoch time duration : 297.99379539489746
# generator Mean Gradients : 8.301085566482424
# discriminator Mean Gradients : 8.820645678645922
# Mean Running Discriminator Loss : 0.031147069306459513
# Mean Running Generator Loss : 0.49952108059828493
# Generating and Saving Images to ./images/epoch63_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 364 Summary
# Epoch time duration : 297.2434940338135
# generator Mean Gradients : 8.306606803770263
# discriminator Mean Gradients : 8.79801605962987
# Mean Running Discriminator Loss : 0.031115752022988007
# Mean Running Generator Loss : 0.4995308475882888
# Generating and Saving Images to ./images/epoch64_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 365 Summary
# Epoch time duration : 296.54347920417786
# generator Mean Gradients : 8.347869480996588
# discriminator Mean Gradients : 8.777850396600412
# Mean Running Discriminator Loss : 0.031084706355228312
# Mean Running Generator Loss : 0.49953268730051487
# Generating and Saving Images to ./images/epoch65_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 366 Summary
# Epoch time duration : 299.3853614330292
# generator Mean Gradients : 8.337356233405426
# discriminator Mean Gradients : 8.769033132272815
# Mean Running Discriminator Loss : 0.031055480887112432
# Mean Running Generator Loss : 0.4995327978507646
# Generating and Saving Images to ./images/epoch66_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 367 Summary
# Epoch time duration : 683.2377398014069
# generator Mean Gradients : 8.338701942923446
# discriminator Mean Gradients : 8.778666279660312
# Mean Running Discriminator Loss : 0.03103122550496236
# Mean Running Generator Loss : 0.4995325110983597
# Generating and Saving Images to ./images/epoch67_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 368 Summary
# Epoch time duration : 344.47871255874634
# generator Mean Gradients : 8.35956803449705
# discriminator Mean Gradients : 8.771960019009601
# Mean Running Discriminator Loss : 0.03100139412762525
# Mean Running Generator Loss : 0.49951753124748044
# Generating and Saving Images to ./images/epoch68_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 369 Summary
# Epoch time duration : 299.80624651908875
# generator Mean Gradients : 8.361080489428055
# discriminator Mean Gradients : 8.766844395974044
# Mean Running Discriminator Loss : 0.03097433766604367
# Mean Running Generator Loss : 0.4995073399508604
# Generating and Saving Images to ./images/epoch69_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 370 Summary
# Epoch time duration : 299.26261734962463
# generator Mean Gradients : 8.379842223166861
# discriminator Mean Gradients : 8.751319388540528
# Mean Running Discriminator Loss : 0.030943999381349254
# Mean Running Generator Loss : 0.4994995594250018
# Generating and Saving Images to ./images/epoch70_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 371 Summary
# Epoch time duration : 300.2020061016083
# generator Mean Gradients : 8.400394734345698
# discriminator Mean Gradients : 8.735902433666247
# Mean Running Discriminator Loss : 0.030914812266535863
# Mean Running Generator Loss : 0.4994965632658845
# Generating and Saving Images to ./images/epoch71_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 372 Summary
# Epoch time duration : 301.2531988620758
# generator Mean Gradients : 8.39231469538738
# discriminator Mean Gradients : 8.719284781005186
# Mean Running Discriminator Loss : 0.030883386366070808
# Mean Running Generator Loss : 0.49949711975876987
# Generating and Saving Images to ./images/epoch72_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 373 Summary
# Epoch time duration : 300.3742470741272
# generator Mean Gradients : 8.398600693530666
# discriminator Mean Gradients : 8.713138227389651
# Mean Running Discriminator Loss : 0.03085549585440472
# Mean Running Generator Loss : 0.49948253599385706
# Generating and Saving Images to ./images/epoch73_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 374 Summary
# Epoch time duration : 300.14931893348694
# generator Mean Gradients : 8.448827315243378
# discriminator Mean Gradients : 8.700633184311048
# Mean Running Discriminator Loss : 0.030827829706423143
# Mean Running Generator Loss : 0.4994742068664784
# Generating and Saving Images to ./images/epoch74_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 375 Summary
# Epoch time duration : 300.309627532959
# generator Mean Gradients : 8.443804565405594
# discriminator Mean Gradients : 8.682729475013142
# Mean Running Discriminator Loss : 0.030796168374212077
# Mean Running Generator Loss : 0.4994833814650563
# Generating and Saving Images to ./images/epoch75_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 376 Summary
# Epoch time duration : 300.7767117023468
# generator Mean Gradients : 8.440023311508371
# discriminator Mean Gradients : 8.671221331641249
# Mean Running Discriminator Loss : 0.030766990590402533
# Mean Running Generator Loss : 0.49948554231581604
# Generating and Saving Images to ./images/epoch76_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 377 Summary
# Epoch time duration : 614.6618385314941
# generator Mean Gradients : 8.45577634782859
# discriminator Mean Gradients : 8.676130852260012
# Mean Running Discriminator Loss : 0.030744657202200303
# Mean Running Generator Loss : 0.4994852961649528
# Generating and Saving Images to ./images/epoch77_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 378 Summary
# Epoch time duration : 564.7045555114746
# generator Mean Gradients : 8.472943781577978
# discriminator Mean Gradients : 8.735910596359947
# Mean Running Discriminator Loss : 0.03074027977244901
# Mean Running Generator Loss : 0.49947577114629543
# Generating and Saving Images to ./images/epoch78_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 379 Summary
# Epoch time duration : 300.2323682308197
# generator Mean Gradients : 8.472149279553967
# discriminator Mean Gradients : 8.711994261044932
# Mean Running Discriminator Loss : 0.03070937487510233
# Mean Running Generator Loss : 0.4994690320395824
# Generating and Saving Images to ./images/epoch79_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 380 Summary
# Epoch time duration : 301.7949204444885
# generator Mean Gradients : 8.470778704673805
# discriminator Mean Gradients : 8.688521729162577
# Mean Running Discriminator Loss : 0.030676870176679177
# Mean Running Generator Loss : 0.4994610625635603
# Generating and Saving Images to ./images/epoch80_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 381 Summary
# Epoch time duration : 299.93195509910583
# generator Mean Gradients : 8.479309635073326
# discriminator Mean Gradients : 8.679747279822198
# Mean Running Discriminator Loss : 0.030650223419533124
# Mean Running Generator Loss : 0.49945725038528654
# Generating and Saving Images to ./images/epoch81_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 382 Summary
# Epoch time duration : 298.4657826423645
# generator Mean Gradients : 8.519315034472484
# discriminator Mean Gradients : 8.679201197699133
# Mean Running Discriminator Loss : 0.030625894144402564
# Mean Running Generator Loss : 0.4994550338753005
# Generating and Saving Images to ./images/epoch82_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 383 Summary
# Epoch time duration : 300.6122829914093
# generator Mean Gradients : 8.517415001448619
# discriminator Mean Gradients : 8.665202958512529
# Mean Running Discriminator Loss : 0.030598134259797266
# Mean Running Generator Loss : 0.4994530377613294
# Generating and Saving Images to ./images/epoch83_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 384 Summary
# Epoch time duration : 299.18584060668945
# generator Mean Gradients : 8.529692219222614
# discriminator Mean Gradients : 8.634418296642348
# Mean Running Discriminator Loss : 0.0305633827240641
# Mean Running Generator Loss : 0.49943814886410237
# Generating and Saving Images to ./images/epoch84_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 385 Summary
# Epoch time duration : 301.4711949825287
# generator Mean Gradients : 8.520985287299744
# discriminator Mean Gradients : 8.617486697102354
# Mean Running Discriminator Loss : 0.030533585988281594
# Mean Running Generator Loss : 0.4994552429383155
# Generating and Saving Images to ./images/epoch85_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 386 Summary
# Epoch time duration : 298.8199956417084
# generator Mean Gradients : 8.524363185968788
# discriminator Mean Gradients : 8.614818094802123
# Mean Running Discriminator Loss : 0.030508473134521492
# Mean Running Generator Loss : 0.4994527001839438
# Generating and Saving Images to ./images/epoch86_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 387 Summary
# Epoch time duration : 573.8172812461853
# generator Mean Gradients : 8.543675296710818
# discriminator Mean Gradients : 8.586512608393807
# Mean Running Discriminator Loss : 0.030474941481164516
# Mean Running Generator Loss : 0.49944953731244246
# Generating and Saving Images to ./images/epoch87_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 388 Summary
# Epoch time duration : 781.1480097770691
# generator Mean Gradients : 8.55205872828954
# discriminator Mean Gradients : 8.602746760319558
# Mean Running Discriminator Loss : 0.03045873268808533
# Mean Running Generator Loss : 0.49943193064875496
# Generating and Saving Images to ./images/epoch88_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 389 Summary
# Epoch time duration : 301.681627035141
# generator Mean Gradients : 8.559179406110283
# discriminator Mean Gradients : 8.584146189706141
# Mean Running Discriminator Loss : 0.03042896290265461
# Mean Running Generator Loss : 0.4994418005397425
# Generating and Saving Images to ./images/epoch89_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 390 Summary
# Epoch time duration : 300.3074631690979
# generator Mean Gradients : 8.560938483643525
# discriminator Mean Gradients : 8.571349758501057
# Mean Running Discriminator Loss : 0.030400680805771397
# Mean Running Generator Loss : 0.4994394688569192
# Generating and Saving Images to ./images/epoch90_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 391 Summary
# Epoch time duration : 301.32770013809204
# generator Mean Gradients : 8.559557153122244
# discriminator Mean Gradients : 8.552436350049492
# Mean Running Discriminator Loss : 0.030369969980224926
# Mean Running Generator Loss : 0.4994415996996072
# Generating and Saving Images to ./images/epoch91_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 392 Summary
# Epoch time duration : 301.24229979515076
# generator Mean Gradients : 8.548095744546792
# discriminator Mean Gradients : 8.539287127482421
# Mean Running Discriminator Loss : 0.03034158071682089
# Mean Running Generator Loss : 0.49943681434638026
# Generating and Saving Images to ./images/epoch92_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 393 Summary
# Epoch time duration : 301.82430386543274
# generator Mean Gradients : 8.54064728748251
# discriminator Mean Gradients : 8.545979908149672
# Mean Running Discriminator Loss : 0.030319087437816035
# Mean Running Generator Loss : 0.49944393284641847
# Generating and Saving Images to ./images/epoch93_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 394 Summary
# Epoch time duration : 299.25863337516785
# generator Mean Gradients : 8.54148956295354
# discriminator Mean Gradients : 8.540242494634855
# Mean Running Discriminator Loss : 0.030293743142902205
# Mean Running Generator Loss : 0.49944398733587575
# Generating and Saving Images to ./images/epoch94_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 395 Summary
# Epoch time duration : 299.85611391067505
# generator Mean Gradients : 8.546156643864158
# discriminator Mean Gradients : 8.526374748658391
# Mean Running Discriminator Loss : 0.03026618897165414
# Mean Running Generator Loss : 0.4994534092088482
# Generating and Saving Images to ./images/epoch95_generator.png
#
# Saving Model at './model/gan0.model'
# Epoch 396 Summary
# Epoch time duration : 301.77592730522156
# generator Mean Gradients : 8.544971251125528
# discriminator Mean Gradients : 8.508748149043713
# Mean Running Discriminator Loss : 0.030235849802832438
# Mean Running Generator Loss : 0.4994668304582334
# Generating and Saving Images to ./images/epoch96_generator.png
#
# Saving Model at './model/gan1.model'
# Epoch 397 Summary
# Epoch time duration : 582.9693608283997
# generator Mean Gradients : 8.550358632452177
# discriminator Mean Gradients : 8.494582789371108
# Mean Running Discriminator Loss : 0.03020823508350017
# Mean Running Generator Loss : 0.4994550678865646
# Generating and Saving Images to ./images/epoch97_generator.png
#
# Saving Model at './model/gan2.model'
# Epoch 398 Summary
# Epoch time duration : 381.81516098976135
# generator Mean Gradients : 8.545879029322288
# discriminator Mean Gradients : 8.4806124331634
# Mean Running Discriminator Loss : 0.030179766508664285
# Mean Running Generator Loss : 0.49946672142103216
# Generating and Saving Images to ./images/epoch98_generator.png
#
# Saving Model at './model/gan3.model'
# Epoch 399 Summary
# Epoch time duration : 300.64506435394287
# generator Mean Gradients : 8.551026148059547
# discriminator Mean Gradients : 8.475534732865487
# Mean Running Discriminator Loss : 0.030155637563718127
# Mean Running Generator Loss : 0.49945670973982537
# Generating and Saving Images to ./images/epoch99_generator.png
#
# Saving Model at './model/gan4.model'
# Epoch 400 Summary
# Epoch time duration : 301.54006695747375
# generator Mean Gradients : 8.572015446335797
# discriminator Mean Gradients : 8.46224182345491
# Mean Running Discriminator Loss : 0.030129335763071603
# Mean Running Generator Loss : 0.49944612130792215
# Generating and Saving Images to ./images/epoch100_generator.png
#
# Training of the Model is Complete
